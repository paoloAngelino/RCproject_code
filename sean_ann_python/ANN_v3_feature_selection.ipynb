# %%
import rpy2.robjects as ro
import rpy2.robjects.packages as rpackages
import anndata as ad
import scanpy as sc
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
import pandas as pd
import umap
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from keras.callbacks import EarlyStopping
import seaborn as sb
from scipy.spatial.distance import pdist
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import pearsonr
import time
from keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.decomposition import PCA
import math
import random
import rpy2.robjects as ro
from rpy2 import robjects
from rpy2.robjects import r
from rpy2.robjects import pandas2ri
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model
import pydot

# adata = sc.read('/tmp/work/RCproject_code/sce_export.h5ad')
epoch_count = 0

# Enable automatic conversion between R objects and pandas DataFrames
pandas2ri.activate()

#exclude partial
# adata = adata[~adata.obs['Response'].isin(['partial']), :]
# Out:
# 2025-01-20 15:03:13.685605: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
test_set_size = 0.1
dropout_rate = 0.3 #0.1
balance = True
l2_reg = 0.2
batch_size = 16  #determines how many samples are processed per batch, each epoch will process multiple batches
# learning_rate = 0.00001
learning_rate = 0.01
num_epochs = 100000
report_frequency = 1
accuracy_threshold = 0.9  #currently not used
auc_threshold = 0.90
clipnorm = 2.0
simplifly_categories = True
holdout_size = 0.5

use_boruta_list = False
use_gene_list = False
use_diff_genes = False
use_imported_genes = True
current_gene_list = 'de_intersect_plus_bulk_genes'#'sig9_0.05'
# current_gene_list = 'Boruta_6'

PCA_reduce = False
n_comp_PCA = 16

multiplier = 3 #0.91 performance with 3

#dynamic learning rate parameters

lr_dict = {
    0.6:  0.005,
    0.7:  0.001,
    0.8:  0.0005,
    0.85: 0.0001,
    0.88: 0.00005,
    0.89: 0.00001,
    0.9:  0.000005,
    0.91: 0.000001,
    0.92: 0.0000005
}

auc_thresholds = [0.6, 0.7, 0.8, 0.85, 0.88,0.89,0.90,0.91,0.92]  # AUC values at which the learning rate should be adjusted

# %%
# Load the RDS file
rds_path = '/tmp/work/RCproject/gene_lists.rds'
rds_data = r.readRDS(rds_path)

# Extract the names of the lists and their contents
gene_lists = {}
for name, item in zip(rds_data.names, rds_data):
    # Each 'item' is a list associated with the 'name'
    inner_list = list(item)  # Convert the inner R list to a Python list
    gene_lists[name] = inner_list

# Now `python_data` is a dictionary with names as keys and lists as values
print(gene_lists.keys())
# Out:
# dict_keys(['meta', 'DE4', 'DEall', 'meta_intersect_unionDE', 'de_intersect', 'de_intersect_plus_bulk_genes', '5k', 'CV', 'CV300', 'CV300_4MA', 'Boruta_4MA', 'Boruta_6', 'CVBig', 'final300', 'final350', 'final', 'sig_4_6_0.05', 'sig_4_6_0.1', 'sig9_0.05', 'sig9_0.01', 'sig9', 'GEOMX_4_6_0.05_'])

# %%
# select a gene_list

current_genes = gene_lists[current_gene_list]
print(len(current_genes))
# Out:
# 366

# %%
#import the data

# Function to read RDS file and extract counts and metadata
def read_rds_to_matrix_and_metadata(file_path):
    # Load the RDS file in R
    ro.r(f"sce <- readRDS('{file_path}')")

    # Extract count data (assumed to be stored in assays)
    counts = ro.r('assay(sce, "scalelogcounts")')
    # Extract row (gene) and column (cell) names
    gene_names = ro.r('rownames(sce)')
    cell_names = ro.r('colnames(sce)')
    
    # Convert to a NumPy array
    counts_np = ro.conversion.rpy2py(counts)

    # Convert the counts matrix to a pandas DataFrame
    counts_df = pd.DataFrame(counts_np, index=gene_names, columns=cell_names)

    # Extract metadata from colData and convert to a pandas DataFrame directly
    metadata = ro.r('as.data.frame(colData(sce))')  # Get the colData as an R data frame
    metadata_df = pd.DataFrame(metadata)  # Convert R data frame to pandas DataFrame directly

    return counts_df, metadata_df

# Usage example
file_path = '/tmp/work/RCproject/GEO_singlecellexperiment.rds'
counts_df, metadata_df = read_rds_to_matrix_and_metadata(file_path)

# Display the results
print("Counts DataFrame:")
print(counts_df.head())  # Show the first few rows of the counts DataFrame
print("\nMetadata DataFrame:")
print(metadata_df.head())  # Show the first few rows of the metadata DataFrame
# Out:
# R[write to console]: Loading required package: SingleCellExperiment
#
# R[write to console]: Loading required package: SummarizedExperiment
#
# R[write to console]: Loading required package: MatrixGenerics
#
# R[write to console]: Loading required package: matrixStats
#
# R[write to console]:
# Attaching package: ‘MatrixGenerics’
#
#
# R[write to console]: The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# R[write to console]: Loading required package: GenomicRanges
#
# R[write to console]: Loading required package: stats4
#
# R[write to console]: Loading required package: BiocGenerics
#
# R[write to console]:
# Attaching package: ‘BiocGenerics’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# R[write to console]: Loading required package: S4Vectors
#
# R[write to console]:
# Attaching package: ‘S4Vectors’
#
#
# R[write to console]: The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# R[write to console]: Loading required package: IRanges
#
# R[write to console]: Loading required package: GenomeInfoDb
#
# R[write to console]: Loading required package: Biobase
#
# R[write to console]: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# R[write to console]:
# Attaching package: ‘Biobase’
#
#
# R[write to console]: The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# R[write to console]: The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
# Counts DataFrame:
#         GSM3899156_GSE133057  GSM3899157_GSE133057  GSM3899158_GSE133057  \
# A1CF                0.057669             -0.027535              0.447468
# A2M                 0.392288             -0.233300             -0.691535
# A2ML1              -0.448972             -0.560902             -0.670516
# A4GALT             -0.218099              0.224682             -0.247762
# AAAS               -1.148204             -0.252932              0.053839
#
#         GSM3899159_GSE133057  GSM3899160_GSE133057  GSM3899161_GSE133057  \
# A1CF                0.045675              0.014587              1.406735
# A2M                 0.293834             -1.091569             -0.816868
# A2ML1               0.532968              0.516362              1.266745
# A4GALT             -1.663294             -0.673025              0.513021
# AAAS                0.442668              0.006890              0.582186
#
#         GSM3899162_GSE133057  GSM3899163_GSE133057  GSM3899164_GSE133057  \
# A1CF               -0.390043             -0.141597             -0.939894
# A2M                 0.115628              0.384196              1.236704
# A2ML1               1.132630              0.017735              0.335514
# A4GALT              0.452215              1.025558              1.812865
# AAAS                0.456027              0.470222             -0.351307
#
#         GSM3899165_GSE133057  ...  GSM6390453_GSE209746  GSM6390454_GSE209746  \
# A1CF                0.496517  ...              0.481642             -0.494055
# A2M                 0.721205  ...              1.271784              2.545357
# A2ML1               0.367068  ...             -1.763592             -1.603974
# A4GALT             -0.386278  ...             -0.792048             -0.029957
# AAAS                0.276047  ...              0.178485              0.211358
#
#         GSM6390455_GSE209746  GSM6390456_GSE209746  GSM6390457_GSE209746  \
# A1CF                0.692194              0.141950              0.554797
# A2M                 1.705187              2.176357              2.173685
# A2ML1              -1.897987             -1.911380             -1.666886
# A4GALT             -0.723102             -0.532311             -0.472129
# AAAS                0.189983              0.189037             -0.142190
#
#         GSM6390458_GSE209746  GSM6390459_GSE209746  GSM6390460_GSE209746  \
# A1CF                0.756641              0.757147              0.263922
# A2M                 1.465240              1.147636              2.230243
# A2ML1              -1.513177             -1.772573             -1.714675
# A4GALT             -1.560049             -1.291245             -0.483064
# AAAS               -0.114270              0.214479             -0.019179
#
#         GSM6390461_GSE209746  GSM6390462_GSE209746
# A1CF                0.054849              1.130573
# A2M                 2.129601              1.589073
# A2ML1              -2.031892             -1.777141
# A4GALT             -0.167779             -0.986447
# AAAS                0.088624             -0.014329
#
# [5 rows x 450 columns]
#
# Metadata DataFrame:
#                      Response  TRG therapy Treatment Platform      batch
# GSM3899156_GSE133057      yes  1,2     CRT       pre  GPL6102  GSE133057
# GSM3899157_GSE133057  partial    3     CRT       pre  GPL6102  GSE133057
# GSM3899158_GSE133057      yes  1,2     CRT       pre  GPL6102  GSE133057
# GSM3899159_GSE133057  partial    3     CRT       pre  GPL6102  GSE133057
# GSM3899160_GSE133057      yes  1,2     CRT       pre  GPL6102  GSE133057

# %%
# X_train_diff, X_test, y_train_diff, y_test = train_test_split(counts_df.T, metadata_df, test_size=test_set_size, random_state=1)

# %%
# filtered_counts_df = X_train_diff.T
# filtered_metadata_df = y_train_diff

# if use_diff_genes:

#     from scipy.stats import ttest_ind
    
#     # Example: Two conditions
#     condition1 = filtered_counts_df.loc[:, filtered_metadata_df['Response'] == 'yes']
#     condition2 = filtered_counts_df.loc[:, filtered_metadata_df['Response'] == 'no']
    
#     # Apply t-test for each gene
#     p_values = []
#     for gene in filtered_counts_df.index:
#         t_stat, p_val = ttest_ind(condition1.loc[gene], condition2.loc[gene], equal_var=False)
#         p_values.append(p_val)
    
#     # Adjust for multiple testing using FDR
#     from statsmodels.stats.multitest import multipletests
#     adjusted_pvals = multipletests(p_values, method='fdr_bh')[1]
    
#     # Example: Genes and their p-values
#     genes = filtered_counts_df.index  # List of gene names
#     p_values_df = pd.DataFrame({'Gene': genes, 'P_value': adjusted_pvals})
    
#     # Filter genes with p-value < 0.1
#     filtered_genes = p_values_df[p_values_df['P_value'] < 0.015]
    
#     # Get a list of the gene names
#     filtered_gene_list = filtered_genes['Gene'].tolist()
    
#     # Display the filtered genes
#     print(f"Number of genes with p-value < 0.015: {len(filtered_gene_list)}")
#     print(filtered_gene_list)

# %%
if use_boruta_list:
    counts_df = counts_df.loc[selected_features]

if use_gene_list:
    counts_df = counts_df.loc[current_genes]

if use_diff_genes:
    counts_df = counts_df.loc[filtered_gene_list]
    
if use_imported_genes:
    # imported_genes = read
    # saveRDS(de_intersect_plus_bulk_genes,'ann_gene_set.rds')
    rds_path = '/tmp/work/RCproject_code/sean_ann_python/ann_gene_set.rds'
    current_genes = r.readRDS(rds_path)
    print(len(current_genes))
    counts_df = counts_df.loc[current_genes]

counts_df.shape[0]
# Out:
# 366
# 366

# %%
filtered_metadata_df = metadata_df[~metadata_df['Response'].isin(['partial'])].copy()

row_names = filtered_metadata_df.index.tolist()  # Convert index to a list

filtered_counts_df = counts_df[row_names].copy()

# %%
# adata = metadata_df[~adata.obs['Response'].isin(['partial']), :]

# %%
# generate numerical values for each batch category
# set up categories variable

# categories_technology = adata.obs['batch']
categories_technology = filtered_metadata_df['batch']

#collapse the categories to microARRAY vs sequencing

if simplifly_categories:
    category_map = {'GSE133057': 'micro', 'GSE145037': 'micro', 'GSE150082': 'micro','GSE190826':'seq','GSE209746':'seq',
                    'GSE45404_GPL1': 'micro', 'GSE45404_GPL2': 'micro', 'GSE93375': 'micro','GSE94104': 'micro'}
    categories_technology = np.vectorize(category_map.get)(categories_technology)
    
# Create a LabelEncoder instance
label_encoder = LabelEncoder()
# Fit and transform the categories to integers
numerical_categories_technology = label_encoder.fit_transform(categories_technology)
print(numerical_categories_technology.shape)

#do the same for the response variable

# categories_outcome = adata.obs['Response']
categories_outcome = filtered_metadata_df['Response']

numerical_categories_outcome = label_encoder.fit_transform(categories_outcome)
print(numerical_categories_technology.shape)
# Out:
# (410,)
# (410,)

# %%
frequency_counts = pd.Series(numerical_categories_technology).value_counts()
print('Technology frequencies')
print(frequency_counts)

print('')

print('Outcome frequencies')
frequency_counts = pd.Series(numerical_categories_outcome).value_counts()
print(frequency_counts)

unique_combinations_array = (numerical_categories_outcome + (numerical_categories_technology+1)*2)-2

np.unique(unique_combinations_array)
# Out:
# Technology frequencies
# 0    209
# 1    201
# Name: count, dtype: int64
#
# Outcome frequencies
# 0    267
# 1    143
# Name: count, dtype: int64
# array([0, 1, 2, 3])

# %%
# Assuming filtered_metadata_df is your filtered DataFrame
filtered_metadata_df.loc[:, 'numerical_categories_technology'] = numerical_categories_technology
filtered_metadata_df.loc[:, 'numerical_categories_outcome'] = numerical_categories_outcome
filtered_metadata_df.loc[:, 'combination_tech_outcome'] = unique_combinations_array

# %%
#normalizaiton
# gene_expression_data = adata.layers['scalelogcounts']

gene_expression_data = filtered_counts_df.T

#Min-max normalization

scaler = MinMaxScaler()
gene_expression_data = scaler.fit_transform(gene_expression_data)

number_genes = gene_expression_data.shape[1]
input_dim = number_genes

if PCA_reduce:
# Initialize PCA and fit it to X_train
    n_components = n_comp_PCA  # You can adjust this based on your data
    pca = PCA(n_components=n_components)
    gene_expression_data = pca.fit_transform(gene_expression_data)

# %%
# setup the test and train datasets
X_train, X_test, y_train, y_test = train_test_split(gene_expression_data, filtered_metadata_df, test_size=test_set_size, random_state=1)

y_train_outcome = y_train['numerical_categories_outcome']
y_test_outcome = y_test['numerical_categories_outcome']

y_train_tech = y_train['numerical_categories_technology']
y_test_tech = y_test['numerical_categories_technology']

y_train_comb = y_train['combination_tech_outcome']
y_test_comb = y_test['combination_tech_outcome']

# %%
train_samples = y_train.index.tolist()

# Export the row names to a file in a format readable by R
with open('train_samples.txt', 'w') as f:
    for name in train_samples:
        f.write(f"{name}\n")

# %%
# len(selected_features)

# %%
# #  boruta filtering

# import pandas as pd
# import numpy as np
# from sklearn.ensemble import RandomForestClassifier
# from boruta import BorutaPy

# boruta_df = filtered_counts_df[train_samples]
# boruta_df = boruta_df.T
# boruta_df['outcome'] = y_train_outcome.tolist()  # Ensure it’s a Python list

# # Define features (X) and target (y)
# X = boruta_df.drop(columns=["outcome"])  # Features (gene expressions)
# y = boruta_df["outcome"]  # Target (e.g., disease vs. control)
# rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5, random_state=42)

# boruta_selector = BorutaPy(
#     estimator=rf,
#     n_estimators='auto',
#     alpha=0.05,   # Significance level
#     perc=50,      # Shadow importance threshold
#     max_iter=100, # Iterations
#     random_state=42
# )

# # Fit and transform data
# boruta_selector.fit(X.values, y.values)
# selected_features = X.columns[boruta_selector.support_].tolist()

# # Fit Boruta
# boruta_selector.fit(X.values, y.values)

# # Get selected features
# selected_features = X.columns[boruta_selector.support_].tolist()
# print("Selected Features:", selected_features)
# print(len(selected_features))

# %%
# # Define the input shape
# # input_shape = (gene_expression_data.shape[1],)[0]  # Number of genes

input_shape = (X_train.shape[1],)[0]  # Number of genes

def build_outcome_classifier():
    model = keras.Sequential()
    model.add(layers.Input(shape=(input_shape,)))  # Input shape matches your data
    
    model.add(layers.Dense((512*multiplier),kernel_regularizer=tf.keras.regularizers.l2(l2_reg),kernel_initializer='he_normal'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.1))  # Leaky ReLU helps with vanishing gradients
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense((256*multiplier),kernel_regularizer=tf.keras.regularizers.l2(l2_reg),kernel_initializer='he_normal'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.1))
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense((128*multiplier),kernel_regularizer=tf.keras.regularizers.l2(l2_reg),kernel_initializer='he_normal'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.1))
    model.add(layers.Dropout(dropout_rate))
    
    model.add(layers.Dense((64*multiplier),kernel_regularizer=tf.keras.regularizers.l2(l2_reg),kernel_initializer='he_normal'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.1))
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense((32),kernel_initializer='he_normal'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.1))
    
    # Output layer for binary classification with sigmoid activation
    model.add(layers.Dense(1, activation='sigmoid'))
    
    return model

# %%
# Define the model
outcome_classifier = build_outcome_classifier()

# Assuming `model` is your TensorFlow/Keras model
plot_model(outcome_classifier, to_file="model.png", show_shapes=True, show_layer_names=True)

# %%
# Define the callback-like function to adjust learning rate based on AUC
def adjust_learning_rate_by_auc(epoch, model, X_test, y_test_outcome, lr_dict, auc_thresholds,test_auc):
    # Get model's current learning rate
    current_lr = tf.keras.backend.get_value(model.optimizer.lr)

    # Adjust learning rate based on AUC thresholds
    new_lr = current_lr
    for threshold in auc_thresholds:
        if test_auc >= threshold:
            new_lr = lr_dict[threshold]
    
    # Set new learning rate
    if new_lr != current_lr:
        tf.keras.backend.set_value(model.optimizer.lr, new_lr)
        #print(f"Epoch {epoch + 1}: Adjusting learning rate to {new_lr:.6f}")
    
    return test_auc

# %%
# # set up the optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate, clipnorm = clipnorm)

# determine the sample and batch size
num_samples = math.floor(X_train.shape[0]* (1-holdout_size))  # number of samples used in each training epoch

# batch_size = adata.shape[0]

# Calculate the number of steps per epoch
num_steps_per_epoch = num_samples // batch_size

# Compile the outcome discriminator
outcome_classifier.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
test_accuracy_list = []
train_accuracy_list = []
test_auc_list = []

num_outcomes = len(np.unique(y_test_outcome))
num_conditions = len(np.unique(unique_combinations_array))

# Define the training step for only the outcome classifier
def train_step(data, outcome_labels):
    with tf.GradientTape() as tape:
        # Forward pass through the outcome classifier
        outcome_predictions = outcome_classifier(data)

        # Compute the biological discriminator loss
        outcome_loss = tf.keras.losses.binary_crossentropy(outcome_labels, outcome_predictions)
        outcome_loss = tf.reduce_mean(outcome_loss)  # Average over the batch

    # Compute gradients for the outcome classifier
    classifier_grads = tape.gradient(outcome_loss, outcome_classifier.trainable_variables)
    
    # Calculate accuracy for the outcome classifier
    predicted_outcome_labels = tf.cast(outcome_predictions > 0.5, tf.float32)  # Threshold at 0.5
    outcome_labels_float = tf.cast(outcome_labels, tf.float32)

    # Calculate accuracy
    accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted_outcome_labels, outcome_labels_float), tf.float32))

    return outcome_loss, accuracy, classifier_grads

# Training loop
for epoch in range(num_epochs):
    total_loss = 0.0  # To accumulate losses
    total_accuracy = 0.0  # To accumulate accuracy
    accumulated_grads = [tf.zeros_like(var) for var in outcome_classifier.trainable_variables]  # Initialize gradient accumulator

    # Split train data randomly, holding out a portion for generalization
    X_train_temp, X_test_temp, y_train_temp, y_test_temp = train_test_split(X_train, y_train, test_size=holdout_size, random_state=None)
    y_train_comb_temp = y_train_temp['combination_tech_outcome']
    y_train_temp = y_train_temp['numerical_categories_outcome']
    
    # Mini-batch training loop
    for step in range(num_steps_per_epoch):
        # Balance batches if necessary
        batch_indices = []
        if balance:
            for condition in range(num_conditions):
                condition_indices = np.where(y_train_comb_temp == condition)[0]
                condition_batch_indices = np.random.choice(condition_indices, size=batch_size // num_conditions, replace=True)
                batch_indices.append(condition_batch_indices)
        else:
            all_indices = np.arange(len(X_train_temp))
            random_indices = np.random.choice(all_indices, size=batch_size, replace=True)
            batch_indices.append(random_indices)
        X_batch = X_train_temp[np.concatenate(batch_indices)]
        #y_batch = y_train_temp[np.concatenate(batch_indices)]
        y_batch = y_train_temp.iloc[np.concatenate(batch_indices)]
        y_batch = tf.expand_dims(y_batch, axis=-1)  # Adjust labels shape for binary_crossentropy
                
        # Perform the training step and collect gradients
        outcome_loss, accuracy, classifier_grads = train_step(X_batch, y_batch)
        
        # Accumulate gradients and losses
        total_loss += outcome_loss.numpy()
        total_accuracy += accuracy.numpy()
        accumulated_grads = [acc_grad + grad for acc_grad, grad in zip(accumulated_grads, classifier_grads)]

    # Average the accumulated gradients
    averaged_grads = [grad / num_steps_per_epoch for grad in accumulated_grads]

    # Apply averaged gradients to update model weights
    optimizer.apply_gradients(zip(averaged_grads, outcome_classifier.trainable_variables))

    # Calculate average loss and accuracy for the epoch
    avg_loss = total_loss / num_steps_per_epoch
    avg_accuracy = total_accuracy / num_steps_per_epoch

    if epoch % report_frequency == 0:

        #adjust the learning rate depending on test set performance
        # adjust_learning_rate_by_auc(epoch, outcome_classifier, X_test_temp, y_test_temp['numerical_categories_outcome'], lr_dict, auc_thresholds)
        
        # Evaluate on test data
        outcome_predictions = outcome_classifier(X_test)
        outcome_labels = tf.expand_dims(y_test_outcome, axis=-1)  # Reshape to match logits shape
        outcome_labels_float = tf.cast(outcome_labels, tf.float32)
    
        # Calculate AUC
        outcome_predictions_np = outcome_predictions.numpy().flatten()  # Convert predictions to numpy for roc_auc_score
        outcome_labels_np = outcome_labels_float.numpy().flatten()  # Convert labels to numpy for roc_auc_score
        test_auc = roc_auc_score(outcome_labels_np, outcome_predictions_np)

        # Calculate accuracy
        predicted_outcome_labels = tf.cast(outcome_predictions > 0.5, tf.float32)  # Threshold at 0.5
        outcome_labels_float = tf.cast(outcome_labels, tf.float32)
        test_accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted_outcome_labels, outcome_labels_float), tf.float32))
    
        # Store and print metrics
        train_accuracy_list.append(avg_accuracy)
        test_auc_list.append(test_auc)
        test_accuracy_list.append(test_accuracy)
        
        if epoch % (report_frequency*100) == 0:
            print(f'Epoch {epoch}, Average Outcome Loss: {avg_loss}, Average Accuracy: {avg_accuracy}, Test AUC: {test_auc:.4f}, Test Accuracy: {test_accuracy:.4f}')

        adjust_learning_rate_by_auc(epoch, outcome_classifier, X_test_temp, y_test_temp['numerical_categories_outcome'], lr_dict, auc_thresholds, test_auc)
    
        # Early stopping condition for AUC (if needed)
        if test_auc > auc_threshold:  # Define auc_threshold as desired
            print('Early stopping triggered based on AUC')
            break
# Out:
# Epoch 0, Average Outcome Loss: 0.6987846222790804, Average Accuracy: 0.48863636363636365, Test AUC: 0.5000, Test Accuracy: 0.3659
# Epoch 100, Average Outcome Loss: 0.621192065152255, Average Accuracy: 0.6761363636363636, Test AUC: 0.7179, Test Accuracy: 0.6829
# Epoch 200, Average Outcome Loss: 0.5078744481910359, Average Accuracy: 0.7272727272727273, Test AUC: 0.8051, Test Accuracy: 0.7073
# Epoch 300, Average Outcome Loss: 0.41663766449148004, Average Accuracy: 0.7954545454545454, Test AUC: 0.8462, Test Accuracy: 0.7805
# Epoch 400, Average Outcome Loss: 0.36267228560014203, Average Accuracy: 0.8181818181818182, Test AUC: 0.8359, Test Accuracy: 0.7805
# Epoch 500, Average Outcome Loss: 0.6093041463331743, Average Accuracy: 0.7215909090909091, Test AUC: 0.8590, Test Accuracy: 0.7805
# Epoch 600, Average Outcome Loss: 0.4248193475333127, Average Accuracy: 0.8295454545454546, Test AUC: 0.8513, Test Accuracy: 0.7805
# Epoch 700, Average Outcome Loss: 0.4486587873914025, Average Accuracy: 0.7443181818181818, Test AUC: 0.8385, Test Accuracy: 0.5610
# Epoch 800, Average Outcome Loss: 0.3286222801967101, Average Accuracy: 0.9147727272727273, Test AUC: 0.8513, Test Accuracy: 0.8049
# Epoch 900, Average Outcome Loss: 0.344753009351817, Average Accuracy: 0.8352272727272727, Test AUC: 0.8615, Test Accuracy: 0.7317
# Epoch 1000, Average Outcome Loss: 0.2186808775771748, Average Accuracy: 0.9261363636363636, Test AUC: 0.8667, Test Accuracy: 0.8049
# Epoch 1100, Average Outcome Loss: 0.19892952387983148, Average Accuracy: 0.9261363636363636, Test AUC: 0.8744, Test Accuracy: 0.8293
# Epoch 1200, Average Outcome Loss: 0.8491033207286488, Average Accuracy: 0.6761363636363636, Test AUC: 0.8256, Test Accuracy: 0.6829
# Epoch 1300, Average Outcome Loss: 0.17795667526396838, Average Accuracy: 0.9431818181818182, Test AUC: 0.8615, Test Accuracy: 0.8049
# Epoch 1400, Average Outcome Loss: 0.1285973350432786, Average Accuracy: 0.9545454545454546, Test AUC: 0.8615, Test Accuracy: 0.8293
# Epoch 1500, Average Outcome Loss: 0.14038515836000443, Average Accuracy: 0.9431818181818182, Test AUC: 0.8359, Test Accuracy: 0.6341
# Epoch 1600, Average Outcome Loss: 0.5035340487957001, Average Accuracy: 0.6931818181818182, Test AUC: 0.8128, Test Accuracy: 0.5854
# Epoch 1700, Average Outcome Loss: 0.6363325660878961, Average Accuracy: 0.6477272727272727, Test AUC: 0.8026, Test Accuracy: 0.4146
# Epoch 1800, Average Outcome Loss: 0.16830183565616608, Average Accuracy: 0.9375, Test AUC: 0.8615, Test Accuracy: 0.8293
# Epoch 1900, Average Outcome Loss: 0.20567532696507193, Average Accuracy: 0.8977272727272727, Test AUC: 0.8513, Test Accuracy: 0.7805
# Epoch 2000, Average Outcome Loss: 0.1595382968133146, Average Accuracy: 0.9602272727272727, Test AUC: 0.8590, Test Accuracy: 0.8049
# Epoch 2100, Average Outcome Loss: 0.1442091458223083, Average Accuracy: 0.9431818181818182, Test AUC: 0.8513, Test Accuracy: 0.7805
# Epoch 2200, Average Outcome Loss: 0.20346969637003812, Average Accuracy: 0.9147727272727273, Test AUC: 0.8564, Test Accuracy: 0.8049
# Epoch 2300, Average Outcome Loss: 0.4093706174330278, Average Accuracy: 0.8011363636363636, Test AUC: 0.8282, Test Accuracy: 0.6585
# Epoch 2400, Average Outcome Loss: 0.161464404145425, Average Accuracy: 0.9431818181818182, Test AUC: 0.8308, Test Accuracy: 0.8049
# Epoch 2500, Average Outcome Loss: 0.2646507051858035, Average Accuracy: 0.9545454545454546, Test AUC: 0.8538, Test Accuracy: 0.8293
# Epoch 2600, Average Outcome Loss: 0.4508326974782077, Average Accuracy: 0.7784090909090909, Test AUC: 0.8231, Test Accuracy: 0.7317
# Epoch 2700, Average Outcome Loss: 0.2852892740206285, Average Accuracy: 0.9488636363636364, Test AUC: 0.8154, Test Accuracy: 0.7805
# Epoch 2800, Average Outcome Loss: 0.2419717853719538, Average Accuracy: 0.8238636363636364, Test AUC: 0.8205, Test Accuracy: 0.7561
# Epoch 2900, Average Outcome Loss: 0.08795386586676944, Average Accuracy: 0.9602272727272727, Test AUC: 0.8256, Test Accuracy: 0.7805
# Epoch 3000, Average Outcome Loss: 0.08943425965580074, Average Accuracy: 0.9772727272727273, Test AUC: 0.8282, Test Accuracy: 0.7317
# Epoch 3100, Average Outcome Loss: 0.06012887185947462, Average Accuracy: 0.9943181818181818, Test AUC: 0.8256, Test Accuracy: 0.8293
# Epoch 3200, Average Outcome Loss: 0.05291333828460087, Average Accuracy: 0.9715909090909091, Test AUC: 0.8128, Test Accuracy: 0.8293
# Epoch 3300, Average Outcome Loss: 0.324835097247904, Average Accuracy: 0.8465909090909091, Test AUC: 0.7974, Test Accuracy: 0.7317
# Epoch 3400, Average Outcome Loss: 0.5048776919191534, Average Accuracy: 0.7897727272727273, Test AUC: 0.8128, Test Accuracy: 0.6829
# Epoch 3500, Average Outcome Loss: 0.10256056995554404, Average Accuracy: 0.9715909090909091, Test AUC: 0.8282, Test Accuracy: 0.7317
# Epoch 3600, Average Outcome Loss: 0.1717816482890736, Average Accuracy: 0.8693181818181818, Test AUC: 0.8256, Test Accuracy: 0.7073
# Epoch 3700, Average Outcome Loss: 3.193711519241333, Average Accuracy: 0.5397727272727273, Test AUC: 0.7872, Test Accuracy: 0.6585
# Epoch 3800, Average Outcome Loss: 0.054503392089496956, Average Accuracy: 1.0, Test AUC: 0.8051, Test Accuracy: 0.6585
# Epoch 3900, Average Outcome Loss: 0.05413041340017861, Average Accuracy: 1.0, Test AUC: 0.7795, Test Accuracy: 0.7317
# Epoch 4000, Average Outcome Loss: 0.044672218236056244, Average Accuracy: 1.0, Test AUC: 0.7744, Test Accuracy: 0.7317
# Epoch 4100, Average Outcome Loss: 0.08731681243939833, Average Accuracy: 0.9943181818181818, Test AUC: 0.7795, Test Accuracy: 0.7561
# Epoch 4200, Average Outcome Loss: 0.09164723618464037, Average Accuracy: 1.0, Test AUC: 0.7744, Test Accuracy: 0.7073
# Epoch 4300, Average Outcome Loss: 0.25784218311309814, Average Accuracy: 0.8863636363636364, Test AUC: 0.8077, Test Accuracy: 0.6829
# Epoch 4400, Average Outcome Loss: 0.25213057683272794, Average Accuracy: 0.8693181818181818, Test AUC: 0.8000, Test Accuracy: 0.6585
# Epoch 4500, Average Outcome Loss: 0.10959639313461428, Average Accuracy: 0.9375, Test AUC: 0.7795, Test Accuracy: 0.7317
# Epoch 4600, Average Outcome Loss: 0.7005154056982561, Average Accuracy: 0.6420454545454546, Test AUC: 0.8128, Test Accuracy: 0.5610
# Epoch 4700, Average Outcome Loss: 0.056380240923979065, Average Accuracy: 1.0, Test AUC: 0.8103, Test Accuracy: 0.6585
# Epoch 4800, Average Outcome Loss: 0.056128152392127297, Average Accuracy: 1.0, Test AUC: 0.8026, Test Accuracy: 0.7317
# Epoch 4900, Average Outcome Loss: 0.04183502177792517, Average Accuracy: 0.9886363636363636, Test AUC: 0.8000, Test Accuracy: 0.8293
# Epoch 5000, Average Outcome Loss: 0.024358425882052292, Average Accuracy: 1.0, Test AUC: 0.7923, Test Accuracy: 0.7317
# Epoch 5100, Average Outcome Loss: 0.9178185625509783, Average Accuracy: 0.7215909090909091, Test AUC: 0.7923, Test Accuracy: 0.5366
# Epoch 5200, Average Outcome Loss: 0.029510889456353405, Average Accuracy: 0.9886363636363636, Test AUC: 0.7923, Test Accuracy: 0.7805
# Epoch 5300, Average Outcome Loss: 0.003503833902703429, Average Accuracy: 1.0, Test AUC: 0.7744, Test Accuracy: 0.8049
# Epoch 5400, Average Outcome Loss: 0.7760489637201483, Average Accuracy: 0.6193181818181818, Test AUC: 0.7795, Test Accuracy: 0.6585
# Epoch 5500, Average Outcome Loss: 0.005691163157197562, Average Accuracy: 1.0, Test AUC: 0.7821, Test Accuracy: 0.7561
# Epoch 5600, Average Outcome Loss: 0.010719590397043661, Average Accuracy: 0.9886363636363636, Test AUC: 0.7667, Test Accuracy: 0.6829
# Epoch 5700, Average Outcome Loss: 0.0070837365505708886, Average Accuracy: 1.0, Test AUC: 0.7615, Test Accuracy: 0.7561
# Epoch 5800, Average Outcome Loss: 0.00021374978082762524, Average Accuracy: 1.0, Test AUC: 0.7718, Test Accuracy: 0.7561
# Epoch 5900, Average Outcome Loss: 9.138706214302643e-05, Average Accuracy: 1.0, Test AUC: 0.7718, Test Accuracy: 0.7561
# Epoch 6000, Average Outcome Loss: 0.00011779208481047218, Average Accuracy: 1.0, Test AUC: 0.7744, Test Accuracy: 0.7561
# Epoch 6100, Average Outcome Loss: 3.279650156235386e-05, Average Accuracy: 1.0, Test AUC: 0.7744, Test Accuracy: 0.7561
# Epoch 6200, Average Outcome Loss: 1.8018843134500045e-05, Average Accuracy: 1.0, Test AUC: 0.7744, Test Accuracy: 0.7561
# Epoch 6300, Average Outcome Loss: 8.47687747099454e-06, Average Accuracy: 1.0, Test AUC: 0.7718, Test Accuracy: 0.7561
# Epoch 6400, Average Outcome Loss: 7.097398131670409e-06, Average Accuracy: 1.0, Test AUC: 0.7718, Test Accuracy: 0.7561
# Epoch 6500, Average Outcome Loss: 8.99001015981908e-06, Average Accuracy: 1.0, Test AUC: 0.7718, Test Accuracy: 0.7561
# Epoch 6600, Average Outcome Loss: 5.229444912980728e-06, Average Accuracy: 1.0, Test AUC: 0.7718, Test Accuracy: 0.7561
# Epoch 6700, Average Outcome Loss: 3.4656651580049087e-06, Average Accuracy: 1.0, Test AUC: 0.7718, Test Accuracy: 0.7561
# Epoch 6800, Average Outcome Loss: 3.817702670196675e-06, Average Accuracy: 1.0, Test AUC: 0.7718, Test Accuracy: 0.7561
# Epoch 6900, Average Outcome Loss: 2.99876222827193e-06, Average Accuracy: 1.0, Test AUC: 0.7718, Test Accuracy: 0.7561
# Epoch 7000, Average Outcome Loss: 3.2039302301324244e-06, Average Accuracy: 1.0, Test AUC: 0.7718, Test Accuracy: 0.7561
# Epoch 7100, Average Outcome Loss: 3.2839220487155463e-06, Average Accuracy: 1.0, Test AUC: 0.7718, Test Accuracy: 0.7561
# Epoch 7200, Average Outcome Loss: 4.362045767824053e-06, Average Accuracy: 1.0, Test AUC: 0.7718, Test Accuracy: 0.7561
# Epoch 7300, Average Outcome Loss: 2.353215682598437e-06, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 7400, Average Outcome Loss: 1.6500582866931588e-06, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 7500, Average Outcome Loss: 1.7086400974490474e-06, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 7600, Average Outcome Loss: 1.5710695193278794e-06, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 7700, Average Outcome Loss: 1.5021450549697461e-06, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 7800, Average Outcome Loss: 1.7394583913053132e-06, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 7900, Average Outcome Loss: 2.626491803684158e-06, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 8000, Average Outcome Loss: 1.0305187433087584e-06, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 8100, Average Outcome Loss: 1.4088462462909361e-06, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 8200, Average Outcome Loss: 1.0912558175071105e-06, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 8300, Average Outcome Loss: 1.102485446773988e-06, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 8400, Average Outcome Loss: 8.561413977759003e-07, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 8500, Average Outcome Loss: 8.763213372731116e-07, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 8600, Average Outcome Loss: 5.223919649986122e-07, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 8700, Average Outcome Loss: 7.071241008495897e-07, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 8800, Average Outcome Loss: 5.421075351043989e-07, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 8900, Average Outcome Loss: 6.660602464721292e-07, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 9000, Average Outcome Loss: 3.5069149394540877e-07, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 9100, Average Outcome Loss: 6.936669872846902e-07, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 9200, Average Outcome Loss: 3.9270961165788715e-07, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 9300, Average Outcome Loss: 5.348163505593881e-07, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 9400, Average Outcome Loss: 5.187576151270563e-07, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 9500, Average Outcome Loss: 3.608050023599803e-07, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 9600, Average Outcome Loss: 3.5860009911010077e-07, Average Accuracy: 1.0, Test AUC: 0.7692, Test Accuracy: 0.7561
# Epoch 9700, Average Outcome Loss: 3.684328162152765e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 9800, Average Outcome Loss: 5.17191369650308e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 9900, Average Outcome Loss: 3.4390308621048216e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 10000, Average Outcome Loss: 4.001782294629017e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 10100, Average Outcome Loss: 4.2801084728952527e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 10200, Average Outcome Loss: 3.070262150376121e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 10300, Average Outcome Loss: 5.699923913870076e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 10400, Average Outcome Loss: 4.020752945941488e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 10500, Average Outcome Loss: 3.086211924402898e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 10600, Average Outcome Loss: 3.6658246765403585e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 10700, Average Outcome Loss: 1.6604508410657878e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 10800, Average Outcome Loss: 1.7750824616252264e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 10900, Average Outcome Loss: 3.1755257881823956e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 11000, Average Outcome Loss: 1.209018411042383e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 11100, Average Outcome Loss: 2.2309806753510616e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 11200, Average Outcome Loss: 7.518240236431045e-08, Average Accuracy: 1.0, Test AUC: 0.7641, Test Accuracy: 0.7561
# Epoch 11300, Average Outcome Loss: 2.5542987975251724e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 11400, Average Outcome Loss: 2.03666984852837e-07, Average Accuracy: 1.0, Test AUC: 0.7667, Test Accuracy: 0.7561
# Epoch 11500, Average Outcome Loss: 1.3989885032246588e-07, Average Accuracy: 1.0, Test AUC: 0.7603, Test Accuracy: 0.7561
# Epoch 11600, Average Outcome Loss: 1.4361735009319174e-07, Average Accuracy: 1.0, Test AUC: 0.7641, Test Accuracy: 0.7561
# Epoch 11700, Average Outcome Loss: 2.3420919829804501e-07, Average Accuracy: 1.0, Test AUC: 0.7641, Test Accuracy: 0.7561
# Epoch 11800, Average Outcome Loss: 1.1076811968667823e-07, Average Accuracy: 1.0, Test AUC: 0.7603, Test Accuracy: 0.7561
# Epoch 11900, Average Outcome Loss: 8.272118166210228e-08, Average Accuracy: 1.0, Test AUC: 0.7603, Test Accuracy: 0.7561
# Epoch 12000, Average Outcome Loss: 1.3980467401934635e-07, Average Accuracy: 1.0, Test AUC: 0.7603, Test Accuracy: 0.7561
# Epoch 12100, Average Outcome Loss: 1.1019548909726754e-07, Average Accuracy: 1.0, Test AUC: 0.7641, Test Accuracy: 0.7561
# Epoch 12200, Average Outcome Loss: 9.949549870859962e-08, Average Accuracy: 1.0, Test AUC: 0.7641, Test Accuracy: 0.7561
# Epoch 12300, Average Outcome Loss: 1.6709523720237485e-07, Average Accuracy: 1.0, Test AUC: 0.7641, Test Accuracy: 0.7561
# Epoch 12400, Average Outcome Loss: 1.0092734195862621e-07, Average Accuracy: 1.0, Test AUC: 0.7641, Test Accuracy: 0.7561
# Epoch 12500, Average Outcome Loss: 9.274127098602879e-08, Average Accuracy: 1.0, Test AUC: 0.7603, Test Accuracy: 0.7561
# Epoch 12600, Average Outcome Loss: 6.500759058331534e-08, Average Accuracy: 1.0, Test AUC: 0.7603, Test Accuracy: 0.7561
# Epoch 12700, Average Outcome Loss: 5.6923682656417895e-08, Average Accuracy: 1.0, Test AUC: 0.7603, Test Accuracy: 0.7561
# Epoch 12800, Average Outcome Loss: 1.1465806050058415e-07, Average Accuracy: 1.0, Test AUC: 0.7603, Test Accuracy: 0.7561
# Epoch 12900, Average Outcome Loss: 9.674946645852535e-08, Average Accuracy: 1.0, Test AUC: 0.7603, Test Accuracy: 0.7561
# Epoch 13000, Average Outcome Loss: 8.425440692602396e-08, Average Accuracy: 1.0, Test AUC: 0.7603, Test Accuracy: 0.7561
# Epoch 13100, Average Outcome Loss: 6.217694060627434e-08, Average Accuracy: 1.0, Test AUC: 0.7603, Test Accuracy: 0.7561
# Epoch 13200, Average Outcome Loss: 7.026213606890637e-08, Average Accuracy: 1.0, Test AUC: 0.7603, Test Accuracy: 0.7561
# Epoch 13300, Average Outcome Loss: 9.090864432953988e-08, Average Accuracy: 1.0, Test AUC: 0.7603, Test Accuracy: 0.7561
# Epoch 13400, Average Outcome Loss: 4.407975600690344e-08, Average Accuracy: 1.0, Test AUC: 0.7577, Test Accuracy: 0.7561
# Epoch 13500, Average Outcome Loss: 3.662594167346873e-08, Average Accuracy: 1.0, Test AUC: 0.7577, Test Accuracy: 0.7561
# Epoch 13600, Average Outcome Loss: 3.128877012027364e-08, Average Accuracy: 1.0, Test AUC: 0.7577, Test Accuracy: 0.7561
# Epoch 13700, Average Outcome Loss: 4.150482382023959e-08, Average Accuracy: 1.0, Test AUC: 0.7577, Test Accuracy: 0.7561
# Epoch 13800, Average Outcome Loss: 6.574927551900539e-08, Average Accuracy: 1.0, Test AUC: 0.7577, Test Accuracy: 0.7561
# Epoch 13900, Average Outcome Loss: 2.1606920172248776e-08, Average Accuracy: 1.0, Test AUC: 0.7577, Test Accuracy: 0.7561
# Epoch 14000, Average Outcome Loss: 3.820024699593719e-08, Average Accuracy: 1.0, Test AUC: 0.7577, Test Accuracy: 0.7561
# Epoch 14100, Average Outcome Loss: 5.3421364947842616e-08, Average Accuracy: 1.0, Test AUC: 0.7577, Test Accuracy: 0.7561
# Epoch 14200, Average Outcome Loss: 3.770756985442925e-08, Average Accuracy: 1.0, Test AUC: 0.7551, Test Accuracy: 0.7561
# Epoch 14300, Average Outcome Loss: 5.809272057339337e-08, Average Accuracy: 1.0, Test AUC: 0.7577, Test Accuracy: 0.7561
# Epoch 14400, Average Outcome Loss: 4.302016740822332e-08, Average Accuracy: 1.0, Test AUC: 0.7577, Test Accuracy: 0.7561
# Epoch 14500, Average Outcome Loss: 3.230438345108217e-08, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 14600, Average Outcome Loss: 3.082574119194315e-08, Average Accuracy: 1.0, Test AUC: 0.7551, Test Accuracy: 0.7561
# Epoch 14700, Average Outcome Loss: 1.865561709153822e-08, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 14800, Average Outcome Loss: 2.4024782082935046e-08, Average Accuracy: 1.0, Test AUC: 0.7551, Test Accuracy: 0.7561
# Epoch 14900, Average Outcome Loss: 2.0744201669551578e-08, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 15000, Average Outcome Loss: 1.952939866388771e-08, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 15100, Average Outcome Loss: 2.7053641226227786e-08, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 15200, Average Outcome Loss: 1.4739047538014916e-08, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 15300, Average Outcome Loss: 2.5281124930871937e-08, Average Accuracy: 1.0, Test AUC: 0.7551, Test Accuracy: 0.7561
# Epoch 15400, Average Outcome Loss: 1.9241787799470247e-08, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 15500, Average Outcome Loss: 9.173706254235596e-09, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 15600, Average Outcome Loss: 1.24710728410804e-08, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 15700, Average Outcome Loss: 1.0787722291218736e-08, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 15800, Average Outcome Loss: 1.667945862235146e-08, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 15900, Average Outcome Loss: 1.1923345033526545e-08, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 16000, Average Outcome Loss: 1.6516604568876533e-08, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 16100, Average Outcome Loss: 7.084741601462693e-09, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 16200, Average Outcome Loss: 1.0097784144200907e-08, Average Accuracy: 1.0, Test AUC: 0.7551, Test Accuracy: 0.7561
# Epoch 16300, Average Outcome Loss: 6.4666278089895646e-09, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 16400, Average Outcome Loss: 7.849660154203197e-09, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 16500, Average Outcome Loss: 8.305924491121401e-09, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 16600, Average Outcome Loss: 1.3745808410706413e-08, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 16700, Average Outcome Loss: 7.079456293917536e-09, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7317
# Epoch 16800, Average Outcome Loss: 8.439936931155372e-09, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7317
# Epoch 16900, Average Outcome Loss: 6.678087040427757e-09, Average Accuracy: 1.0, Test AUC: 0.7513, Test Accuracy: 0.7561
# Epoch 17000, Average Outcome Loss: 5.419777818457564e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 17100, Average Outcome Loss: 4.430896286241906e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 17200, Average Outcome Loss: 6.953060899766489e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 17300, Average Outcome Loss: 6.97077348369132e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 17400, Average Outcome Loss: 9.49056389032421e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 17500, Average Outcome Loss: 6.663618374263597e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 17600, Average Outcome Loss: 5.820177814444802e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 17700, Average Outcome Loss: 5.507603267391142e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 17800, Average Outcome Loss: 2.7054599621207324e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 17900, Average Outcome Loss: 4.2032195855170396e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 18000, Average Outcome Loss: 5.775311592595952e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 18100, Average Outcome Loss: 4.942251618057402e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 18200, Average Outcome Loss: 2.8450048428219077e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 18300, Average Outcome Loss: 2.843121725422519e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 18400, Average Outcome Loss: 2.7227759390558892e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 18500, Average Outcome Loss: 4.4486918997095745e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 18600, Average Outcome Loss: 4.926688849811582e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 18700, Average Outcome Loss: 3.2960025163720663e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 18800, Average Outcome Loss: 2.613361947300209e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 18900, Average Outcome Loss: 1.4482018892173184e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 19000, Average Outcome Loss: 1.284477342670827e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 19100, Average Outcome Loss: 2.287712433632097e-09, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 19200, Average Outcome Loss: 3.1449214495231233e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 19300, Average Outcome Loss: 3.3327176523540395e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 19400, Average Outcome Loss: 2.2492877182024207e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 19500, Average Outcome Loss: 2.4577647972368055e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 19600, Average Outcome Loss: 2.9520170752306285e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 19700, Average Outcome Loss: 9.704444167449563e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 19800, Average Outcome Loss: 1.5253281945596083e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 19900, Average Outcome Loss: 1.4599834434848478e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 20000, Average Outcome Loss: 1.5124520461797595e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 20100, Average Outcome Loss: 1.1310100179639062e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 20200, Average Outcome Loss: 8.956139248788626e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 20300, Average Outcome Loss: 1.4210219743328943e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 20400, Average Outcome Loss: 1.2014600015632724e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 20500, Average Outcome Loss: 7.686765898669416e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 20600, Average Outcome Loss: 1.0303475194252019e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 20700, Average Outcome Loss: 1.7456449543449472e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 20800, Average Outcome Loss: 1.6320413707340074e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 20900, Average Outcome Loss: 1.0555339266779288e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 21000, Average Outcome Loss: 9.249656425892493e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 21100, Average Outcome Loss: 1.7465077313664908e-09, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 21200, Average Outcome Loss: 8.80500914603808e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 21300, Average Outcome Loss: 9.112799599515901e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 21400, Average Outcome Loss: 7.759126674500294e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 21500, Average Outcome Loss: 5.821679580958976e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 21600, Average Outcome Loss: 3.2344470425857164e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 21700, Average Outcome Loss: 4.2682478511176083e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 21800, Average Outcome Loss: 4.897731361888899e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 21900, Average Outcome Loss: 5.416389768831358e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 22000, Average Outcome Loss: 5.957301053975557e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 22100, Average Outcome Loss: 5.554363086892409e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 22200, Average Outcome Loss: 7.154370788979444e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 22300, Average Outcome Loss: 2.87390307101363e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 22400, Average Outcome Loss: 6.02371202791789e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 22500, Average Outcome Loss: 7.423492452065326e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 22600, Average Outcome Loss: 4.919405243013083e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 22700, Average Outcome Loss: 4.0240857741972877e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 22800, Average Outcome Loss: 3.5389052988559817e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 22900, Average Outcome Loss: 1.276773540112827e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 23000, Average Outcome Loss: 1.8986300316028236e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 23100, Average Outcome Loss: 2.724075649395242e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 23200, Average Outcome Loss: 3.3635419386592665e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 23300, Average Outcome Loss: 3.4000177168652164e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 23400, Average Outcome Loss: 5.683336642212857e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 23500, Average Outcome Loss: 3.2650134994639433e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 23600, Average Outcome Loss: 5.046474112959463e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 23700, Average Outcome Loss: 3.3067490097137377e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 23800, Average Outcome Loss: 8.879092201858038e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 23900, Average Outcome Loss: 3.1946058298704116e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 24000, Average Outcome Loss: 2.2037604569485387e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 24100, Average Outcome Loss: 1.981001650203979e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 24200, Average Outcome Loss: 1.631265867335136e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 24300, Average Outcome Loss: 1.2376474750356e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 24400, Average Outcome Loss: 1.2726318105398866e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 24500, Average Outcome Loss: 2.1710342094159098e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 24600, Average Outcome Loss: 1.3048051370428466e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 24700, Average Outcome Loss: 2.7989000172143596e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 24800, Average Outcome Loss: 1.6113476107392828e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 24900, Average Outcome Loss: 2.6828449436769574e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 25000, Average Outcome Loss: 1.0446976380564596e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 25100, Average Outcome Loss: 1.2770575730898894e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 25200, Average Outcome Loss: 1.1507894471632111e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 25300, Average Outcome Loss: 6.114270215050707e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 25400, Average Outcome Loss: 8.11256740446636e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 25500, Average Outcome Loss: 1.3907300942175092e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 25600, Average Outcome Loss: 2.2321498405954786e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 25700, Average Outcome Loss: 7.994053970709019e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 25800, Average Outcome Loss: 2.349359746926943e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 25900, Average Outcome Loss: 1.5993834523820758e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 26000, Average Outcome Loss: 7.096200804998257e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 26100, Average Outcome Loss: 1.0956443655592159e-10, Average Accuracy: 1.0, Test AUC: 0.7487, Test Accuracy: 0.7317
# Epoch 26200, Average Outcome Loss: 1.0531866256627528e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 26300, Average Outcome Loss: 1.1033172828638966e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 26400, Average Outcome Loss: 1.2118112132440052e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 26500, Average Outcome Loss: 8.632176578651532e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 26600, Average Outcome Loss: 1.0837990637522424e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 26700, Average Outcome Loss: 4.250667620916718e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 26800, Average Outcome Loss: 5.968366964237541e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 26900, Average Outcome Loss: 5.905950980792082e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 27000, Average Outcome Loss: 1.1319322613850572e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 27100, Average Outcome Loss: 6.756099467753917e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 27200, Average Outcome Loss: 3.493047458761283e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 27300, Average Outcome Loss: 5.8202826377129225e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 27400, Average Outcome Loss: 4.388209358701202e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 27500, Average Outcome Loss: 3.6883952903431847e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 27600, Average Outcome Loss: 4.491168299789915e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 27700, Average Outcome Loss: 1.2486848108536367e-10, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 27800, Average Outcome Loss: 3.6889273063779466e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 27900, Average Outcome Loss: 5.463529928347159e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 28000, Average Outcome Loss: 3.175106634367203e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 28100, Average Outcome Loss: 4.982524395929582e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 28200, Average Outcome Loss: 6.308521930063886e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 28300, Average Outcome Loss: 4.933212412593722e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 28400, Average Outcome Loss: 1.994349197308807e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 28500, Average Outcome Loss: 3.503864435415954e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 28600, Average Outcome Loss: 4.9340733597974026e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 28700, Average Outcome Loss: 4.069078155230247e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 28800, Average Outcome Loss: 8.460763426670903e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 28900, Average Outcome Loss: 5.011529748638105e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 29000, Average Outcome Loss: 4.440812080437743e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 29100, Average Outcome Loss: 3.721219110946018e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 29200, Average Outcome Loss: 1.1552936420811375e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 29300, Average Outcome Loss: 1.1344394134625443e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 29400, Average Outcome Loss: 2.7959744880772343e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 29500, Average Outcome Loss: 1.8995019868097253e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 29600, Average Outcome Loss: 3.031407582833733e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 29700, Average Outcome Loss: 3.7470680401615406e-11, Average Accuracy: 1.0, Test AUC: 0.7462, Test Accuracy: 0.7317
# Epoch 29800, Average Outcome Loss: 2.7749433432906883e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 29900, Average Outcome Loss: 2.2212544737582052e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 30000, Average Outcome Loss: 1.1851957783248768e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 30100, Average Outcome Loss: 5.80845735944449e-11, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 30200, Average Outcome Loss: 5.732635836102763e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 30300, Average Outcome Loss: 2.2610327436092057e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 30400, Average Outcome Loss: 3.681686710549864e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 30500, Average Outcome Loss: 2.075199753987713e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 30600, Average Outcome Loss: 1.742465527137325e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 30700, Average Outcome Loss: 3.238606491767581e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 30800, Average Outcome Loss: 9.519814584678251e-12, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 30900, Average Outcome Loss: 2.7590618158213065e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 31000, Average Outcome Loss: 2.1371869748994874e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 31100, Average Outcome Loss: 3.808228763900846e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 31200, Average Outcome Loss: 2.030594799393538e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 31300, Average Outcome Loss: 1.6892551987905552e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 31400, Average Outcome Loss: 1.7840671884892448e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 31500, Average Outcome Loss: 7.899188987179415e-12, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 31600, Average Outcome Loss: 1.9114434210779074e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 31700, Average Outcome Loss: 2.3723707820073817e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 31800, Average Outcome Loss: 1.6410983027652183e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 31900, Average Outcome Loss: 1.4655960108322802e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 32000, Average Outcome Loss: 2.360989185880165e-11, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 32100, Average Outcome Loss: 2.0480042210330046e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 32200, Average Outcome Loss: 1.192831283952266e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 32300, Average Outcome Loss: 2.054378230820472e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 32400, Average Outcome Loss: 2.4362361126252635e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 32500, Average Outcome Loss: 1.1479269954300236e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 32600, Average Outcome Loss: 1.745443040023195e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 32700, Average Outcome Loss: 1.2734477268847905e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 32800, Average Outcome Loss: 1.669867511312383e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 32900, Average Outcome Loss: 7.695051390595806e-12, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 33000, Average Outcome Loss: 1.9787445715629415e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 33100, Average Outcome Loss: 1.1747329205804587e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 33200, Average Outcome Loss: 1.6731417387924356e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 33300, Average Outcome Loss: 1.2694138492100326e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 33400, Average Outcome Loss: 4.7826105055437385e-12, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 33500, Average Outcome Loss: 7.16590594864402e-12, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 33600, Average Outcome Loss: 4.618752438987174e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 33700, Average Outcome Loss: 1.1502980208979996e-11, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 33800, Average Outcome Loss: 7.776369687862137e-12, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 33900, Average Outcome Loss: 6.118227713639328e-12, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 34000, Average Outcome Loss: 1.242631622994221e-11, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 34100, Average Outcome Loss: 5.1598731206308806e-12, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 34200, Average Outcome Loss: 6.58399144567275e-12, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 34300, Average Outcome Loss: 4.399760937523478e-12, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7317
# Epoch 34400, Average Outcome Loss: 1.2026336159176461e-11, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 34500, Average Outcome Loss: 3.817483555781221e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 34600, Average Outcome Loss: 8.166068239857054e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 34700, Average Outcome Loss: 7.764021088367545e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 34800, Average Outcome Loss: 5.567292116878391e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 34900, Average Outcome Loss: 4.904464717081755e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 35000, Average Outcome Loss: 6.910899547547684e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 35100, Average Outcome Loss: 6.710997758829363e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 35200, Average Outcome Loss: 2.4483143820783584e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 35300, Average Outcome Loss: 1.1384062238693696e-11, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 35400, Average Outcome Loss: 7.0832321171391325e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 35500, Average Outcome Loss: 6.4767964064482586e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 35600, Average Outcome Loss: 9.33336679131538e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 35700, Average Outcome Loss: 3.6222214956795944e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 35800, Average Outcome Loss: 3.840099850160931e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 35900, Average Outcome Loss: 1.1845364020465512e-11, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 36000, Average Outcome Loss: 3.1626567818169472e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 36100, Average Outcome Loss: 3.267118595568478e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 36200, Average Outcome Loss: 2.754125949948086e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 36300, Average Outcome Loss: 9.090731166576257e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 36400, Average Outcome Loss: 4.5883713285894555e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 36500, Average Outcome Loss: 4.1122885533016046e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 36600, Average Outcome Loss: 6.192101824579264e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 36700, Average Outcome Loss: 4.3601081428827185e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 36800, Average Outcome Loss: 4.489485179901976e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 36900, Average Outcome Loss: 6.11015945561426e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 37000, Average Outcome Loss: 8.549726691692673e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 37100, Average Outcome Loss: 2.758034455042195e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 37200, Average Outcome Loss: 9.665684363459846e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 37300, Average Outcome Loss: 2.3441768324058094e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 37400, Average Outcome Loss: 4.97428803802509e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 37500, Average Outcome Loss: 5.117895168187871e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 37600, Average Outcome Loss: 6.358797164441964e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 37700, Average Outcome Loss: 2.009209865639173e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 37800, Average Outcome Loss: 4.013307427271767e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 37900, Average Outcome Loss: 3.757130797488751e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 38000, Average Outcome Loss: 6.381308148601396e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 38100, Average Outcome Loss: 4.390510583726132e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 38200, Average Outcome Loss: 1.750090261770552e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 38300, Average Outcome Loss: 2.0100871453629438e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 38400, Average Outcome Loss: 2.1034473515144425e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 38500, Average Outcome Loss: 4.3460263032978505e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 38600, Average Outcome Loss: 1.2459876658486667e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 38700, Average Outcome Loss: 4.625304285652007e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 38800, Average Outcome Loss: 2.9855031044396528e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 38900, Average Outcome Loss: 1.6590138136849673e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# Epoch 39000, Average Outcome Loss: 2.1606013320792474e-12, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7317
# ...
# Epoch 86900, Average Outcome Loss: 2.6661151957755713e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 87000, Average Outcome Loss: 5.365803755982771e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 87100, Average Outcome Loss: 4.552742489633516e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 87200, Average Outcome Loss: 1.4440983340973235e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 87300, Average Outcome Loss: 6.337368768857254e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 87400, Average Outcome Loss: 7.553753417012871e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 87500, Average Outcome Loss: 2.751005481494437e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 87600, Average Outcome Loss: 4.4732783878382953e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 87700, Average Outcome Loss: 4.345875577019012e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 87800, Average Outcome Loss: 4.586997313632049e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 87900, Average Outcome Loss: 3.714105767249293e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 88000, Average Outcome Loss: 2.0512593272216917e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 88100, Average Outcome Loss: 3.5276866488778023e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 88200, Average Outcome Loss: 3.798532334000765e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 88300, Average Outcome Loss: 4.5474406747874857e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 88400, Average Outcome Loss: 5.209273142291989e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 88500, Average Outcome Loss: 3.189534257318894e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 88600, Average Outcome Loss: 2.3095052740494543e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 88700, Average Outcome Loss: 4.060912188166165e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 88800, Average Outcome Loss: 5.364247488488242e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 88900, Average Outcome Loss: 3.04508327905274e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 89000, Average Outcome Loss: 2.0249676963594913e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 89100, Average Outcome Loss: 3.207961357442458e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 89200, Average Outcome Loss: 5.006720166937792e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 89300, Average Outcome Loss: 1.8996315773988432e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 89400, Average Outcome Loss: 1.553541031767553e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 89500, Average Outcome Loss: 4.667798555498344e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 89600, Average Outcome Loss: 3.746126962285797e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 89700, Average Outcome Loss: 2.774684433840622e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 89800, Average Outcome Loss: 2.3514398677758665e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 89900, Average Outcome Loss: 2.571115431685774e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 90000, Average Outcome Loss: 5.09741375874932e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 90100, Average Outcome Loss: 2.94866219675757e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 90200, Average Outcome Loss: 2.6089616060779697e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 90300, Average Outcome Loss: 2.646362952647586e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 90400, Average Outcome Loss: 8.542094995064644e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 90500, Average Outcome Loss: 5.186290883785281e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 90600, Average Outcome Loss: 5.913734735912369e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 90700, Average Outcome Loss: 2.141535874661339e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 90800, Average Outcome Loss: 2.699314810769374e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 90900, Average Outcome Loss: 3.1642536195715484e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 91000, Average Outcome Loss: 1.7149260428710556e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 91100, Average Outcome Loss: 5.394500739416578e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 91200, Average Outcome Loss: 3.363986404888102e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 91300, Average Outcome Loss: 3.706084813396227e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 91400, Average Outcome Loss: 1.7183811187540142e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 91500, Average Outcome Loss: 1.9717568910253683e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 91600, Average Outcome Loss: 4.788205829010447e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 91700, Average Outcome Loss: 2.274131822919399e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 91800, Average Outcome Loss: 4.788108577307623e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 91900, Average Outcome Loss: 3.416898767403619e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 92000, Average Outcome Loss: 3.4347303417628665e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 92100, Average Outcome Loss: 3.8714816597590984e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 92200, Average Outcome Loss: 9.429143546736007e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 92300, Average Outcome Loss: 3.934105770164924e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 92400, Average Outcome Loss: 3.0186930774264076e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 92500, Average Outcome Loss: 3.9087834814974717e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 92600, Average Outcome Loss: 2.2717387330747797e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 92700, Average Outcome Loss: 1.4986908365156666e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 92800, Average Outcome Loss: 3.4271434283827823e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 92900, Average Outcome Loss: 3.624694140167671e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 93000, Average Outcome Loss: 2.4764433700127004e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 93100, Average Outcome Loss: 3.9023671853611816e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 93200, Average Outcome Loss: 4.723020890055427e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 93300, Average Outcome Loss: 2.601126496836249e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 93400, Average Outcome Loss: 4.2619665189072044e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 93500, Average Outcome Loss: 4.2048443325711077e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 93600, Average Outcome Loss: 1.3444664286499548e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 93700, Average Outcome Loss: 3.7255690938011986e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 93800, Average Outcome Loss: 3.9786488419180264e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 93900, Average Outcome Loss: 1.956348839634505e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 94000, Average Outcome Loss: 2.3347988771761183e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 94100, Average Outcome Loss: 4.484235573702719e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 94200, Average Outcome Loss: 3.828614323337496e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 94300, Average Outcome Loss: 3.1685552871745985e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 94400, Average Outcome Loss: 4.942395887380058e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 94500, Average Outcome Loss: 2.409721384280784e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 94600, Average Outcome Loss: 4.852445226626508e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 94700, Average Outcome Loss: 5.052863361701283e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 94800, Average Outcome Loss: 2.8993687185967104e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 94900, Average Outcome Loss: 2.3045171001031936e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 95000, Average Outcome Loss: 1.9981549003703993e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 95100, Average Outcome Loss: 3.756717647774363e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 95200, Average Outcome Loss: 6.032391580417593e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 95300, Average Outcome Loss: 3.8895401349941666e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 95400, Average Outcome Loss: 4.4212828607151555e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 95500, Average Outcome Loss: 2.928389106910078e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 95600, Average Outcome Loss: 4.127566199215303e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 95700, Average Outcome Loss: 7.55902313239032e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 95800, Average Outcome Loss: 4.322090229634353e-13, Average Accuracy: 1.0, Test AUC: 0.7436, Test Accuracy: 0.7561
# Epoch 95900, Average Outcome Loss: 2.859385158206072e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 96000, Average Outcome Loss: 6.018402552542846e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 96100, Average Outcome Loss: 1.6707221227250188e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 96200, Average Outcome Loss: 7.595563859604208e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 96300, Average Outcome Loss: 2.773499111334833e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 96400, Average Outcome Loss: 2.4218996513019093e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 96500, Average Outcome Loss: 4.0748961292230493e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 96600, Average Outcome Loss: 3.869126850413485e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 96700, Average Outcome Loss: 4.169554954851277e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 96800, Average Outcome Loss: 4.726995904792578e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 96900, Average Outcome Loss: 1.6904793244608803e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 97000, Average Outcome Loss: 4.456314413252545e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 97100, Average Outcome Loss: 2.7088955141924126e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 97200, Average Outcome Loss: 9.501289989599402e-14, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 97300, Average Outcome Loss: 6.058126905451025e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 97400, Average Outcome Loss: 3.487324338474829e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 97500, Average Outcome Loss: 4.917917454131263e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 97600, Average Outcome Loss: 8.184804075789593e-14, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 97700, Average Outcome Loss: 4.667174821226795e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 97800, Average Outcome Loss: 5.23868098349621e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 97900, Average Outcome Loss: 1.9484885586911735e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 98000, Average Outcome Loss: 4.221953064413767e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 98100, Average Outcome Loss: 3.296368162814276e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 98200, Average Outcome Loss: 2.2178508881456768e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 98300, Average Outcome Loss: 3.615865529233964e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 98400, Average Outcome Loss: 3.8858445510361046e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 98500, Average Outcome Loss: 4.609489676003145e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 98600, Average Outcome Loss: 5.225087096491357e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 98700, Average Outcome Loss: 2.4703748309532053e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 98800, Average Outcome Loss: 1.4956080764672709e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 98900, Average Outcome Loss: 4.54891271640586e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 99000, Average Outcome Loss: 3.2599161636972926e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 99100, Average Outcome Loss: 3.899984482450585e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 99200, Average Outcome Loss: 2.8217014878548367e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 99300, Average Outcome Loss: 5.887157845144342e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 99400, Average Outcome Loss: 2.470279602889095e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 99500, Average Outcome Loss: 3.530027926487068e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 99600, Average Outcome Loss: 3.1567846493691295e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 99700, Average Outcome Loss: 2.6143476398698857e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 99800, Average Outcome Loss: 3.9919068942198327e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561
# Epoch 99900, Average Outcome Loss: 6.063005051357498e-13, Average Accuracy: 1.0, Test AUC: 0.7410, Test Accuracy: 0.7561

# %%
print(max(test_auc_list))
print(max(test_accuracy_list))
print(max(train_accuracy_list))
# Out:
# 0.8794871794871795
# tf.Tensor(0.85365856, shape=(), dtype=float32)
# 1.0

# %%
# After training, plot the metrics

frequency_counts = pd.Series(y_test_outcome).value_counts()
test_chance_level = frequency_counts[0]/len(y_test_outcome)

frequency_counts = pd.Series(y_train_outcome).value_counts()
train_chance_level = frequency_counts[0]/len(y_train_outcome)

fig, axs = plt.subplots(3, 1, figsize=(12, 6))

x_values = np.arange(1, len(train_accuracy_list) + 1) * report_frequency

# Plot train accuracy
axs[0].plot(x_values, train_accuracy_list, label='Training Accuracy', color='blue')
axs[0].axhline(train_chance_level, color='black',linestyle ='--')
axs[0].set_title('Training set accuracy over epochs')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Training Accuracy')
axs[0].grid()
axs[0].legend()

# Plot test accuracay
axs[1].plot(x_values, test_accuracy_list, label='Test Accuracy', color='orange')
axs[1].axhline(test_chance_level, color='black',linestyle ='--')
axs[1].set_title('Test set accuracy over epochs')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Test Accuracy')
axs[1].grid()
axs[1].legend()

# Plot test accuracay
axs[2].plot(x_values, test_auc_list, label='Test AUC', color='orange')
# axs[2].axhline(0.5, color='black',linestyle ='--')
axs[2].set_title('Test set AUC over epochs')
axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('Test AUC')
axs[2].grid()
axs[2].legend()

plt.tight_layout()
plt.show()

# %%
# After loop: Calculate ROC and AUC using continuous probabilities
fpr, tpr, thresholds = roc_curve(y_test_outcome, outcome_predictions)  # Use probabilities, not thresholded labels
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line for random guessing
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for ANN')
plt.legend(loc="lower right")
plt.show()

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train_outcome)

y_pred_prob = clf.predict_proba(X_test)[:, 1]  # Probabilities for the positive class (class 1)

fpr, tpr, thresholds = roc_curve(y_test_outcome, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line for random guessing
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for random forest')
plt.legend(loc="lower right")
plt.show()
