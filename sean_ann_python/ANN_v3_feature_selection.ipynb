# %%
import rpy2.robjects as ro
import rpy2.robjects.packages as rpackages
import anndata as ad
import scanpy as sc
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
import pandas as pd
import umap
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from keras.callbacks import EarlyStopping
import seaborn as sb
from scipy.spatial.distance import pdist
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import pearsonr
import time
from keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.decomposition import PCA
import math
import random
import rpy2.robjects as ro
from rpy2 import robjects
from rpy2.robjects import r
from rpy2.robjects import pandas2ri
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model
import pydot

# adata = sc.read('/tmp/work/RCproject_code/sce_export.h5ad')
epoch_count = 0

# Enable automatic conversion between R objects and pandas DataFrames
pandas2ri.activate()

#exclude partial
# adata = adata[~adata.obs['Response'].isin(['partial']), :]

# %%
test_set_size = 0.1
dropout_rate = 0.3 #0.1
balance = True
l2_reg = 0.2
batch_size = 16  #determines how many samples are processed per batch, each epoch will process multiple batches
# learning_rate = 0.00001
learning_rate = 0.01
num_epochs = 100000
report_frequency = 1
accuracy_threshold = 0.9  #currently not used
auc_threshold = 0.85
clipnorm = 2.0
simplifly_categories = True
holdout_size = 0.5

use_boruta_list = True
use_gene_list = False
use_diff_genes = False
use_imported_genes = False
current_gene_list = 'de_intersect_plus_bulk_genes'#'sig9_0.05'
# current_gene_list = 'Boruta_6'

PCA_reduce = False
n_comp_PCA = 16

multiplier = 3 #0.91 performance with 3

#dynamic learning rate parameters

lr_dict = {
    0.6:  0.005,
    0.7:  0.001,
    0.8:  0.0005,
    0.85: 0.0001,
    0.88: 0.00005,
    0.89: 0.00001,
    0.9:  0.000005,
    0.91: 0.000001,
    0.92: 0.0000005
}

auc_thresholds = [0.6, 0.7, 0.8, 0.85, 0.88,0.89,0.90,0.91,0.92]  # AUC values at which the learning rate should be adjusted

# %%
# Load the RDS file
rds_path = '/tmp/work/RCproject/gene_lists.rds'
rds_data = r.readRDS(rds_path)

# Extract the names of the lists and their contents
gene_lists = {}
for name, item in zip(rds_data.names, rds_data):
    # Each 'item' is a list associated with the 'name'
    inner_list = list(item)  # Convert the inner R list to a Python list
    gene_lists[name] = inner_list

# Now `python_data` is a dictionary with names as keys and lists as values
print(gene_lists.keys())
# Out:
# dict_keys(['meta', 'DE4', 'DEall', 'meta_intersect_unionDE', 'de_intersect', 'de_intersect_plus_bulk_genes', '5k', 'CV', 'CV300', 'CV300_4MA', 'Boruta_4MA', 'Boruta_6', 'CVBig', 'final300', 'final350', 'final', 'sig_4_6_0.05', 'sig_4_6_0.1', 'sig9_0.05', 'sig9_0.01', 'sig9', 'GEOMX_4_6_0.05_'])

# %%
# select a gene_list

current_genes = gene_lists[current_gene_list]
print(len(current_genes))
# Out:
# 366

# %%
#import the data

# Function to read RDS file and extract counts and metadata
def read_rds_to_matrix_and_metadata(file_path):
    # Load the RDS file in R
    ro.r(f"sce <- readRDS('{file_path}')")

    # Extract count data (assumed to be stored in assays)
    counts = ro.r('assay(sce, "scalelogcounts")')
    # Extract row (gene) and column (cell) names
    gene_names = ro.r('rownames(sce)')
    cell_names = ro.r('colnames(sce)')
    
    # Convert to a NumPy array
    counts_np = ro.conversion.rpy2py(counts)

    # Convert the counts matrix to a pandas DataFrame
    counts_df = pd.DataFrame(counts_np, index=gene_names, columns=cell_names)

    # Extract metadata from colData and convert to a pandas DataFrame directly
    metadata = ro.r('as.data.frame(colData(sce))')  # Get the colData as an R data frame
    metadata_df = pd.DataFrame(metadata)  # Convert R data frame to pandas DataFrame directly

    return counts_df, metadata_df

# Usage example
file_path = '/tmp/work/RCproject/GEO_singlecellexperiment.rds'
counts_df, metadata_df = read_rds_to_matrix_and_metadata(file_path)

# Display the results
print("Counts DataFrame:")
print(counts_df.head())  # Show the first few rows of the counts DataFrame
print("\nMetadata DataFrame:")
print(metadata_df.head())  # Show the first few rows of the metadata DataFrame
# Out:
# Counts DataFrame:
#         GSM3899156_GSE133057  GSM3899157_GSE133057  GSM3899158_GSE133057  \
# A1CF                0.057669             -0.027535              0.447468
# A2M                 0.392288             -0.233300             -0.691535
# A2ML1              -0.448972             -0.560902             -0.670516
# A4GALT             -0.218099              0.224682             -0.247762
# AAAS               -1.148204             -0.252932              0.053839
#
#         GSM3899159_GSE133057  GSM3899160_GSE133057  GSM3899161_GSE133057  \
# A1CF                0.045675              0.014587              1.406735
# A2M                 0.293834             -1.091569             -0.816868
# A2ML1               0.532968              0.516362              1.266745
# A4GALT             -1.663294             -0.673025              0.513021
# AAAS                0.442668              0.006890              0.582186
#
#         GSM3899162_GSE133057  GSM3899163_GSE133057  GSM3899164_GSE133057  \
# A1CF               -0.390043             -0.141597             -0.939894
# A2M                 0.115628              0.384196              1.236704
# A2ML1               1.132630              0.017735              0.335514
# A4GALT              0.452215              1.025558              1.812865
# AAAS                0.456027              0.470222             -0.351307
#
#         GSM3899165_GSE133057  ...  GSM6390453_GSE209746  GSM6390454_GSE209746  \
# A1CF                0.496517  ...              0.481642             -0.494055
# A2M                 0.721205  ...              1.271784              2.545357
# A2ML1               0.367068  ...             -1.763592             -1.603974
# A4GALT             -0.386278  ...             -0.792048             -0.029957
# AAAS                0.276047  ...              0.178485              0.211358
#
#         GSM6390455_GSE209746  GSM6390456_GSE209746  GSM6390457_GSE209746  \
# A1CF                0.692194              0.141950              0.554797
# A2M                 1.705187              2.176357              2.173685
# A2ML1              -1.897987             -1.911380             -1.666886
# A4GALT             -0.723102             -0.532311             -0.472129
# AAAS                0.189983              0.189037             -0.142190
#
#         GSM6390458_GSE209746  GSM6390459_GSE209746  GSM6390460_GSE209746  \
# A1CF                0.756641              0.757147              0.263922
# A2M                 1.465240              1.147636              2.230243
# A2ML1              -1.513177             -1.772573             -1.714675
# A4GALT             -1.560049             -1.291245             -0.483064
# AAAS               -0.114270              0.214479             -0.019179
#
#         GSM6390461_GSE209746  GSM6390462_GSE209746
# A1CF                0.054849              1.130573
# A2M                 2.129601              1.589073
# A2ML1              -2.031892             -1.777141
# A4GALT             -0.167779             -0.986447
# AAAS                0.088624             -0.014329
#
# [5 rows x 450 columns]
#
# Metadata DataFrame:
#                      Response  TRG therapy Treatment Platform      batch
# GSM3899156_GSE133057      yes  1,2     CRT       pre  GPL6102  GSE133057
# GSM3899157_GSE133057  partial    3     CRT       pre  GPL6102  GSE133057
# GSM3899158_GSE133057      yes  1,2     CRT       pre  GPL6102  GSE133057
# GSM3899159_GSE133057  partial    3     CRT       pre  GPL6102  GSE133057
# GSM3899160_GSE133057      yes  1,2     CRT       pre  GPL6102  GSE133057

# %%
# X_train_diff, X_test, y_train_diff, y_test = train_test_split(counts_df.T, metadata_df, test_size=test_set_size, random_state=1)

# %%
# filtered_counts_df = X_train_diff.T
# filtered_metadata_df = y_train_diff

# if use_diff_genes:

#     from scipy.stats import ttest_ind
    
#     # Example: Two conditions
#     condition1 = filtered_counts_df.loc[:, filtered_metadata_df['Response'] == 'yes']
#     condition2 = filtered_counts_df.loc[:, filtered_metadata_df['Response'] == 'no']
    
#     # Apply t-test for each gene
#     p_values = []
#     for gene in filtered_counts_df.index:
#         t_stat, p_val = ttest_ind(condition1.loc[gene], condition2.loc[gene], equal_var=False)
#         p_values.append(p_val)
    
#     # Adjust for multiple testing using FDR
#     from statsmodels.stats.multitest import multipletests
#     adjusted_pvals = multipletests(p_values, method='fdr_bh')[1]
    
#     # Example: Genes and their p-values
#     genes = filtered_counts_df.index  # List of gene names
#     p_values_df = pd.DataFrame({'Gene': genes, 'P_value': adjusted_pvals})
    
#     # Filter genes with p-value < 0.1
#     filtered_genes = p_values_df[p_values_df['P_value'] < 0.015]
    
#     # Get a list of the gene names
#     filtered_gene_list = filtered_genes['Gene'].tolist()
    
#     # Display the filtered genes
#     print(f"Number of genes with p-value < 0.015: {len(filtered_gene_list)}")
#     print(filtered_gene_list)

# %%
if use_boruta_list:
    counts_df = counts_df.loc[selected_features]

if use_gene_list:
    counts_df = counts_df.loc[current_genes]

if use_diff_genes:
    counts_df = counts_df.loc[filtered_gene_list]
    
if use_imported_genes:
    # imported_genes = read
    # saveRDS(de_intersect_plus_bulk_genes,'ann_gene_set.rds')
    rds_path = '/tmp/work/RCproject_code/sean_ann_python/ann_gene_set.rds'
    current_genes = r.readRDS(rds_path)
    print(len(current_genes))
    counts_df = counts_df.loc[current_genes]

counts_df.shape[0]
# Out:
# 975

# %%
filtered_metadata_df = metadata_df[~metadata_df['Response'].isin(['partial'])].copy()

row_names = filtered_metadata_df.index.tolist()  # Convert index to a list

filtered_counts_df = counts_df[row_names].copy()

# %%
# adata = metadata_df[~adata.obs['Response'].isin(['partial']), :]

# %%
# generate numerical values for each batch category
# set up categories variable

# categories_technology = adata.obs['batch']
categories_technology = filtered_metadata_df['batch']

#collapse the categories to microARRAY vs sequencing

if simplifly_categories:
    category_map = {'GSE133057': 'micro', 'GSE145037': 'micro', 'GSE150082': 'micro','GSE190826':'seq','GSE209746':'seq',
                    'GSE45404_GPL1': 'micro', 'GSE45404_GPL2': 'micro', 'GSE93375': 'micro','GSE94104': 'micro'}
    categories_technology = np.vectorize(category_map.get)(categories_technology)
    
# Create a LabelEncoder instance
label_encoder = LabelEncoder()
# Fit and transform the categories to integers
numerical_categories_technology = label_encoder.fit_transform(categories_technology)
print(numerical_categories_technology.shape)

#do the same for the response variable

# categories_outcome = adata.obs['Response']
categories_outcome = filtered_metadata_df['Response']

numerical_categories_outcome = label_encoder.fit_transform(categories_outcome)
print(numerical_categories_technology.shape)
# Out:
# (410,)
# (410,)

# %%
frequency_counts = pd.Series(numerical_categories_technology).value_counts()
print('Technology frequencies')
print(frequency_counts)

print('')

print('Outcome frequencies')
frequency_counts = pd.Series(numerical_categories_outcome).value_counts()
print(frequency_counts)

unique_combinations_array = (numerical_categories_outcome + (numerical_categories_technology+1)*2)-2

np.unique(unique_combinations_array)
# Out:
# Technology frequencies
# 0    209
# 1    201
# Name: count, dtype: int64
#
# Outcome frequencies
# 0    267
# 1    143
# Name: count, dtype: int64
# array([0, 1, 2, 3])

# %%
# Assuming filtered_metadata_df is your filtered DataFrame
filtered_metadata_df.loc[:, 'numerical_categories_technology'] = numerical_categories_technology
filtered_metadata_df.loc[:, 'numerical_categories_outcome'] = numerical_categories_outcome
filtered_metadata_df.loc[:, 'combination_tech_outcome'] = unique_combinations_array

# %%
#normalizaiton
# gene_expression_data = adata.layers['scalelogcounts']

gene_expression_data = filtered_counts_df.T

#Min-max normalization

scaler = MinMaxScaler()
gene_expression_data = scaler.fit_transform(gene_expression_data)

number_genes = gene_expression_data.shape[1]
input_dim = number_genes

if PCA_reduce:
# Initialize PCA and fit it to X_train
    n_components = n_comp_PCA  # You can adjust this based on your data
    pca = PCA(n_components=n_components)
    gene_expression_data = pca.fit_transform(gene_expression_data)

# %%
# setup the test and train datasets
X_train, X_test, y_train, y_test = train_test_split(gene_expression_data, filtered_metadata_df, test_size=test_set_size, random_state=1)

y_train_outcome = y_train['numerical_categories_outcome']
y_test_outcome = y_test['numerical_categories_outcome']

y_train_tech = y_train['numerical_categories_technology']
y_test_tech = y_test['numerical_categories_technology']

y_train_comb = y_train['combination_tech_outcome']
y_test_comb = y_test['combination_tech_outcome']

# %%
train_samples = y_train.index.tolist()

# Export the row names to a file in a format readable by R
with open('train_samples.txt', 'w') as f:
    for name in train_samples:
        f.write(f"{name}\n")

# %%
# len(selected_features)

# %%
# #  boruta filtering

# import pandas as pd
# import numpy as np
# from sklearn.ensemble import RandomForestClassifier
# from boruta import BorutaPy

# boruta_df = filtered_counts_df[train_samples]
# boruta_df = boruta_df.T
# boruta_df['outcome'] = y_train_outcome.tolist()  # Ensure it’s a Python list

# # Define features (X) and target (y)
# X = boruta_df.drop(columns=["outcome"])  # Features (gene expressions)
# y = boruta_df["outcome"]  # Target (e.g., disease vs. control)
# rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5, random_state=42)

# boruta_selector = BorutaPy(
#     estimator=rf,
#     n_estimators='auto',
#     alpha=0.05,   # Significance level
#     perc=50,      # Shadow importance threshold
#     max_iter=100, # Iterations
#     random_state=42
# )

# # Fit and transform data
# boruta_selector.fit(X.values, y.values)
# selected_features = X.columns[boruta_selector.support_].tolist()

# # Fit Boruta
# boruta_selector.fit(X.values, y.values)

# # Get selected features
# selected_features = X.columns[boruta_selector.support_].tolist()
# print("Selected Features:", selected_features)
# print(len(selected_features))

# %%
# # Define the input shape
# # input_shape = (gene_expression_data.shape[1],)[0]  # Number of genes

input_shape = (X_train.shape[1],)[0]  # Number of genes

def build_outcome_classifier():
    model = keras.Sequential()
    model.add(layers.Input(shape=(input_shape,)))  # Input shape matches your data
    
    model.add(layers.Dense((512*multiplier),kernel_regularizer=tf.keras.regularizers.l2(l2_reg),kernel_initializer='he_normal'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.1))  # Leaky ReLU helps with vanishing gradients
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense((256*multiplier),kernel_regularizer=tf.keras.regularizers.l2(l2_reg),kernel_initializer='he_normal'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.1))
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense((128*multiplier),kernel_regularizer=tf.keras.regularizers.l2(l2_reg),kernel_initializer='he_normal'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.1))
    model.add(layers.Dropout(dropout_rate))
    
    model.add(layers.Dense((64*multiplier),kernel_regularizer=tf.keras.regularizers.l2(l2_reg),kernel_initializer='he_normal'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.1))
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense((32),kernel_initializer='he_normal'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.1))
    
    # Output layer for binary classification with sigmoid activation
    model.add(layers.Dense(1, activation='sigmoid'))
    
    return model

# %%
# Define the model
outcome_classifier = build_outcome_classifier()

# Assuming `model` is your TensorFlow/Keras model
plot_model(outcome_classifier, to_file="model.png", show_shapes=True, show_layer_names=True)

# %%
# Define the callback-like function to adjust learning rate based on AUC
def adjust_learning_rate_by_auc(epoch, model, X_test, y_test_outcome, lr_dict, auc_thresholds,test_auc):
    # Get model's current learning rate
    current_lr = tf.keras.backend.get_value(model.optimizer.lr)

    # Adjust learning rate based on AUC thresholds
    new_lr = current_lr
    for threshold in auc_thresholds:
        if test_auc >= threshold:
            new_lr = lr_dict[threshold]
    
    # Set new learning rate
    if new_lr != current_lr:
        tf.keras.backend.set_value(model.optimizer.lr, new_lr)
        #print(f"Epoch {epoch + 1}: Adjusting learning rate to {new_lr:.6f}")
    
    return test_auc

# %%
# # set up the optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate, clipnorm = clipnorm)

# determine the sample and batch size
num_samples = math.floor(X_train.shape[0]* (1-holdout_size))  # number of samples used in each training epoch

# batch_size = adata.shape[0]

# Calculate the number of steps per epoch
num_steps_per_epoch = num_samples // batch_size

# Compile the outcome discriminator
outcome_classifier.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
test_accuracy_list = []
train_accuracy_list = []
test_auc_list = []

num_outcomes = len(np.unique(y_test_outcome))
num_conditions = len(np.unique(unique_combinations_array))

# Define the training step for only the outcome classifier
def train_step(data, outcome_labels):
    with tf.GradientTape() as tape:
        # Forward pass through the outcome classifier
        outcome_predictions = outcome_classifier(data)

        # Compute the biological discriminator loss
        outcome_loss = tf.keras.losses.binary_crossentropy(outcome_labels, outcome_predictions)
        outcome_loss = tf.reduce_mean(outcome_loss)  # Average over the batch

    # Compute gradients for the outcome classifier
    classifier_grads = tape.gradient(outcome_loss, outcome_classifier.trainable_variables)
    
    # Calculate accuracy for the outcome classifier
    predicted_outcome_labels = tf.cast(outcome_predictions > 0.5, tf.float32)  # Threshold at 0.5
    outcome_labels_float = tf.cast(outcome_labels, tf.float32)

    # Calculate accuracy
    accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted_outcome_labels, outcome_labels_float), tf.float32))

    return outcome_loss, accuracy, classifier_grads

# Training loop
for epoch in range(num_epochs):
    total_loss = 0.0  # To accumulate losses
    total_accuracy = 0.0  # To accumulate accuracy
    accumulated_grads = [tf.zeros_like(var) for var in outcome_classifier.trainable_variables]  # Initialize gradient accumulator

    # Split train data randomly, holding out a portion for generalization
    X_train_temp, X_test_temp, y_train_temp, y_test_temp = train_test_split(X_train, y_train, test_size=holdout_size, random_state=None)
    y_train_comb_temp = y_train_temp['combination_tech_outcome']
    y_train_temp = y_train_temp['numerical_categories_outcome']
    
    # Mini-batch training loop
    for step in range(num_steps_per_epoch):
        # Balance batches if necessary
        batch_indices = []
        if balance:
            for condition in range(num_conditions):
                condition_indices = np.where(y_train_comb_temp == condition)[0]
                condition_batch_indices = np.random.choice(condition_indices, size=batch_size // num_conditions, replace=True)
                batch_indices.append(condition_batch_indices)
        else:
            all_indices = np.arange(len(X_train_temp))
            random_indices = np.random.choice(all_indices, size=batch_size, replace=True)
            batch_indices.append(random_indices)
        X_batch = X_train_temp[np.concatenate(batch_indices)]
        #y_batch = y_train_temp[np.concatenate(batch_indices)]
        y_batch = y_train_temp.iloc[np.concatenate(batch_indices)]
        y_batch = tf.expand_dims(y_batch, axis=-1)  # Adjust labels shape for binary_crossentropy
                
        # Perform the training step and collect gradients
        outcome_loss, accuracy, classifier_grads = train_step(X_batch, y_batch)
        
        # Accumulate gradients and losses
        total_loss += outcome_loss.numpy()
        total_accuracy += accuracy.numpy()
        accumulated_grads = [acc_grad + grad for acc_grad, grad in zip(accumulated_grads, classifier_grads)]

    # Average the accumulated gradients
    averaged_grads = [grad / num_steps_per_epoch for grad in accumulated_grads]

    # Apply averaged gradients to update model weights
    optimizer.apply_gradients(zip(averaged_grads, outcome_classifier.trainable_variables))

    # Calculate average loss and accuracy for the epoch
    avg_loss = total_loss / num_steps_per_epoch
    avg_accuracy = total_accuracy / num_steps_per_epoch

    if epoch % report_frequency == 0:

        #adjust the learning rate depending on test set performance
        # adjust_learning_rate_by_auc(epoch, outcome_classifier, X_test_temp, y_test_temp['numerical_categories_outcome'], lr_dict, auc_thresholds)
        
        # Evaluate on test data
        outcome_predictions = outcome_classifier(X_test)
        outcome_labels = tf.expand_dims(y_test_outcome, axis=-1)  # Reshape to match logits shape
        outcome_labels_float = tf.cast(outcome_labels, tf.float32)
    
        # Calculate AUC
        outcome_predictions_np = outcome_predictions.numpy().flatten()  # Convert predictions to numpy for roc_auc_score
        outcome_labels_np = outcome_labels_float.numpy().flatten()  # Convert labels to numpy for roc_auc_score
        test_auc = roc_auc_score(outcome_labels_np, outcome_predictions_np)

        # Calculate accuracy
        predicted_outcome_labels = tf.cast(outcome_predictions > 0.5, tf.float32)  # Threshold at 0.5
        outcome_labels_float = tf.cast(outcome_labels, tf.float32)
        test_accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted_outcome_labels, outcome_labels_float), tf.float32))
    
        # Store and print metrics
        train_accuracy_list.append(avg_accuracy)
        test_auc_list.append(test_auc)
        test_accuracy_list.append(test_accuracy)
        
        if epoch % (report_frequency*100) == 0:
            print(f'Epoch {epoch}, Average Outcome Loss: {avg_loss}, Average Accuracy: {avg_accuracy}, Test AUC: {test_auc:.4f}, Test Accuracy: {test_accuracy:.4f}')

        adjust_learning_rate_by_auc(epoch, outcome_classifier, X_test_temp, y_test_temp['numerical_categories_outcome'], lr_dict, auc_thresholds, test_auc)
    
        # Early stopping condition for AUC (if needed)
        if test_auc > auc_threshold:  # Define auc_threshold as desired
            print('Early stopping triggered based on AUC')
            break
# Out:
# Epoch 0, Average Outcome Loss: 0.7282817526297136, Average Accuracy: 0.5397727272727273, Test AUC: 0.5000, Test Accuracy: 0.3659
# Epoch 100, Average Outcome Loss: 0.6879874305291609, Average Accuracy: 0.5852272727272727, Test AUC: 0.6077, Test Accuracy: 0.6341
# Epoch 200, Average Outcome Loss: 0.665725892240351, Average Accuracy: 0.5909090909090909, Test AUC: 0.5205, Test Accuracy: 0.6341
# Epoch 300, Average Outcome Loss: 0.6366334422068163, Average Accuracy: 0.6704545454545454, Test AUC: 0.5692, Test Accuracy: 0.6585
# Epoch 400, Average Outcome Loss: 0.9186619032513011, Average Accuracy: 0.5, Test AUC: 0.5641, Test Accuracy: 0.7073
# Epoch 500, Average Outcome Loss: 0.5312717773697593, Average Accuracy: 0.7215909090909091, Test AUC: 0.5692, Test Accuracy: 0.5610
# Epoch 600, Average Outcome Loss: 0.9227989315986633, Average Accuracy: 0.5, Test AUC: 0.5487, Test Accuracy: 0.3659
# Epoch 700, Average Outcome Loss: 0.5609028122641824, Average Accuracy: 0.6818181818181818, Test AUC: 0.6026, Test Accuracy: 0.7317
# Epoch 800, Average Outcome Loss: 0.534297834743153, Average Accuracy: 0.7159090909090909, Test AUC: 0.6077, Test Accuracy: 0.4390
# Epoch 900, Average Outcome Loss: 0.5499625747854059, Average Accuracy: 0.6931818181818182, Test AUC: 0.6231, Test Accuracy: 0.4634
# Epoch 1000, Average Outcome Loss: 0.33360209654677997, Average Accuracy: 0.8181818181818182, Test AUC: 0.6667, Test Accuracy: 0.5122
# Epoch 1100, Average Outcome Loss: 0.37281096794388513, Average Accuracy: 0.7954545454545454, Test AUC: 0.6487, Test Accuracy: 0.7073
# Epoch 1200, Average Outcome Loss: 0.3853424001823772, Average Accuracy: 0.7443181818181818, Test AUC: 0.6436, Test Accuracy: 0.6829
# Epoch 1300, Average Outcome Loss: 0.35861060294238006, Average Accuracy: 0.7727272727272727, Test AUC: 0.6513, Test Accuracy: 0.6829
# Epoch 1400, Average Outcome Loss: 0.8619607470252297, Average Accuracy: 0.6875, Test AUC: 0.6462, Test Accuracy: 0.3902
# Epoch 1500, Average Outcome Loss: 0.5052286413582888, Average Accuracy: 0.6988636363636364, Test AUC: 0.6538, Test Accuracy: 0.6829
# Epoch 1600, Average Outcome Loss: 0.18727446008812298, Average Accuracy: 0.9147727272727273, Test AUC: 0.6513, Test Accuracy: 0.5854
# Epoch 1700, Average Outcome Loss: 0.10294800251722336, Average Accuracy: 0.9602272727272727, Test AUC: 0.6410, Test Accuracy: 0.7317
# Epoch 1800, Average Outcome Loss: 0.16413681615482678, Average Accuracy: 0.9318181818181818, Test AUC: 0.6410, Test Accuracy: 0.7561
# Epoch 1900, Average Outcome Loss: 0.15172726186839017, Average Accuracy: 0.9659090909090909, Test AUC: 0.6615, Test Accuracy: 0.6585
# Epoch 2000, Average Outcome Loss: 0.1474831077185544, Average Accuracy: 0.9375, Test AUC: 0.6538, Test Accuracy: 0.5366
# Epoch 2100, Average Outcome Loss: 0.20303717255592346, Average Accuracy: 0.8579545454545454, Test AUC: 0.6487, Test Accuracy: 0.4390
# Epoch 2200, Average Outcome Loss: 0.06688167472285303, Average Accuracy: 0.9829545454545454, Test AUC: 0.6590, Test Accuracy: 0.7561
# Epoch 2300, Average Outcome Loss: 0.04941862093454057, Average Accuracy: 0.9943181818181818, Test AUC: 0.6462, Test Accuracy: 0.7561
# Epoch 2400, Average Outcome Loss: 0.16434708847240967, Average Accuracy: 0.9090909090909091, Test AUC: 0.6590, Test Accuracy: 0.5122
# Epoch 2500, Average Outcome Loss: 0.34410864250226453, Average Accuracy: 0.9034090909090909, Test AUC: 0.6833, Test Accuracy: 0.5366
# Epoch 2600, Average Outcome Loss: 0.35665234025906434, Average Accuracy: 0.8693181818181818, Test AUC: 0.6333, Test Accuracy: 0.7317
# Epoch 2700, Average Outcome Loss: 0.12922770597717978, Average Accuracy: 0.9772727272727273, Test AUC: 0.6333, Test Accuracy: 0.6829
# Epoch 2800, Average Outcome Loss: 0.14567196199839766, Average Accuracy: 0.9261363636363636, Test AUC: 0.6256, Test Accuracy: 0.7561
# Epoch 2900, Average Outcome Loss: 0.06059586993333968, Average Accuracy: 0.9772727272727273, Test AUC: 0.6282, Test Accuracy: 0.6585
# Epoch 3000, Average Outcome Loss: 0.49578833038156683, Average Accuracy: 0.6704545454545454, Test AUC: 0.6282, Test Accuracy: 0.6829
# Epoch 3100, Average Outcome Loss: 0.15669459443200717, Average Accuracy: 0.8920454545454546, Test AUC: 0.6282, Test Accuracy: 0.5854
# Epoch 3200, Average Outcome Loss: 0.18062053485350174, Average Accuracy: 0.9715909090909091, Test AUC: 0.6308, Test Accuracy: 0.5366
# Epoch 3300, Average Outcome Loss: 0.04812503771179102, Average Accuracy: 0.9772727272727273, Test AUC: 0.6256, Test Accuracy: 0.6829
# Epoch 3400, Average Outcome Loss: 1.8186046914620833, Average Accuracy: 0.7897727272727273, Test AUC: 0.6846, Test Accuracy: 0.6829
# Epoch 3500, Average Outcome Loss: 0.11504057185216383, Average Accuracy: 0.9659090909090909, Test AUC: 0.6256, Test Accuracy: 0.7561
# Epoch 3600, Average Outcome Loss: 0.004374259617179632, Average Accuracy: 1.0, Test AUC: 0.6513, Test Accuracy: 0.6829
# Epoch 3700, Average Outcome Loss: 0.0261025924066251, Average Accuracy: 1.0, Test AUC: 0.6205, Test Accuracy: 0.5610
# Epoch 3800, Average Outcome Loss: 0.0015849363037639043, Average Accuracy: 1.0, Test AUC: 0.6256, Test Accuracy: 0.7561
# Epoch 3900, Average Outcome Loss: 0.37600738216530194, Average Accuracy: 0.8181818181818182, Test AUC: 0.6026, Test Accuracy: 0.7073
# Epoch 4000, Average Outcome Loss: 0.164326488760046, Average Accuracy: 0.9204545454545454, Test AUC: 0.6179, Test Accuracy: 0.7073
# Epoch 4100, Average Outcome Loss: 0.11580088395964015, Average Accuracy: 0.9715909090909091, Test AUC: 0.6128, Test Accuracy: 0.4878
# Epoch 4200, Average Outcome Loss: 0.021594288674267857, Average Accuracy: 0.9943181818181818, Test AUC: 0.6026, Test Accuracy: 0.6341
# Epoch 4300, Average Outcome Loss: 0.0006847312615718693, Average Accuracy: 1.0, Test AUC: 0.6282, Test Accuracy: 0.7317
# Epoch 4400, Average Outcome Loss: 2.1122471314976625e-05, Average Accuracy: 1.0, Test AUC: 0.6282, Test Accuracy: 0.7073
# Epoch 4500, Average Outcome Loss: 1.130176544641224e-05, Average Accuracy: 1.0, Test AUC: 0.6333, Test Accuracy: 0.7073
# Epoch 4600, Average Outcome Loss: 4.782509160411957e-06, Average Accuracy: 1.0, Test AUC: 0.6372, Test Accuracy: 0.7073
# Epoch 4700, Average Outcome Loss: 8.508316093205146e-06, Average Accuracy: 1.0, Test AUC: 0.6372, Test Accuracy: 0.7073
# Epoch 4800, Average Outcome Loss: 4.657254697287334e-06, Average Accuracy: 1.0, Test AUC: 0.6372, Test Accuracy: 0.7073
# Epoch 4900, Average Outcome Loss: 3.626538087205104e-06, Average Accuracy: 1.0, Test AUC: 0.6397, Test Accuracy: 0.7073
# Epoch 5000, Average Outcome Loss: 1.7031604034979286e-06, Average Accuracy: 1.0, Test AUC: 0.6397, Test Accuracy: 0.7073
# Epoch 5100, Average Outcome Loss: 5.6811645353346565e-06, Average Accuracy: 1.0, Test AUC: 0.6397, Test Accuracy: 0.7073
# Epoch 5200, Average Outcome Loss: 2.3415174516892212e-06, Average Accuracy: 1.0, Test AUC: 0.6397, Test Accuracy: 0.7073
# Epoch 5300, Average Outcome Loss: 2.198680394113498e-06, Average Accuracy: 1.0, Test AUC: 0.6449, Test Accuracy: 0.7073
# Epoch 5400, Average Outcome Loss: 2.126125237241054e-06, Average Accuracy: 1.0, Test AUC: 0.6449, Test Accuracy: 0.7073
# Epoch 5500, Average Outcome Loss: 2.321690627385661e-06, Average Accuracy: 1.0, Test AUC: 0.6474, Test Accuracy: 0.7073
# Epoch 5600, Average Outcome Loss: 3.0925824383778244e-06, Average Accuracy: 1.0, Test AUC: 0.6474, Test Accuracy: 0.7073
# Epoch 5700, Average Outcome Loss: 7.173987048697034e-06, Average Accuracy: 1.0, Test AUC: 0.6500, Test Accuracy: 0.7073
# Epoch 5800, Average Outcome Loss: 1.7513525821496758e-06, Average Accuracy: 1.0, Test AUC: 0.6526, Test Accuracy: 0.7073
# Epoch 5900, Average Outcome Loss: 2.922114147581438e-06, Average Accuracy: 1.0, Test AUC: 0.6551, Test Accuracy: 0.7073
# Epoch 6000, Average Outcome Loss: 2.252987510008676e-06, Average Accuracy: 1.0, Test AUC: 0.6551, Test Accuracy: 0.7073
# Epoch 6100, Average Outcome Loss: 1.9591184819877196e-06, Average Accuracy: 1.0, Test AUC: 0.6551, Test Accuracy: 0.7073
# Epoch 6200, Average Outcome Loss: 6.635481026054632e-07, Average Accuracy: 1.0, Test AUC: 0.6577, Test Accuracy: 0.7073
# Epoch 6300, Average Outcome Loss: 6.984929980676084e-07, Average Accuracy: 1.0, Test AUC: 0.6603, Test Accuracy: 0.7073
# Epoch 6400, Average Outcome Loss: 6.280545740245845e-07, Average Accuracy: 1.0, Test AUC: 0.6603, Test Accuracy: 0.7073
# Epoch 6500, Average Outcome Loss: 4.888283163907335e-07, Average Accuracy: 1.0, Test AUC: 0.6603, Test Accuracy: 0.7073
# Epoch 6600, Average Outcome Loss: 7.958354666987527e-07, Average Accuracy: 1.0, Test AUC: 0.6603, Test Accuracy: 0.7073
# Epoch 6700, Average Outcome Loss: 9.591268993974273e-07, Average Accuracy: 1.0, Test AUC: 0.6603, Test Accuracy: 0.7073
# Epoch 6800, Average Outcome Loss: 3.5992792818911373e-07, Average Accuracy: 1.0, Test AUC: 0.6603, Test Accuracy: 0.7073
# Epoch 6900, Average Outcome Loss: 1.5241773985152918e-06, Average Accuracy: 1.0, Test AUC: 0.6603, Test Accuracy: 0.7073
# Epoch 7000, Average Outcome Loss: 4.866730385153708e-07, Average Accuracy: 1.0, Test AUC: 0.6603, Test Accuracy: 0.7073
# Epoch 7100, Average Outcome Loss: 4.3170821115914104e-07, Average Accuracy: 1.0, Test AUC: 0.6603, Test Accuracy: 0.7073
# Epoch 7200, Average Outcome Loss: 1.5001177932173382e-07, Average Accuracy: 1.0, Test AUC: 0.6628, Test Accuracy: 0.7073
# Epoch 7300, Average Outcome Loss: 2.471205819370487e-07, Average Accuracy: 1.0, Test AUC: 0.6628, Test Accuracy: 0.7073
# Epoch 7400, Average Outcome Loss: 1.0481161839043744e-06, Average Accuracy: 1.0, Test AUC: 0.6628, Test Accuracy: 0.7073
# Epoch 7500, Average Outcome Loss: 8.771384203207979e-07, Average Accuracy: 1.0, Test AUC: 0.6628, Test Accuracy: 0.7073
# Epoch 7600, Average Outcome Loss: 2.523632554646776e-07, Average Accuracy: 1.0, Test AUC: 0.6628, Test Accuracy: 0.7073
# Epoch 7700, Average Outcome Loss: 5.580435738556327e-07, Average Accuracy: 1.0, Test AUC: 0.6628, Test Accuracy: 0.7073
# Epoch 7800, Average Outcome Loss: 6.456173741882636e-07, Average Accuracy: 1.0, Test AUC: 0.6628, Test Accuracy: 0.7073
# Epoch 7900, Average Outcome Loss: 1.7474907993369532e-07, Average Accuracy: 1.0, Test AUC: 0.6628, Test Accuracy: 0.7073
# Epoch 8000, Average Outcome Loss: 5.24955034916533e-07, Average Accuracy: 1.0, Test AUC: 0.6654, Test Accuracy: 0.7073
# Epoch 8100, Average Outcome Loss: 6.520316506517723e-07, Average Accuracy: 1.0, Test AUC: 0.6654, Test Accuracy: 0.7073
# Epoch 8200, Average Outcome Loss: 4.00353791608531e-08, Average Accuracy: 1.0, Test AUC: 0.6654, Test Accuracy: 0.7073
# Epoch 8300, Average Outcome Loss: 1.6204754407021163e-07, Average Accuracy: 1.0, Test AUC: 0.6654, Test Accuracy: 0.7073
# Epoch 8400, Average Outcome Loss: 4.351699096425612e-07, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 8500, Average Outcome Loss: 1.2257930854192073e-07, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 8600, Average Outcome Loss: 3.6270578492163125e-07, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 8700, Average Outcome Loss: 2.909839904383851e-07, Average Accuracy: 1.0, Test AUC: 0.6654, Test Accuracy: 0.7073
# Epoch 8800, Average Outcome Loss: 1.542220389576117e-07, Average Accuracy: 1.0, Test AUC: 0.6654, Test Accuracy: 0.7073
# Epoch 8900, Average Outcome Loss: 1.9472290697047417e-07, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 9000, Average Outcome Loss: 7.32741630199934e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 9100, Average Outcome Loss: 3.8246346776495764e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 9200, Average Outcome Loss: 1.1034943415598843e-07, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 9300, Average Outcome Loss: 8.751812006415414e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 9400, Average Outcome Loss: 3.577077256622374e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 9500, Average Outcome Loss: 7.207395652015175e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 9600, Average Outcome Loss: 1.3405829206321454e-07, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 9700, Average Outcome Loss: 5.8336315457556284e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 9800, Average Outcome Loss: 5.693591483128686e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 9900, Average Outcome Loss: 3.189265708091294e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 10000, Average Outcome Loss: 8.140331067804399e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 10100, Average Outcome Loss: 8.456392283387712e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 10200, Average Outcome Loss: 3.0542420855054916e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 10300, Average Outcome Loss: 8.967133505587775e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 10400, Average Outcome Loss: 4.006950467387456e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 10500, Average Outcome Loss: 4.7937265540925526e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 10600, Average Outcome Loss: 1.1993794894622892e-07, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 10700, Average Outcome Loss: 1.736072250604146e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 10800, Average Outcome Loss: 8.740875477964882e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 10900, Average Outcome Loss: 3.470645898955899e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 11000, Average Outcome Loss: 2.766728239188655e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 11100, Average Outcome Loss: 2.7282187499043754e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 11200, Average Outcome Loss: 1.8644852126860977e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 11300, Average Outcome Loss: 4.122200099447455e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 11400, Average Outcome Loss: 3.3547270365681794e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 11500, Average Outcome Loss: 3.104223839089926e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 11600, Average Outcome Loss: 2.9608191454144617e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 11700, Average Outcome Loss: 3.3721909229657916e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 11800, Average Outcome Loss: 8.645039048263666e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 11900, Average Outcome Loss: 3.315102888161321e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 12000, Average Outcome Loss: 3.058195515008451e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 12100, Average Outcome Loss: 2.448651054647916e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 12200, Average Outcome Loss: 2.978119770866907e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 12300, Average Outcome Loss: 2.754339063392276e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 12400, Average Outcome Loss: 3.769669069322099e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 12500, Average Outcome Loss: 1.7831908626465453e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 12600, Average Outcome Loss: 7.589674838099308e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 12700, Average Outcome Loss: 1.5933089928229807e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 12800, Average Outcome Loss: 7.88603820628902e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 12900, Average Outcome Loss: 1.8319265768481943e-08, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 13000, Average Outcome Loss: 5.54458309189674e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 13100, Average Outcome Loss: 3.526995067216664e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 13200, Average Outcome Loss: 5.568873715702047e-09, Average Accuracy: 1.0, Test AUC: 0.6692, Test Accuracy: 0.7073
# Epoch 13300, Average Outcome Loss: 8.623440441522169e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 13400, Average Outcome Loss: 5.955099698715862e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 13500, Average Outcome Loss: 4.316156589962377e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 13600, Average Outcome Loss: 2.520973143622046e-09, Average Accuracy: 1.0, Test AUC: 0.6692, Test Accuracy: 0.7073
# Epoch 13700, Average Outcome Loss: 7.380707282718516e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 13800, Average Outcome Loss: 6.088458200987306e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 13900, Average Outcome Loss: 6.788274519518225e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 14000, Average Outcome Loss: 4.330963879195515e-09, Average Accuracy: 1.0, Test AUC: 0.6679, Test Accuracy: 0.7073
# Epoch 14100, Average Outcome Loss: 3.0172875394534667e-09, Average Accuracy: 1.0, Test AUC: 0.6705, Test Accuracy: 0.7073
# Epoch 14200, Average Outcome Loss: 8.038253635943672e-10, Average Accuracy: 1.0, Test AUC: 0.6705, Test Accuracy: 0.7073
# Epoch 14300, Average Outcome Loss: 1.2743358536964672e-09, Average Accuracy: 1.0, Test AUC: 0.6705, Test Accuracy: 0.7073
# Epoch 14400, Average Outcome Loss: 1.0911656269197887e-09, Average Accuracy: 1.0, Test AUC: 0.6667, Test Accuracy: 0.7073
# Epoch 14500, Average Outcome Loss: 2.196040201642284e-09, Average Accuracy: 1.0, Test AUC: 0.6744, Test Accuracy: 0.7073
# Epoch 14600, Average Outcome Loss: 2.335896443444502e-09, Average Accuracy: 1.0, Test AUC: 0.6667, Test Accuracy: 0.7073
# Epoch 14700, Average Outcome Loss: 2.7234903139535097e-09, Average Accuracy: 1.0, Test AUC: 0.6667, Test Accuracy: 0.7073
# Epoch 14800, Average Outcome Loss: 4.494778853407363e-09, Average Accuracy: 1.0, Test AUC: 0.6667, Test Accuracy: 0.7073
# Epoch 14900, Average Outcome Loss: 6.178201016438966e-09, Average Accuracy: 1.0, Test AUC: 0.6731, Test Accuracy: 0.7073
# Epoch 15000, Average Outcome Loss: 3.980048187488741e-09, Average Accuracy: 1.0, Test AUC: 0.6667, Test Accuracy: 0.7073
# Epoch 15100, Average Outcome Loss: 4.350957119844426e-09, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 15200, Average Outcome Loss: 2.801833506366707e-10, Average Accuracy: 1.0, Test AUC: 0.6667, Test Accuracy: 0.7073
# Epoch 15300, Average Outcome Loss: 5.065968465272428e-09, Average Accuracy: 1.0, Test AUC: 0.6705, Test Accuracy: 0.7073
# Epoch 15400, Average Outcome Loss: 6.497644990868043e-09, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 15500, Average Outcome Loss: 7.329705064171552e-10, Average Accuracy: 1.0, Test AUC: 0.6731, Test Accuracy: 0.7073
# Epoch 15600, Average Outcome Loss: 1.2858190290603413e-09, Average Accuracy: 1.0, Test AUC: 0.6692, Test Accuracy: 0.7073
# Epoch 15700, Average Outcome Loss: 2.997084616469929e-09, Average Accuracy: 1.0, Test AUC: 0.6667, Test Accuracy: 0.7073
# Epoch 15800, Average Outcome Loss: 9.711218079688777e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 15900, Average Outcome Loss: 1.93838670430425e-09, Average Accuracy: 1.0, Test AUC: 0.6667, Test Accuracy: 0.7073
# Epoch 16000, Average Outcome Loss: 3.7018675312638916e-09, Average Accuracy: 1.0, Test AUC: 0.6667, Test Accuracy: 0.7073
# Epoch 16100, Average Outcome Loss: 3.650733266384015e-10, Average Accuracy: 1.0, Test AUC: 0.6692, Test Accuracy: 0.7073
# Epoch 16200, Average Outcome Loss: 8.428914559692847e-10, Average Accuracy: 1.0, Test AUC: 0.6667, Test Accuracy: 0.7073
# Epoch 16300, Average Outcome Loss: 2.2559015350198663e-09, Average Accuracy: 1.0, Test AUC: 0.6667, Test Accuracy: 0.7073
# Epoch 16400, Average Outcome Loss: 2.2394118485491066e-09, Average Accuracy: 1.0, Test AUC: 0.6667, Test Accuracy: 0.7073
# Epoch 16500, Average Outcome Loss: 1.2695062526465765e-09, Average Accuracy: 1.0, Test AUC: 0.6667, Test Accuracy: 0.7073
# Epoch 16600, Average Outcome Loss: 1.3017672791987794e-09, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 16700, Average Outcome Loss: 4.413384220896089e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 16800, Average Outcome Loss: 7.532344144718524e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 16900, Average Outcome Loss: 1.1320580344354912e-09, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 17000, Average Outcome Loss: 4.2908852678377995e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 17100, Average Outcome Loss: 1.444070740826773e-09, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 17200, Average Outcome Loss: 2.1405508434266504e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 17300, Average Outcome Loss: 4.0887945925198834e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 17400, Average Outcome Loss: 6.256092597881321e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 17500, Average Outcome Loss: 4.472508290172892e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 17600, Average Outcome Loss: 3.3443425167773886e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 17700, Average Outcome Loss: 5.930629283911546e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 17800, Average Outcome Loss: 4.05842245305735e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 17900, Average Outcome Loss: 6.898334442803395e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 18000, Average Outcome Loss: 6.153900411665585e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 18100, Average Outcome Loss: 3.764236452528809e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 18200, Average Outcome Loss: 2.3238998373606562e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 18300, Average Outcome Loss: 3.055431315542687e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 18400, Average Outcome Loss: 2.6315982271908937e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 18500, Average Outcome Loss: 4.3824729364738186e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 18600, Average Outcome Loss: 9.334548372584446e-11, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 18700, Average Outcome Loss: 1.9502677680664898e-10, Average Accuracy: 1.0, Test AUC: 0.6641, Test Accuracy: 0.7073
# Epoch 18800, Average Outcome Loss: 2.8944913586382496e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 18900, Average Outcome Loss: 1.1431409196763472e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 19000, Average Outcome Loss: 5.048918239379025e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 19100, Average Outcome Loss: 3.25775890855709e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 19200, Average Outcome Loss: 3.0313563244162414e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 19300, Average Outcome Loss: 2.2639965375921683e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 19400, Average Outcome Loss: 3.8736244388871586e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 19500, Average Outcome Loss: 1.1642356424232611e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 19600, Average Outcome Loss: 1.5796381161763508e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 19700, Average Outcome Loss: 4.6432666660464495e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 19800, Average Outcome Loss: 2.2583885692726492e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 19900, Average Outcome Loss: 1.1360324944504574e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 20000, Average Outcome Loss: 9.180403449551276e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 20100, Average Outcome Loss: 2.435900915950554e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 20200, Average Outcome Loss: 1.4676872661104447e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 20300, Average Outcome Loss: 2.556221560181336e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 20400, Average Outcome Loss: 1.7293644956718377e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 20500, Average Outcome Loss: 1.0445559535309209e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 20600, Average Outcome Loss: 2.600688840418116e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 20700, Average Outcome Loss: 1.9682820843322954e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 20800, Average Outcome Loss: 4.1163173012216294e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 20900, Average Outcome Loss: 1.8490584130913888e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 21000, Average Outcome Loss: 4.099057096355885e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 21100, Average Outcome Loss: 1.9732971431905454e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 21200, Average Outcome Loss: 1.19364870477553e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 21300, Average Outcome Loss: 9.402352736349495e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 21400, Average Outcome Loss: 1.1643877386277357e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 21500, Average Outcome Loss: 1.028181043698481e-10, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 21600, Average Outcome Loss: 9.152248072413267e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 21700, Average Outcome Loss: 6.295186183711194e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 21800, Average Outcome Loss: 8.953080385651093e-12, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 21900, Average Outcome Loss: 5.906340083210297e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 22000, Average Outcome Loss: 6.29205144031909e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 22100, Average Outcome Loss: 8.509475445543394e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 22200, Average Outcome Loss: 1.1383963051664968e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 22300, Average Outcome Loss: 6.842597988379102e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 22400, Average Outcome Loss: 8.347775048530971e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 22500, Average Outcome Loss: 4.364120996398894e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 22600, Average Outcome Loss: 2.99117117103427e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 22700, Average Outcome Loss: 6.959165365973004e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 22800, Average Outcome Loss: 7.909626575867337e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 22900, Average Outcome Loss: 5.65715282778434e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 23000, Average Outcome Loss: 2.1466421926398778e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 23100, Average Outcome Loss: 3.374267646386547e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 23200, Average Outcome Loss: 5.044426536047147e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 23300, Average Outcome Loss: 4.219720623269141e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 23400, Average Outcome Loss: 3.0745039721184625e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 23500, Average Outcome Loss: 8.103389017976343e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 23600, Average Outcome Loss: 9.295578132986002e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 23700, Average Outcome Loss: 6.963512906293176e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 23800, Average Outcome Loss: 2.9056533324653223e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 23900, Average Outcome Loss: 7.564370180582203e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 24000, Average Outcome Loss: 1.0888188002036378e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 24100, Average Outcome Loss: 2.7685025914959404e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 24200, Average Outcome Loss: 2.511144677613819e-11, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 24300, Average Outcome Loss: 8.218948839407079e-12, Average Accuracy: 1.0, Test AUC: 0.6615, Test Accuracy: 0.7073
# Epoch 24400, Average Outcome Loss: 6.900894924401733e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 24500, Average Outcome Loss: 1.6427753553099542e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 24600, Average Outcome Loss: 3.216907238686258e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 24700, Average Outcome Loss: 2.1111540723455074e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 24800, Average Outcome Loss: 4.2870429290642586e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 24900, Average Outcome Loss: 2.5189466161597915e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 25000, Average Outcome Loss: 1.2892210048987658e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 25100, Average Outcome Loss: 1.082097773522967e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 25200, Average Outcome Loss: 3.417927856776768e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 25300, Average Outcome Loss: 4.282000528499931e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 25400, Average Outcome Loss: 1.5421260556119446e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 25500, Average Outcome Loss: 1.1600544999822286e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 25600, Average Outcome Loss: 2.1429644646599645e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 25700, Average Outcome Loss: 1.649137311972588e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 25800, Average Outcome Loss: 2.100931746824332e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 25900, Average Outcome Loss: 6.26049402699202e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 26000, Average Outcome Loss: 2.4909954403694532e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 26100, Average Outcome Loss: 1.3507088346511963e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 26200, Average Outcome Loss: 1.538553698407465e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 26300, Average Outcome Loss: 7.150286264377219e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 26400, Average Outcome Loss: 2.10099854969478e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 26500, Average Outcome Loss: 2.743640894396234e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 26600, Average Outcome Loss: 2.4271981572984343e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 26700, Average Outcome Loss: 2.4469180053279394e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 26800, Average Outcome Loss: 7.9935316351212e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 26900, Average Outcome Loss: 7.121386692839292e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 27000, Average Outcome Loss: 8.571248789835155e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 27100, Average Outcome Loss: 5.897249263848802e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 27200, Average Outcome Loss: 2.137211408873902e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 27300, Average Outcome Loss: 6.639145845107343e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 27400, Average Outcome Loss: 5.264789124075143e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 27500, Average Outcome Loss: 6.755826283303792e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 27600, Average Outcome Loss: 9.964309054515813e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 27700, Average Outcome Loss: 4.736881915851245e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 27800, Average Outcome Loss: 5.1526042818290235e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 27900, Average Outcome Loss: 1.073482731335897e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 28000, Average Outcome Loss: 2.388923240655143e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 28100, Average Outcome Loss: 2.6785468000328193e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 28200, Average Outcome Loss: 3.3751718005252584e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 28300, Average Outcome Loss: 5.67885574916515e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 28400, Average Outcome Loss: 4.644077137232352e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 28500, Average Outcome Loss: 4.508228079319265e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 28600, Average Outcome Loss: 3.1396293825758876e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 28700, Average Outcome Loss: 1.0247967065185035e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 28800, Average Outcome Loss: 5.2992546972632406e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 28900, Average Outcome Loss: 7.128132590132161e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 29000, Average Outcome Loss: 3.52730608259582e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 29100, Average Outcome Loss: 1.1536727480056116e-11, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 29200, Average Outcome Loss: 3.271510981940239e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 29300, Average Outcome Loss: 2.827062738540758e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 29400, Average Outcome Loss: 4.034399174770792e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 29500, Average Outcome Loss: 5.279782404684562e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 29600, Average Outcome Loss: 6.87162446738298e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 29700, Average Outcome Loss: 3.9564338158445514e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 29800, Average Outcome Loss: 4.384039966612546e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 29900, Average Outcome Loss: 2.725680264865095e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 30000, Average Outcome Loss: 4.66024801124892e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 30100, Average Outcome Loss: 3.0128925514498852e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 30200, Average Outcome Loss: 3.006615453936039e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 30300, Average Outcome Loss: 2.5899458162079925e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 30400, Average Outcome Loss: 4.1676886230920994e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 30500, Average Outcome Loss: 3.539676835678874e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 30600, Average Outcome Loss: 7.031580886424177e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 30700, Average Outcome Loss: 3.874505279389594e-13, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 30800, Average Outcome Loss: 5.933993906698448e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 30900, Average Outcome Loss: 2.6145331071280524e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 31000, Average Outcome Loss: 3.110198848165464e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 31100, Average Outcome Loss: 1.9321360326068398e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 31200, Average Outcome Loss: 4.9410472924204195e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 31300, Average Outcome Loss: 4.000033744593982e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 31400, Average Outcome Loss: 1.1044574931218227e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 31500, Average Outcome Loss: 2.9202123572089815e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 31600, Average Outcome Loss: 6.179503958380883e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 31700, Average Outcome Loss: 7.05984285960928e-13, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 31800, Average Outcome Loss: 8.872866036781824e-13, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 31900, Average Outcome Loss: 1.931638463892784e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 32000, Average Outcome Loss: 2.113270207796562e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 32100, Average Outcome Loss: 7.525984258068888e-13, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 32200, Average Outcome Loss: 7.715641122919821e-13, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 32300, Average Outcome Loss: 3.6294447487082903e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 32400, Average Outcome Loss: 9.300537308466703e-13, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 32500, Average Outcome Loss: 1.5259747429126589e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 32600, Average Outcome Loss: 2.7251511777085583e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 32700, Average Outcome Loss: 1.6418729358639172e-12, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 32800, Average Outcome Loss: 1.7661513601631492e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 32900, Average Outcome Loss: 1.1719636454776663e-12, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 33000, Average Outcome Loss: 2.2581687040619366e-12, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 33100, Average Outcome Loss: 1.9138370352821234e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 33200, Average Outcome Loss: 1.5303499724010644e-12, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 33300, Average Outcome Loss: 6.635456199774277e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 33400, Average Outcome Loss: 1.1218512416948504e-12, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 33500, Average Outcome Loss: 6.236907970058212e-13, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 33600, Average Outcome Loss: 1.5070810656245254e-12, Average Accuracy: 1.0, Test AUC: 0.6590, Test Accuracy: 0.7073
# Epoch 33700, Average Outcome Loss: 3.1026504040957303e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 33800, Average Outcome Loss: 3.0005674532694307e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 33900, Average Outcome Loss: 4.0555233532699816e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 34000, Average Outcome Loss: 9.58441966868113e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 34100, Average Outcome Loss: 4.123851337846153e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 34200, Average Outcome Loss: 1.9149951151388725e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 34300, Average Outcome Loss: 8.904023117834314e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 34400, Average Outcome Loss: 8.533681389078487e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 34500, Average Outcome Loss: 7.674566838413558e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 34600, Average Outcome Loss: 1.1546077235479912e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 34700, Average Outcome Loss: 1.7415655224436151e-12, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 34800, Average Outcome Loss: 1.2081026850270075e-12, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 34900, Average Outcome Loss: 1.0589907912320456e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 35000, Average Outcome Loss: 8.795848644904397e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 35100, Average Outcome Loss: 1.3729773435862078e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 35200, Average Outcome Loss: 2.932942079442887e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 35300, Average Outcome Loss: 7.114225499219537e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 35400, Average Outcome Loss: 8.610405112900534e-14, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 35500, Average Outcome Loss: 2.1801123978220952e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 35600, Average Outcome Loss: 8.18630545246902e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 35700, Average Outcome Loss: 2.309513667760947e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 35800, Average Outcome Loss: 5.848112626312613e-14, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 35900, Average Outcome Loss: 4.782557934765565e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 36000, Average Outcome Loss: 5.482547627398598e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 36100, Average Outcome Loss: 1.0872676505206772e-12, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 36200, Average Outcome Loss: 6.573753766709168e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 36300, Average Outcome Loss: 4.0125049698183773e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 36400, Average Outcome Loss: 6.173849295559037e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 36500, Average Outcome Loss: 1.7928145332493211e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 36600, Average Outcome Loss: 6.819269850575238e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 36700, Average Outcome Loss: 9.411475985676426e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 36800, Average Outcome Loss: 3.338660294561997e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 36900, Average Outcome Loss: 1.7148187037758598e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 37000, Average Outcome Loss: 9.568462377593227e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 37100, Average Outcome Loss: 6.040475065322946e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 37200, Average Outcome Loss: 3.469483360894822e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 37300, Average Outcome Loss: 7.890866463724121e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 37400, Average Outcome Loss: 6.549016885997477e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 37500, Average Outcome Loss: 8.565629913693312e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 37600, Average Outcome Loss: 1.1561155931199744e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 37700, Average Outcome Loss: 3.572520325771834e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 37800, Average Outcome Loss: 2.3269048739260816e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 37900, Average Outcome Loss: 3.8208465722733226e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 38000, Average Outcome Loss: 7.228069857117255e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 38100, Average Outcome Loss: 7.015175553533804e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 38200, Average Outcome Loss: 7.660378891570862e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 38300, Average Outcome Loss: 8.452702636057497e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 38400, Average Outcome Loss: 1.1291906210925429e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 38500, Average Outcome Loss: 3.7502563164363273e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 38600, Average Outcome Loss: 7.205771339006169e-14, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 38700, Average Outcome Loss: 5.137208667961946e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 38800, Average Outcome Loss: 7.970544395945859e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 38900, Average Outcome Loss: 3.0981286226608566e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 39000, Average Outcome Loss: 1.633959971280837e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 39100, Average Outcome Loss: 1.0380467751343663e-12, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 39200, Average Outcome Loss: 4.446232597341357e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 39300, Average Outcome Loss: 6.302834665390516e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 39400, Average Outcome Loss: 4.9842884020737737e-14, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 39500, Average Outcome Loss: 5.412465980195082e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 39600, Average Outcome Loss: 5.478433782421332e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 39700, Average Outcome Loss: 4.714228902997538e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 39800, Average Outcome Loss: 3.911331350442573e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 39900, Average Outcome Loss: 4.980248727151519e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 40000, Average Outcome Loss: 6.790816768353519e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 40100, Average Outcome Loss: 2.803491186584153e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 40200, Average Outcome Loss: 2.2003256936887654e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 40300, Average Outcome Loss: 2.3631489646191237e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 40400, Average Outcome Loss: 8.560937148792027e-14, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 40500, Average Outcome Loss: 4.4327625196023444e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 40600, Average Outcome Loss: 1.9070806192261028e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 40700, Average Outcome Loss: 3.390334934033489e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 40800, Average Outcome Loss: 3.4253704159374697e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 40900, Average Outcome Loss: 2.717176819407431e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 41000, Average Outcome Loss: 1.1153902532511524e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 41100, Average Outcome Loss: 3.7897029695927495e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 41200, Average Outcome Loss: 3.45451072409539e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 41300, Average Outcome Loss: 2.3579506905030437e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 41400, Average Outcome Loss: 1.1046009945561342e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 41500, Average Outcome Loss: 2.65127013792361e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 41600, Average Outcome Loss: 3.46903479034166e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 41700, Average Outcome Loss: 6.096292596649048e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 41800, Average Outcome Loss: 1.8627864508959095e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 41900, Average Outcome Loss: 1.6870538188831255e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 42000, Average Outcome Loss: 3.99217705152821e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 42100, Average Outcome Loss: 6.166524791830967e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 42200, Average Outcome Loss: 6.365319716087302e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 42300, Average Outcome Loss: 2.4032895196789236e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073
# Epoch 42400, Average Outcome Loss: 2.1705941555711245e-13, Average Accuracy: 1.0, Test AUC: 0.6564, Test Accuracy: 0.7073

# %%
print(max(test_auc_list))
print(max(test_accuracy_list))
print(max(train_accuracy_list))
# Out:
# 0.7051282051282052
# tf.Tensor(0.7804878, shape=(), dtype=float32)
# 1.0

# %%
# After training, plot the metrics

frequency_counts = pd.Series(y_test_outcome).value_counts()
test_chance_level = frequency_counts[0]/len(y_test_outcome)

frequency_counts = pd.Series(y_train_outcome).value_counts()
train_chance_level = frequency_counts[0]/len(y_train_outcome)

fig, axs = plt.subplots(3, 1, figsize=(12, 6))

x_values = np.arange(1, len(train_accuracy_list) + 1) * report_frequency

# Plot train accuracy
axs[0].plot(x_values, train_accuracy_list, label='Training Accuracy', color='blue')
axs[0].axhline(train_chance_level, color='black',linestyle ='--')
axs[0].set_title('Training set accuracy over epochs')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Training Accuracy')
axs[0].grid()
axs[0].legend()

# Plot test accuracay
axs[1].plot(x_values, test_accuracy_list, label='Test Accuracy', color='orange')
axs[1].axhline(test_chance_level, color='black',linestyle ='--')
axs[1].set_title('Test set accuracy over epochs')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Test Accuracy')
axs[1].grid()
axs[1].legend()

# Plot test accuracay
axs[2].plot(x_values, test_auc_list, label='Test AUC', color='orange')
# axs[2].axhline(0.5, color='black',linestyle ='--')
axs[2].set_title('Test set AUC over epochs')
axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('Test AUC')
axs[2].grid()
axs[2].legend()

plt.tight_layout()
plt.show()

# %%
# After loop: Calculate ROC and AUC using continuous probabilities
fpr, tpr, thresholds = roc_curve(y_test_outcome, outcome_predictions)  # Use probabilities, not thresholded labels
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line for random guessing
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for ANN')
plt.legend(loc="lower right")
plt.show()

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train_outcome)

y_pred_prob = clf.predict_proba(X_test)[:, 1]  # Probabilities for the positive class (class 1)

fpr, tpr, thresholds = roc_curve(y_test_outcome, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line for random guessing
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for random forest')
plt.legend(loc="lower right")
plt.show()
