# %%
import rpy2.robjects as ro
import rpy2.robjects.packages as rpackages
import anndata as ad
import scanpy as sc
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
import pandas as pd
import umap
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from keras.callbacks import EarlyStopping
import seaborn as sb
from scipy.spatial.distance import pdist
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import pearsonr
import time
from keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.decomposition import PCA
import math
import random
import rpy2.robjects as ro
from rpy2 import robjects
from rpy2.robjects import r
from rpy2.robjects import pandas2ri
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from sklearn.metrics import roc_curve, auc
from sklearn.ensemble import RandomForestClassifier
import os

os.environ['PYTHONHASHSEED'] = '0'
random.seed(0)
np.random.seed(0)
tf.random.set_seed(0)

rds_path = '/tmp/work/RCproject/gene_lists.rds'
rds_data = r.readRDS(rds_path)

# Extract the names of the lists and their contents
gene_lists = {}
for name, item in zip(rds_data.names, rds_data):
    # Each 'item' is a list associated with the 'name'
    inner_list = list(item)  # Convert the inner R list to a Python list
    gene_lists[name] = inner_list

# Now `python_data` is a dictionary with names as keys and lists as values
gene_list_names = gene_lists.keys()

current_list = [256,16,1,8,32,64,128]

def test_params(current_value):

    print("let's go")
    
    pandas2ri.activate()
    test_set_size = 0.1
    dropout_rate = 0.2 # #0.1
    balance = False
    l2_reg = 0.1
    l1_reg = 0.1
    batch_size = current_value  #determines how many samples are processed per batch, each epoch will process multiple batches
    learning_rate = 0.00001
    num_epochs = 5000
    report_frequency = 5
    accuracy_threshold = 0.90
    clipnorm = 2.0
    simplifly_categories = True
    holdout_size = 0.5
    use_gene_list = True
    current_gene_list = 'de_intersect_plus_bulk_genes'#'CV300' #'sig_4_6_0.1' #'de_intersect_plus_bulk_genes'
    PCA_reduce = False
    n_comp_PCA = 16
    weight_intializaiton_style = 'he_normal' # options: ['he_normal','glorot_uniform','lecun_normal','lecun_uniform','glorot_normal','glorot_normal','he_uniform']

    # Load the RDS file
    rds_path = '/tmp/work/RCproject/gene_lists.rds'
    rds_data = r.readRDS(rds_path)
    
    # Extract the names of the lists and their contents
    gene_lists = {}
    for name, item in zip(rds_data.names, rds_data):
        # Each 'item' is a list associated with the 'name'
        inner_list = list(item)  # Convert the inner R list to a Python list
        gene_lists[name] = inner_list

    current_genes = gene_lists[current_gene_list]

    # Function to read RDS file and extract counts and metadata
    def read_rds_to_matrix_and_metadata(file_path):
        # Load the RDS file in R
        ro.r(f"sce <- readRDS('{file_path}')")
    
        # Extract count data (assumed to be stored in assays)
        counts = ro.r('assay(sce, "scalelogcounts")')
        # Extract row (gene) and column (cell) names
        gene_names = ro.r('rownames(sce)')
        cell_names = ro.r('colnames(sce)')
        
        # Convert to a NumPy array
        counts_np = ro.conversion.rpy2py(counts)
    
        # Convert the counts matrix to a pandas DataFrame
        counts_df = pd.DataFrame(counts_np, index=gene_names, columns=cell_names)
    
        # Extract metadata from colData and convert to a pandas DataFrame directly
        metadata = ro.r('as.data.frame(colData(sce))')  # Get the colData as an R data frame
        metadata_df = pd.DataFrame(metadata)  # Convert R data frame to pandas DataFrame directly
    
        return counts_df, metadata_df
    
    # Usage example
    file_path = '/tmp/work/RCproject/GEO_singlecellexperiment.rds'
    counts_df, metadata_df = read_rds_to_matrix_and_metadata(file_path)
    
    if use_gene_list:
        counts_df = counts_df.loc[current_genes]

    filtered_metadata_df = metadata_df[~metadata_df['Response'].isin(['partial'])].copy()

    row_names = filtered_metadata_df.index.tolist()  # Convert index to a list
    
    filtered_counts_df = counts_df[row_names].copy()

    categories_technology = filtered_metadata_df['batch']

    if simplifly_categories:
        category_map = {'GSE133057': 'micro', 'GSE145037': 'micro', 'GSE150082': 'micro','GSE190826':'seq','GSE209746':'seq',
                        'GSE45404_GPL1': 'micro', 'GSE45404_GPL2': 'micro', 'GSE93375': 'micro','GSE94104': 'micro'}
        categories_technology = np.vectorize(category_map.get)(categories_technology)
        
    # Create a LabelEncoder instance
    label_encoder = LabelEncoder()
    # Fit and transform the categories to integers
    numerical_categories_technology = label_encoder.fit_transform(categories_technology)        
    # categories_outcome = adata.obs['Response']
    categories_outcome = filtered_metadata_df['Response']
    numerical_categories_outcome = label_encoder.fit_transform(categories_outcome)


    frequency_counts = pd.Series(numerical_categories_technology).value_counts()
    frequency_counts = pd.Series(numerical_categories_outcome).value_counts()    
    unique_combinations_array = (numerical_categories_outcome + (numerical_categories_technology+1)*2)-2
    np.unique(unique_combinations_array)

    # Assuming filtered_metadata_df is your filtered DataFrame
    filtered_metadata_df.loc[:, 'numerical_categories_technology'] = numerical_categories_technology
    filtered_metadata_df.loc[:, 'numerical_categories_outcome'] = numerical_categories_outcome
    filtered_metadata_df.loc[:, 'combination_tech_outcome'] = unique_combinations_array

    #normalizaiton
    # gene_expression_data = adata.layers['scalelogcounts']
    
    gene_expression_data = filtered_counts_df.T
    
    #Min-max normalization
    
    scaler = MinMaxScaler()
    gene_expression_data = scaler.fit_transform(gene_expression_data)
    
    number_genes = gene_expression_data.shape[1]
    input_dim = number_genes
    
    if PCA_reduce:
    # Initialize PCA and fit it to X_train
        n_components = n_comp_PCA  # You can adjust this based on your data
        pca = PCA(n_components=n_components)
        gene_expression_data = pca.fit_transform(gene_expression_data)

    # setup the test and train datasets
    # X_train, X_test, y_train, y_test = train_test_split(gene_expression_data, filtered_metadata_df, test_size=test_set_size, random_state=1)
    # X_train, X_test, y_train, y_test = train_test_split(gene_expression_data, filtered_metadata_df, test_size=test_set_size, random_state=1, stratify=filtered_metadata_df['numerical_categories_outcome'])
    X_train, X_test, y_train, y_test = train_test_split(gene_expression_data, filtered_metadata_df, test_size=test_set_size, random_state=1,stratify=filtered_metadata_df['combination_tech_outcome'])
    
    y_train_outcome = y_train['numerical_categories_outcome']
    y_test_outcome = y_test['numerical_categories_outcome']
    
    y_train_tech = y_train['numerical_categories_technology']
    y_test_tech = y_test['numerical_categories_technology']
    
    y_train_comb = y_train['combination_tech_outcome']
    y_test_comb = y_test['combination_tech_outcome']

    # # Define the input shape
    # # input_shape = (gene_expression_data.shape[1],)[0]  # Number of genes

    input_shape = (X_train.shape[1],)[0]  # Number of genes
    
    def build_outcome_classifier():
        model = keras.Sequential()
        model.add(layers.Input(shape=(input_shape,)))  # Input shape matches your data
        
        # model.add(layers.Dense(512,kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),kernel_initializer=weight_intializaiton_style))
        # model.add(layers.LeakyReLU(alpha=0.1))  # Leaky ReLU helps with vanishing gradients
        # model.add(layers.BatchNormalization())
        # model.add(layers.Dropout(dropout_rate))
        
        model.add(layers.Dense((256),kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),kernel_initializer=weight_intializaiton_style))
        model.add(layers.LeakyReLU(alpha=0.1))
        model.add(layers.BatchNormalization())
        model.add(layers.Dropout(dropout_rate))
    
        model.add(layers.Dense((128),kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),kernel_initializer=weight_intializaiton_style))
        model.add(layers.LeakyReLU(alpha=0.1))
        model.add(layers.BatchNormalization())
        model.add(layers.Dropout(dropout_rate))
        
        model.add(layers.Dense((64),kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),kernel_initializer=weight_intializaiton_style))
        model.add(layers.LeakyReLU(alpha=0.1))
        model.add(layers.BatchNormalization())
        model.add(layers.Dropout(dropout_rate))
    
        model.add(layers.Dense((32),kernel_initializer=weight_intializaiton_style))
        model.add(layers.LeakyReLU(alpha=0.1))
        model.add(layers.BatchNormalization())
        
        # Output layer for binary classification with sigmoid activation
        model.add(layers.Dense(1, activation='sigmoid'))
        
        return model

    # Define the mode
    outcome_classifier = build_outcome_classifier()
    
    # set up the optimizer
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate, clipnorm = clipnorm)
    
    # determine the sample and batch size
    num_samples = math.floor(X_train.shape[0]* (1-holdout_size))  # number of samples used in each training epoch
    
    # batch_size = adata.shape[0]
    
    # Calculate the number of steps per epoch
    num_steps_per_epoch = num_samples // batch_size
    
    # Compile the outcome discriminator
    outcome_classifier.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])


    test_accuracy_list = []
    train_accuracy_list = []
    
    num_outcomes = len(np.unique(y_test_outcome))
    num_conditions = len(np.unique(unique_combinations_array))
    
    # Define the training step for only the outcome classifier
    def train_step(data, outcome_labels):
        with tf.GradientTape() as tape:
            # Forward pass through the outcome classifier
            outcome_predictions = outcome_classifier(data)
    
            # Compute the biological discriminator loss
            outcome_loss = tf.keras.losses.binary_crossentropy(outcome_labels, outcome_predictions)
            outcome_loss = tf.reduce_mean(outcome_loss)  # Average over the batch
    
        # Compute gradients for the outcome classifier
        classifier_grads = tape.gradient(outcome_loss, outcome_classifier.trainable_variables)
        
        # Calculate accuracy for the outcome classifier
        predicted_outcome_labels = tf.cast(outcome_predictions > 0.5, tf.float32)  # Threshold at 0.5
        outcome_labels_float = tf.cast(outcome_labels, tf.float32)
    
        # Calculate accuracy
        accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted_outcome_labels, outcome_labels_float), tf.float32))
    
        return outcome_loss, accuracy, classifier_grads
    
    # Training loop
    for epoch in range(num_epochs):
        total_loss = 0.0  # To accumulate losses
        total_accuracy = 0.0  # To accumulate accuracy
        accumulated_grads = [tf.zeros_like(var) for var in outcome_classifier.trainable_variables]  # Initialize gradient accumulator
    
        # Split train data randomly, holding out a portion for generalization
        X_train_temp, X_test_temp, y_train_temp, y_test_temp = train_test_split(X_train, y_train, test_size=holdout_size, random_state=None)
        y_train_comb_temp = y_train_temp['combination_tech_outcome']
        y_train_temp = y_train_temp['numerical_categories_outcome']
        
        # Mini-batch training loop
        for step in range(num_steps_per_epoch):
            # Balance batches if necessary
            batch_indices = []
            if balance:
                for condition in range(num_conditions):
                    condition_indices = np.where(y_train_comb_temp == condition)[0]
                    condition_batch_indices = np.random.choice(condition_indices, size=batch_size // num_conditions, replace=True)
                    batch_indices.append(condition_batch_indices)
            else:
                all_indices = np.arange(len(X_train_temp))
                random_indices = np.random.choice(all_indices, size=batch_size, replace=True)
                batch_indices.append(random_indices)
            X_batch = X_train_temp[np.concatenate(batch_indices)]
            y_batch = y_train_temp[np.concatenate(batch_indices)]
            y_batch = tf.expand_dims(y_batch, axis=-1)  # Adjust labels shape for binary_crossentropy                    
            # Perform the training step and collect gradients
            outcome_loss, accuracy, classifier_grads = train_step(X_batch, y_batch)
            
            # Accumulate gradients and losses
            total_loss += outcome_loss.numpy()
            total_accuracy += accuracy.numpy()
            accumulated_grads = [acc_grad + grad for acc_grad, grad in zip(accumulated_grads, classifier_grads)]
    
        # Average the accumulated gradients
        averaged_grads = [grad / num_steps_per_epoch for grad in accumulated_grads]
    
        # Apply averaged gradients to update model weights
        optimizer.apply_gradients(zip(averaged_grads, outcome_classifier.trainable_variables))
    
        # Calculate average loss and accuracy for the epoch
        avg_loss = total_loss / num_steps_per_epoch
        avg_accuracy = total_accuracy / num_steps_per_epoch
    
        # Print average accuracy at the end of each epoch and calculate the accuracy for the test set
        if epoch % report_frequency == 0:
            # Evaluate on test data
            outcome_predictions = outcome_classifier(X_test)
            predicted_outcome_labels = tf.cast(outcome_predictions > 0.5, tf.float32)  # Threshold at 0.5
            outcome_labels = tf.expand_dims(y_test_outcome, axis=-1)  # Reshape to match logits shape
            outcome_labels_float = tf.cast(outcome_labels, tf.float32)
    
            # Calculate accuracy
            test_accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted_outcome_labels, outcome_labels_float), tf.float32))
            
            # Store and print metrics
            train_accuracy_list.append(avg_accuracy)
            test_accuracy_list.append(test_accuracy)
            print(f'Epoch {epoch}, Average Outcome Loss: {avg_loss}, Average Accuracy: {avg_accuracy}, Test Accuracy: {test_accuracy}')
    
            # Early stopping condition for accuracy
            if test_accuracy > accuracy_threshold:
                print('Early stopping: test set performance high enough')
                break

    current_val_str = str(current_value)
    title = 'with_balance_true_dropout_is_' + current_val_str
    
    # Create the PDF file name based on a variable
    output_dir = "tmp_plots"
    pdf_filename = os.path.join(output_dir, f"{title}.pdf")
    
    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)  # Ensure the directory is created
    
    # Create a new figure to hold all plots
    with PdfPages(pdf_filename) as pdf:
        fig, axs = plt.subplots(2, 2, figsize=(12, 10))  # 2 rows, 2 columns
    
        # Training accuracy plot
        x_values = np.arange(1, len(train_accuracy_list) + 1) * report_frequency
        frequency_counts = pd.Series(y_train_outcome).value_counts()
        train_chance_level = frequency_counts[0] / len(y_train_outcome)
    
        axs[0, 0].plot(x_values, train_accuracy_list, label='Training Accuracy', color='blue')
        axs[0, 0].axhline(train_chance_level, color='black', linestyle='--')
        axs[0, 0].set_title('Training Set Accuracy Over Epochs')
        axs[0, 0].set_xlabel('Epoch')
        axs[0, 0].set_ylabel('Training Accuracy')
        axs[0, 0].grid()
        axs[0, 0].legend()
    
        # Testing accuracy plot
        frequency_counts = pd.Series(y_test_outcome).value_counts()
        test_chance_level = frequency_counts[0] / len(y_test_outcome)
    
        axs[0, 1].plot(x_values, test_accuracy_list, label='Test Accuracy', color='orange')
        axs[0, 1].axhline(test_chance_level, color='black', linestyle='--')
        axs[0, 1].set_title('Test Set Accuracy Over Epochs')
        axs[0, 1].set_xlabel('Epoch')
        axs[0, 1].set_ylabel('Test Accuracy')
        axs[0, 1].grid()
        axs[0, 1].legend()
    
        # ROC curve for ANN
        fpr, tpr, thresholds = roc_curve(y_test_outcome, predicted_outcome_labels)
        roc_auc = auc(fpr, tpr)
    
        axs[1, 0].plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
        axs[1, 0].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        axs[1, 0].set_xlim([0.0, 1.0])
        axs[1, 0].set_ylim([0.0, 1.05])
        axs[1, 0].set_xlabel('False Positive Rate')
        axs[1, 0].set_ylabel('True Positive Rate')
        axs[1, 0].set_title('ROC Curve for ANN')
        axs[1, 0].legend(loc="lower right")
    
        # ROC curve for Random Forest
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X_train, y_train_outcome)
        y_pred_prob = clf.predict_proba(X_test)[:, 1]
        fpr, tpr, thresholds = roc_curve(y_test_outcome, y_pred_prob)
        roc_auc = auc(fpr, tpr)
    
        axs[1, 1].plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
        axs[1, 1].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        axs[1, 1].set_xlim([0.0, 1.0])
        axs[1, 1].set_ylim([0.0, 1.05])
        axs[1, 1].set_xlabel('False Positive Rate')
        axs[1, 1].set_ylabel('True Positive Rate')
        axs[1, 1].set_title('ROC Curve for Random Forest')
        axs[1, 1].legend(loc="lower right")
    
        plt.tight_layout()
        pdf.savefig(fig)  # Save the figure to the PDF
        plt.close(fig)     # Close the figure

for current_value in current_list:
    test_params(current_value)

# current_value = 0
# test_params(curren_value)
# Out:
# let's go
# /tmp/ipykernel_799/3703698211.py:301: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_batch = y_train_temp[np.concatenate(batch_indices)]
# Epoch 0, Average Outcome Loss: 0.6797791123390198, Average Accuracy: 0.5859375, Test Accuracy: 0.5853658318519592
# Epoch 5, Average Outcome Loss: 0.6392335295677185, Average Accuracy: 0.6171875, Test Accuracy: 0.5853658318519592
# Epoch 10, Average Outcome Loss: 0.6453897356987, Average Accuracy: 0.6484375, Test Accuracy: 0.5853658318519592
# Epoch 15, Average Outcome Loss: 0.623014897108078, Average Accuracy: 0.6875, Test Accuracy: 0.5853658318519592
# Epoch 20, Average Outcome Loss: 0.653052419424057, Average Accuracy: 0.625, Test Accuracy: 0.5853658318519592
# Epoch 25, Average Outcome Loss: 0.6217521727085114, Average Accuracy: 0.609375, Test Accuracy: 0.5853658318519592
# Epoch 30, Average Outcome Loss: 0.5796864032745361, Average Accuracy: 0.6953125, Test Accuracy: 0.5853658318519592
# Epoch 35, Average Outcome Loss: 0.7336251437664032, Average Accuracy: 0.546875, Test Accuracy: 0.5853658318519592
# Epoch 40, Average Outcome Loss: 0.6173466444015503, Average Accuracy: 0.6484375, Test Accuracy: 0.6097561120986938
# Epoch 45, Average Outcome Loss: 0.5754174590110779, Average Accuracy: 0.71875, Test Accuracy: 0.5853658318519592
# Epoch 50, Average Outcome Loss: 0.5986535549163818, Average Accuracy: 0.640625, Test Accuracy: 0.6097561120986938
# Epoch 55, Average Outcome Loss: 0.6396967172622681, Average Accuracy: 0.640625, Test Accuracy: 0.5853658318519592
# Epoch 60, Average Outcome Loss: 0.6331642270088196, Average Accuracy: 0.6484375, Test Accuracy: 0.5853658318519592
# Epoch 65, Average Outcome Loss: 0.5618154406547546, Average Accuracy: 0.703125, Test Accuracy: 0.6341463327407837
# Epoch 70, Average Outcome Loss: 0.5552893877029419, Average Accuracy: 0.7421875, Test Accuracy: 0.6341463327407837
# Epoch 75, Average Outcome Loss: 0.573542445898056, Average Accuracy: 0.734375, Test Accuracy: 0.6341463327407837
# Epoch 80, Average Outcome Loss: 0.6091980040073395, Average Accuracy: 0.6953125, Test Accuracy: 0.6341463327407837
# Epoch 85, Average Outcome Loss: 0.6862269043922424, Average Accuracy: 0.578125, Test Accuracy: 0.6341463327407837
# Epoch 90, Average Outcome Loss: 0.6094034314155579, Average Accuracy: 0.6875, Test Accuracy: 0.6341463327407837
# Epoch 95, Average Outcome Loss: 0.579980194568634, Average Accuracy: 0.6953125, Test Accuracy: 0.6341463327407837
# Epoch 100, Average Outcome Loss: 0.5544315874576569, Average Accuracy: 0.7421875, Test Accuracy: 0.6341463327407837
# Epoch 105, Average Outcome Loss: 0.6363017559051514, Average Accuracy: 0.6640625, Test Accuracy: 0.6341463327407837
# Epoch 110, Average Outcome Loss: 0.5786506235599518, Average Accuracy: 0.7265625, Test Accuracy: 0.6341463327407837
# Epoch 115, Average Outcome Loss: 0.5781101286411285, Average Accuracy: 0.6953125, Test Accuracy: 0.6341463327407837
# Epoch 120, Average Outcome Loss: 0.5860143303871155, Average Accuracy: 0.6953125, Test Accuracy: 0.6341463327407837
# Epoch 125, Average Outcome Loss: 0.5882327556610107, Average Accuracy: 0.6875, Test Accuracy: 0.6341463327407837
# Epoch 130, Average Outcome Loss: 0.6165976822376251, Average Accuracy: 0.6328125, Test Accuracy: 0.6341463327407837
# Epoch 135, Average Outcome Loss: 0.5752167105674744, Average Accuracy: 0.6875, Test Accuracy: 0.6341463327407837
# Epoch 140, Average Outcome Loss: 0.5868977904319763, Average Accuracy: 0.703125, Test Accuracy: 0.6097561120986938
# Epoch 145, Average Outcome Loss: 0.6019249260425568, Average Accuracy: 0.7265625, Test Accuracy: 0.6341463327407837
# Epoch 150, Average Outcome Loss: 0.6272113025188446, Average Accuracy: 0.65625, Test Accuracy: 0.6341463327407837
# Epoch 155, Average Outcome Loss: 0.5635800361633301, Average Accuracy: 0.7421875, Test Accuracy: 0.6341463327407837
# Epoch 160, Average Outcome Loss: 0.6566672921180725, Average Accuracy: 0.6484375, Test Accuracy: 0.6341463327407837
# Epoch 165, Average Outcome Loss: 0.5328072309494019, Average Accuracy: 0.7890625, Test Accuracy: 0.6341463327407837
# Epoch 170, Average Outcome Loss: 0.5355719923973083, Average Accuracy: 0.7734375, Test Accuracy: 0.6097561120986938
# Epoch 175, Average Outcome Loss: 0.6098212897777557, Average Accuracy: 0.7109375, Test Accuracy: 0.6097561120986938
# Epoch 180, Average Outcome Loss: 0.6048683822154999, Average Accuracy: 0.7265625, Test Accuracy: 0.6341463327407837
# Epoch 185, Average Outcome Loss: 0.5758979320526123, Average Accuracy: 0.734375, Test Accuracy: 0.6341463327407837
# Epoch 190, Average Outcome Loss: 0.5978000462055206, Average Accuracy: 0.671875, Test Accuracy: 0.6341463327407837
# Epoch 195, Average Outcome Loss: 0.6162380874156952, Average Accuracy: 0.71875, Test Accuracy: 0.6341463327407837
# Epoch 200, Average Outcome Loss: 0.6250698566436768, Average Accuracy: 0.6953125, Test Accuracy: 0.6341463327407837
# Epoch 205, Average Outcome Loss: 0.581439882516861, Average Accuracy: 0.765625, Test Accuracy: 0.6341463327407837
# Epoch 210, Average Outcome Loss: 0.5826531052589417, Average Accuracy: 0.7109375, Test Accuracy: 0.6341463327407837
# Epoch 215, Average Outcome Loss: 0.5213143825531006, Average Accuracy: 0.8046875, Test Accuracy: 0.6341463327407837
# Epoch 220, Average Outcome Loss: 0.6068473160266876, Average Accuracy: 0.6953125, Test Accuracy: 0.6341463327407837
# Epoch 225, Average Outcome Loss: 0.593682587146759, Average Accuracy: 0.6875, Test Accuracy: 0.6097561120986938
# Epoch 230, Average Outcome Loss: 0.5538260042667389, Average Accuracy: 0.765625, Test Accuracy: 0.6097561120986938
# Epoch 235, Average Outcome Loss: 0.548984169960022, Average Accuracy: 0.75, Test Accuracy: 0.6341463327407837
# Epoch 240, Average Outcome Loss: 0.5177513957023621, Average Accuracy: 0.78125, Test Accuracy: 0.6097561120986938
# Epoch 245, Average Outcome Loss: 0.5547379553318024, Average Accuracy: 0.765625, Test Accuracy: 0.6097561120986938
# Epoch 250, Average Outcome Loss: 0.5535215139389038, Average Accuracy: 0.7578125, Test Accuracy: 0.6097561120986938
# Epoch 255, Average Outcome Loss: 0.525529533624649, Average Accuracy: 0.8046875, Test Accuracy: 0.6097561120986938
# Epoch 260, Average Outcome Loss: 0.5685743093490601, Average Accuracy: 0.7109375, Test Accuracy: 0.6097561120986938
# Epoch 265, Average Outcome Loss: 0.5541353523731232, Average Accuracy: 0.7421875, Test Accuracy: 0.6097561120986938
# Epoch 270, Average Outcome Loss: 0.5651607513427734, Average Accuracy: 0.7265625, Test Accuracy: 0.6097561120986938
# Epoch 275, Average Outcome Loss: 0.5643870830535889, Average Accuracy: 0.7578125, Test Accuracy: 0.6097561120986938
# Epoch 280, Average Outcome Loss: 0.5512017011642456, Average Accuracy: 0.796875, Test Accuracy: 0.6341463327407837
# Epoch 285, Average Outcome Loss: 0.5911628007888794, Average Accuracy: 0.703125, Test Accuracy: 0.6097561120986938
# Epoch 290, Average Outcome Loss: 0.5780419111251831, Average Accuracy: 0.7265625, Test Accuracy: 0.6097561120986938
# Epoch 295, Average Outcome Loss: 0.6462795734405518, Average Accuracy: 0.703125, Test Accuracy: 0.6097561120986938
# Epoch 300, Average Outcome Loss: 0.5874335765838623, Average Accuracy: 0.7421875, Test Accuracy: 0.6097561120986938
# Epoch 305, Average Outcome Loss: 0.5441347360610962, Average Accuracy: 0.7421875, Test Accuracy: 0.6097561120986938
# Epoch 310, Average Outcome Loss: 0.5921071469783783, Average Accuracy: 0.7421875, Test Accuracy: 0.6097561120986938
# Epoch 315, Average Outcome Loss: 0.5760257542133331, Average Accuracy: 0.7109375, Test Accuracy: 0.6097561120986938
# Epoch 320, Average Outcome Loss: 0.5847258567810059, Average Accuracy: 0.6796875, Test Accuracy: 0.707317054271698
# Epoch 325, Average Outcome Loss: 0.518254429101944, Average Accuracy: 0.78125, Test Accuracy: 0.7317073345184326
# Epoch 330, Average Outcome Loss: 0.5124464482069016, Average Accuracy: 0.78125, Test Accuracy: 0.6341463327407837
# Epoch 335, Average Outcome Loss: 0.5916959941387177, Average Accuracy: 0.7265625, Test Accuracy: 0.6097561120986938
# Epoch 340, Average Outcome Loss: 0.5392690598964691, Average Accuracy: 0.78125, Test Accuracy: 0.6097561120986938
# Epoch 345, Average Outcome Loss: 0.5989397168159485, Average Accuracy: 0.6875, Test Accuracy: 0.6097561120986938
# Epoch 350, Average Outcome Loss: 0.5357441008090973, Average Accuracy: 0.796875, Test Accuracy: 0.6097561120986938
# Epoch 355, Average Outcome Loss: 0.5561222732067108, Average Accuracy: 0.734375, Test Accuracy: 0.6097561120986938
# Epoch 360, Average Outcome Loss: 0.5280890762805939, Average Accuracy: 0.734375, Test Accuracy: 0.7317073345184326
# Epoch 365, Average Outcome Loss: 0.5422099828720093, Average Accuracy: 0.7265625, Test Accuracy: 0.7317073345184326
# Epoch 370, Average Outcome Loss: 0.5567252337932587, Average Accuracy: 0.765625, Test Accuracy: 0.6341463327407837
# Epoch 375, Average Outcome Loss: 0.5823219418525696, Average Accuracy: 0.7421875, Test Accuracy: 0.6097561120986938
# Epoch 380, Average Outcome Loss: 0.5253024399280548, Average Accuracy: 0.796875, Test Accuracy: 0.6097561120986938
# Epoch 385, Average Outcome Loss: 0.5087204575538635, Average Accuracy: 0.8125, Test Accuracy: 0.6097561120986938
# Epoch 390, Average Outcome Loss: 0.5980972647666931, Average Accuracy: 0.703125, Test Accuracy: 0.6097561120986938
# Epoch 395, Average Outcome Loss: 0.5770986378192902, Average Accuracy: 0.734375, Test Accuracy: 0.6097561120986938
# Epoch 400, Average Outcome Loss: 0.5165277719497681, Average Accuracy: 0.7734375, Test Accuracy: 0.6097561120986938
# Epoch 405, Average Outcome Loss: 0.526472195982933, Average Accuracy: 0.765625, Test Accuracy: 0.7317073345184326
# Epoch 410, Average Outcome Loss: 0.5717401206493378, Average Accuracy: 0.7265625, Test Accuracy: 0.7560975551605225
# Epoch 415, Average Outcome Loss: 0.5592993795871735, Average Accuracy: 0.71875, Test Accuracy: 0.7560975551605225
# Epoch 420, Average Outcome Loss: 0.4896235466003418, Average Accuracy: 0.8125, Test Accuracy: 0.7317073345184326
# Epoch 425, Average Outcome Loss: 0.46503767371177673, Average Accuracy: 0.8203125, Test Accuracy: 0.6097561120986938
# Epoch 430, Average Outcome Loss: 0.5535119473934174, Average Accuracy: 0.7578125, Test Accuracy: 0.6097561120986938
# Epoch 435, Average Outcome Loss: 0.5748389661312103, Average Accuracy: 0.7421875, Test Accuracy: 0.6097561120986938
# Epoch 440, Average Outcome Loss: 0.5758907198905945, Average Accuracy: 0.7265625, Test Accuracy: 0.6341463327407837
# Epoch 445, Average Outcome Loss: 0.4980475604534149, Average Accuracy: 0.828125, Test Accuracy: 0.707317054271698
# Epoch 450, Average Outcome Loss: 0.5108096897602081, Average Accuracy: 0.796875, Test Accuracy: 0.6097561120986938
# Epoch 455, Average Outcome Loss: 0.5562882125377655, Average Accuracy: 0.75, Test Accuracy: 0.6097561120986938
# Epoch 460, Average Outcome Loss: 0.5226787626743317, Average Accuracy: 0.765625, Test Accuracy: 0.6097561120986938
# Epoch 465, Average Outcome Loss: 0.5197348892688751, Average Accuracy: 0.765625, Test Accuracy: 0.6097561120986938
# Epoch 470, Average Outcome Loss: 0.531587153673172, Average Accuracy: 0.7890625, Test Accuracy: 0.6829268336296082
# Epoch 475, Average Outcome Loss: 0.489888995885849, Average Accuracy: 0.8515625, Test Accuracy: 0.6097561120986938
# Epoch 480, Average Outcome Loss: 0.4997296780347824, Average Accuracy: 0.8203125, Test Accuracy: 0.6097561120986938
# Epoch 485, Average Outcome Loss: 0.5383340120315552, Average Accuracy: 0.78125, Test Accuracy: 0.6097561120986938
# Epoch 490, Average Outcome Loss: 0.5725666880607605, Average Accuracy: 0.7421875, Test Accuracy: 0.6097561120986938
# Epoch 495, Average Outcome Loss: 0.5398273468017578, Average Accuracy: 0.7421875, Test Accuracy: 0.7317073345184326
# Epoch 500, Average Outcome Loss: 0.5279622375965118, Average Accuracy: 0.7734375, Test Accuracy: 0.7317073345184326
# Epoch 505, Average Outcome Loss: 0.41324345767498016, Average Accuracy: 0.875, Test Accuracy: 0.7317073345184326
# Epoch 510, Average Outcome Loss: 0.5017403364181519, Average Accuracy: 0.8125, Test Accuracy: 0.6829268336296082
# Epoch 515, Average Outcome Loss: 0.5151079595088959, Average Accuracy: 0.765625, Test Accuracy: 0.6341463327407837
# Epoch 520, Average Outcome Loss: 0.45607636868953705, Average Accuracy: 0.8671875, Test Accuracy: 0.6341463327407837
# Epoch 525, Average Outcome Loss: 0.5468898415565491, Average Accuracy: 0.7421875, Test Accuracy: 0.6341463327407837
# Epoch 530, Average Outcome Loss: 0.5012217015028, Average Accuracy: 0.828125, Test Accuracy: 0.6341463327407837
# Epoch 535, Average Outcome Loss: 0.5117818415164948, Average Accuracy: 0.7421875, Test Accuracy: 0.6341463327407837
# Epoch 540, Average Outcome Loss: 0.5151384472846985, Average Accuracy: 0.7734375, Test Accuracy: 0.6829268336296082
# Epoch 545, Average Outcome Loss: 0.5249473601579666, Average Accuracy: 0.7421875, Test Accuracy: 0.707317054271698
# Epoch 550, Average Outcome Loss: 0.5131300687789917, Average Accuracy: 0.734375, Test Accuracy: 0.7317073345184326
# Epoch 555, Average Outcome Loss: 0.5602688789367676, Average Accuracy: 0.7421875, Test Accuracy: 0.7317073345184326
# Epoch 560, Average Outcome Loss: 0.4722963571548462, Average Accuracy: 0.7890625, Test Accuracy: 0.7317073345184326
# Epoch 565, Average Outcome Loss: 0.5215945243835449, Average Accuracy: 0.7890625, Test Accuracy: 0.6829268336296082
# Epoch 570, Average Outcome Loss: 0.5713734328746796, Average Accuracy: 0.7265625, Test Accuracy: 0.6585366129875183
# Epoch 575, Average Outcome Loss: 0.5048257857561111, Average Accuracy: 0.7890625, Test Accuracy: 0.6585366129875183
# Epoch 580, Average Outcome Loss: 0.5489797592163086, Average Accuracy: 0.7421875, Test Accuracy: 0.6829268336296082
# Epoch 585, Average Outcome Loss: 0.5041218549013138, Average Accuracy: 0.8046875, Test Accuracy: 0.6829268336296082
# Epoch 590, Average Outcome Loss: 0.5134608149528503, Average Accuracy: 0.7421875, Test Accuracy: 0.6829268336296082
# Epoch 595, Average Outcome Loss: 0.5661013126373291, Average Accuracy: 0.734375, Test Accuracy: 0.6829268336296082
# Epoch 600, Average Outcome Loss: 0.4746314138174057, Average Accuracy: 0.7734375, Test Accuracy: 0.6829268336296082
# Epoch 605, Average Outcome Loss: 0.4488947093486786, Average Accuracy: 0.828125, Test Accuracy: 0.6585366129875183
# Epoch 610, Average Outcome Loss: 0.5297429263591766, Average Accuracy: 0.765625, Test Accuracy: 0.6829268336296082
# Epoch 615, Average Outcome Loss: 0.48695647716522217, Average Accuracy: 0.8125, Test Accuracy: 0.707317054271698
# Epoch 620, Average Outcome Loss: 0.44039252400398254, Average Accuracy: 0.8515625, Test Accuracy: 0.707317054271698
# Epoch 625, Average Outcome Loss: 0.48139023780822754, Average Accuracy: 0.7890625, Test Accuracy: 0.707317054271698
# Epoch 630, Average Outcome Loss: 0.4647118002176285, Average Accuracy: 0.828125, Test Accuracy: 0.6829268336296082
# Epoch 635, Average Outcome Loss: 0.5783464312553406, Average Accuracy: 0.75, Test Accuracy: 0.707317054271698
# Epoch 640, Average Outcome Loss: 0.49402613937854767, Average Accuracy: 0.828125, Test Accuracy: 0.707317054271698
# Epoch 645, Average Outcome Loss: 0.5550671219825745, Average Accuracy: 0.7578125, Test Accuracy: 0.707317054271698
# Epoch 650, Average Outcome Loss: 0.45586341619491577, Average Accuracy: 0.84375, Test Accuracy: 0.707317054271698
# Epoch 655, Average Outcome Loss: 0.5439205169677734, Average Accuracy: 0.765625, Test Accuracy: 0.707317054271698
# Epoch 660, Average Outcome Loss: 0.50814288854599, Average Accuracy: 0.78125, Test Accuracy: 0.707317054271698
# Epoch 665, Average Outcome Loss: 0.4982554018497467, Average Accuracy: 0.8125, Test Accuracy: 0.7317073345184326
# Epoch 670, Average Outcome Loss: 0.5141641497612, Average Accuracy: 0.7890625, Test Accuracy: 0.707317054271698
# Epoch 675, Average Outcome Loss: 0.4311603307723999, Average Accuracy: 0.8671875, Test Accuracy: 0.707317054271698
# Epoch 680, Average Outcome Loss: 0.5451164245605469, Average Accuracy: 0.75, Test Accuracy: 0.6829268336296082
# Epoch 685, Average Outcome Loss: 0.5006507784128189, Average Accuracy: 0.78125, Test Accuracy: 0.707317054271698
# Epoch 690, Average Outcome Loss: 0.5344728082418442, Average Accuracy: 0.7734375, Test Accuracy: 0.7317073345184326
# Epoch 695, Average Outcome Loss: 0.4852999150753021, Average Accuracy: 0.7890625, Test Accuracy: 0.707317054271698
# Epoch 700, Average Outcome Loss: 0.47063103318214417, Average Accuracy: 0.8359375, Test Accuracy: 0.707317054271698
# Epoch 705, Average Outcome Loss: 0.4662783592939377, Average Accuracy: 0.796875, Test Accuracy: 0.7317073345184326
# Epoch 710, Average Outcome Loss: 0.4626174420118332, Average Accuracy: 0.796875, Test Accuracy: 0.707317054271698
# Epoch 715, Average Outcome Loss: 0.5067372024059296, Average Accuracy: 0.796875, Test Accuracy: 0.707317054271698
# Epoch 720, Average Outcome Loss: 0.5661870539188385, Average Accuracy: 0.7265625, Test Accuracy: 0.707317054271698
# Epoch 725, Average Outcome Loss: 0.49634304642677307, Average Accuracy: 0.8046875, Test Accuracy: 0.7317073345184326
# Epoch 730, Average Outcome Loss: 0.4100513905286789, Average Accuracy: 0.859375, Test Accuracy: 0.7317073345184326
# Epoch 735, Average Outcome Loss: 0.52006796002388, Average Accuracy: 0.7734375, Test Accuracy: 0.707317054271698
# Epoch 740, Average Outcome Loss: 0.5104868113994598, Average Accuracy: 0.78125, Test Accuracy: 0.7317073345184326
# Epoch 745, Average Outcome Loss: 0.5466645061969757, Average Accuracy: 0.765625, Test Accuracy: 0.7317073345184326
# Epoch 750, Average Outcome Loss: 0.45587870478630066, Average Accuracy: 0.8125, Test Accuracy: 0.707317054271698
# Epoch 755, Average Outcome Loss: 0.5269272327423096, Average Accuracy: 0.71875, Test Accuracy: 0.7317073345184326
# Epoch 760, Average Outcome Loss: 0.4117417633533478, Average Accuracy: 0.8828125, Test Accuracy: 0.707317054271698
# Epoch 765, Average Outcome Loss: 0.4777482897043228, Average Accuracy: 0.8125, Test Accuracy: 0.7317073345184326
# Epoch 770, Average Outcome Loss: 0.49335789680480957, Average Accuracy: 0.796875, Test Accuracy: 0.7317073345184326
# Epoch 775, Average Outcome Loss: 0.5626022517681122, Average Accuracy: 0.7734375, Test Accuracy: 0.7317073345184326
# Epoch 780, Average Outcome Loss: 0.48859821259975433, Average Accuracy: 0.78125, Test Accuracy: 0.707317054271698
# Epoch 785, Average Outcome Loss: 0.49997177720069885, Average Accuracy: 0.8046875, Test Accuracy: 0.7317073345184326
# Epoch 790, Average Outcome Loss: 0.47803889214992523, Average Accuracy: 0.84375, Test Accuracy: 0.7317073345184326
# Epoch 795, Average Outcome Loss: 0.5069884359836578, Average Accuracy: 0.7578125, Test Accuracy: 0.7317073345184326
# Epoch 800, Average Outcome Loss: 0.5173122137784958, Average Accuracy: 0.78125, Test Accuracy: 0.7317073345184326
# Epoch 805, Average Outcome Loss: 0.5043398439884186, Average Accuracy: 0.7734375, Test Accuracy: 0.707317054271698
# Epoch 810, Average Outcome Loss: 0.5242823362350464, Average Accuracy: 0.7578125, Test Accuracy: 0.7317073345184326
# Epoch 815, Average Outcome Loss: 0.5242351293563843, Average Accuracy: 0.7421875, Test Accuracy: 0.7317073345184326
# Epoch 820, Average Outcome Loss: 0.47217777371406555, Average Accuracy: 0.796875, Test Accuracy: 0.7317073345184326
# Epoch 825, Average Outcome Loss: 0.437543123960495, Average Accuracy: 0.8515625, Test Accuracy: 0.7317073345184326
# Epoch 830, Average Outcome Loss: 0.4381130486726761, Average Accuracy: 0.8671875, Test Accuracy: 0.7317073345184326
# Epoch 835, Average Outcome Loss: 0.46838435530662537, Average Accuracy: 0.765625, Test Accuracy: 0.707317054271698
# Epoch 840, Average Outcome Loss: 0.48787544667720795, Average Accuracy: 0.8125, Test Accuracy: 0.707317054271698
# Epoch 845, Average Outcome Loss: 0.4939780980348587, Average Accuracy: 0.7890625, Test Accuracy: 0.7560975551605225
# Epoch 850, Average Outcome Loss: 0.4913029074668884, Average Accuracy: 0.8046875, Test Accuracy: 0.7560975551605225
# Epoch 855, Average Outcome Loss: 0.4758500009775162, Average Accuracy: 0.8046875, Test Accuracy: 0.707317054271698
# Epoch 860, Average Outcome Loss: 0.4475083649158478, Average Accuracy: 0.8046875, Test Accuracy: 0.6829268336296082
# Epoch 865, Average Outcome Loss: 0.4741661250591278, Average Accuracy: 0.796875, Test Accuracy: 0.6829268336296082
# Epoch 870, Average Outcome Loss: 0.5614659190177917, Average Accuracy: 0.7421875, Test Accuracy: 0.7560975551605225
# Epoch 875, Average Outcome Loss: 0.4766569584608078, Average Accuracy: 0.8046875, Test Accuracy: 0.7317073345184326
# Epoch 880, Average Outcome Loss: 0.4748191088438034, Average Accuracy: 0.78125, Test Accuracy: 0.7317073345184326
# Epoch 885, Average Outcome Loss: 0.47283442318439484, Average Accuracy: 0.8046875, Test Accuracy: 0.7317073345184326
# Epoch 890, Average Outcome Loss: 0.5376663357019424, Average Accuracy: 0.7578125, Test Accuracy: 0.7560975551605225
# Epoch 895, Average Outcome Loss: 0.4754249006509781, Average Accuracy: 0.7421875, Test Accuracy: 0.7560975551605225
# Epoch 900, Average Outcome Loss: 0.37116748094558716, Average Accuracy: 0.8671875, Test Accuracy: 0.7560975551605225
# Epoch 905, Average Outcome Loss: 0.45830555260181427, Average Accuracy: 0.8203125, Test Accuracy: 0.7560975551605225
# Epoch 910, Average Outcome Loss: 0.4328034520149231, Average Accuracy: 0.8671875, Test Accuracy: 0.7560975551605225
# Epoch 915, Average Outcome Loss: 0.5261705219745636, Average Accuracy: 0.7890625, Test Accuracy: 0.7317073345184326
# Epoch 920, Average Outcome Loss: 0.5322241485118866, Average Accuracy: 0.7421875, Test Accuracy: 0.7317073345184326
# Epoch 925, Average Outcome Loss: 0.38795119524002075, Average Accuracy: 0.8671875, Test Accuracy: 0.7317073345184326
# Epoch 930, Average Outcome Loss: 0.4806920886039734, Average Accuracy: 0.765625, Test Accuracy: 0.7317073345184326
# Epoch 935, Average Outcome Loss: 0.46895794570446014, Average Accuracy: 0.796875, Test Accuracy: 0.7560975551605225
# Epoch 940, Average Outcome Loss: 0.44996045529842377, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 945, Average Outcome Loss: 0.4935157299041748, Average Accuracy: 0.78125, Test Accuracy: 0.7560975551605225
# Epoch 950, Average Outcome Loss: 0.44551996886730194, Average Accuracy: 0.8359375, Test Accuracy: 0.7560975551605225
# Epoch 955, Average Outcome Loss: 0.5605471432209015, Average Accuracy: 0.75, Test Accuracy: 0.7560975551605225
# Epoch 960, Average Outcome Loss: 0.4416283369064331, Average Accuracy: 0.84375, Test Accuracy: 0.7560975551605225
# Epoch 965, Average Outcome Loss: 0.3613635003566742, Average Accuracy: 0.9296875, Test Accuracy: 0.7804877758026123
# Epoch 970, Average Outcome Loss: 0.5334702730178833, Average Accuracy: 0.7734375, Test Accuracy: 0.7804877758026123
# Epoch 975, Average Outcome Loss: 0.5498406291007996, Average Accuracy: 0.765625, Test Accuracy: 0.7560975551605225
# Epoch 980, Average Outcome Loss: 0.4695575386285782, Average Accuracy: 0.8046875, Test Accuracy: 0.7560975551605225
# Epoch 985, Average Outcome Loss: 0.48764768242836, Average Accuracy: 0.7734375, Test Accuracy: 0.7560975551605225
# Epoch 990, Average Outcome Loss: 0.3965679705142975, Average Accuracy: 0.90625, Test Accuracy: 0.7560975551605225
# Epoch 995, Average Outcome Loss: 0.4444390833377838, Average Accuracy: 0.8125, Test Accuracy: 0.7560975551605225
# Epoch 1000, Average Outcome Loss: 0.4593822807073593, Average Accuracy: 0.796875, Test Accuracy: 0.7560975551605225
# Epoch 1005, Average Outcome Loss: 0.5740122199058533, Average Accuracy: 0.7109375, Test Accuracy: 0.7560975551605225
# Epoch 1010, Average Outcome Loss: 0.4183444231748581, Average Accuracy: 0.859375, Test Accuracy: 0.7560975551605225
# Epoch 1015, Average Outcome Loss: 0.4868781715631485, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 1020, Average Outcome Loss: 0.416883260011673, Average Accuracy: 0.8515625, Test Accuracy: 0.7560975551605225
# Epoch 1025, Average Outcome Loss: 0.4126967340707779, Average Accuracy: 0.8671875, Test Accuracy: 0.7560975551605225
# Epoch 1030, Average Outcome Loss: 0.45360538363456726, Average Accuracy: 0.8125, Test Accuracy: 0.7560975551605225
# Epoch 1035, Average Outcome Loss: 0.45413079857826233, Average Accuracy: 0.8515625, Test Accuracy: 0.7317073345184326
# Epoch 1040, Average Outcome Loss: 0.5185317844152451, Average Accuracy: 0.7734375, Test Accuracy: 0.7317073345184326
# Epoch 1045, Average Outcome Loss: 0.45597662031650543, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 1050, Average Outcome Loss: 0.43073779344558716, Average Accuracy: 0.84375, Test Accuracy: 0.7317073345184326
# Epoch 1055, Average Outcome Loss: 0.444193959236145, Average Accuracy: 0.8359375, Test Accuracy: 0.7560975551605225
# Epoch 1060, Average Outcome Loss: 0.47086989879608154, Average Accuracy: 0.7890625, Test Accuracy: 0.7317073345184326
# Epoch 1065, Average Outcome Loss: 0.4361719787120819, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 1070, Average Outcome Loss: 0.4635057598352432, Average Accuracy: 0.7734375, Test Accuracy: 0.7560975551605225
# Epoch 1075, Average Outcome Loss: 0.46349966526031494, Average Accuracy: 0.8046875, Test Accuracy: 0.7560975551605225
# Epoch 1080, Average Outcome Loss: 0.4749835431575775, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 1085, Average Outcome Loss: 0.4866890609264374, Average Accuracy: 0.796875, Test Accuracy: 0.7560975551605225
# Epoch 1090, Average Outcome Loss: 0.5237588584423065, Average Accuracy: 0.78125, Test Accuracy: 0.7560975551605225
# Epoch 1095, Average Outcome Loss: 0.36884044110774994, Average Accuracy: 0.8828125, Test Accuracy: 0.7560975551605225
# Epoch 1100, Average Outcome Loss: 0.5034625828266144, Average Accuracy: 0.7890625, Test Accuracy: 0.7560975551605225
# Epoch 1105, Average Outcome Loss: 0.5598748326301575, Average Accuracy: 0.7265625, Test Accuracy: 0.7560975551605225
# Epoch 1110, Average Outcome Loss: 0.4452575743198395, Average Accuracy: 0.8046875, Test Accuracy: 0.7560975551605225
# Epoch 1115, Average Outcome Loss: 0.5870501101016998, Average Accuracy: 0.7109375, Test Accuracy: 0.707317054271698
# Epoch 1120, Average Outcome Loss: 0.45833219587802887, Average Accuracy: 0.84375, Test Accuracy: 0.7560975551605225
# Epoch 1125, Average Outcome Loss: 0.41881318390369415, Average Accuracy: 0.8203125, Test Accuracy: 0.7560975551605225
# Epoch 1130, Average Outcome Loss: 0.4639127850532532, Average Accuracy: 0.7890625, Test Accuracy: 0.7317073345184326
# Epoch 1135, Average Outcome Loss: 0.46758365631103516, Average Accuracy: 0.765625, Test Accuracy: 0.7560975551605225
# Epoch 1140, Average Outcome Loss: 0.39191681146621704, Average Accuracy: 0.890625, Test Accuracy: 0.7804877758026123
# Epoch 1145, Average Outcome Loss: 0.49148452281951904, Average Accuracy: 0.765625, Test Accuracy: 0.7560975551605225
# Epoch 1150, Average Outcome Loss: 0.4916655123233795, Average Accuracy: 0.765625, Test Accuracy: 0.707317054271698
# Epoch 1155, Average Outcome Loss: 0.48036201298236847, Average Accuracy: 0.78125, Test Accuracy: 0.7317073345184326
# Epoch 1160, Average Outcome Loss: 0.4261755496263504, Average Accuracy: 0.8203125, Test Accuracy: 0.707317054271698
# Epoch 1165, Average Outcome Loss: 0.4230964183807373, Average Accuracy: 0.8046875, Test Accuracy: 0.7560975551605225
# Epoch 1170, Average Outcome Loss: 0.4405957758426666, Average Accuracy: 0.8046875, Test Accuracy: 0.7804877758026123
# Epoch 1175, Average Outcome Loss: 0.4824722409248352, Average Accuracy: 0.765625, Test Accuracy: 0.7317073345184326
# Epoch 1180, Average Outcome Loss: 0.408988893032074, Average Accuracy: 0.84375, Test Accuracy: 0.7804877758026123
# Epoch 1185, Average Outcome Loss: 0.4475333243608475, Average Accuracy: 0.859375, Test Accuracy: 0.7560975551605225
# Epoch 1190, Average Outcome Loss: 0.510915145277977, Average Accuracy: 0.78125, Test Accuracy: 0.7560975551605225
# Epoch 1195, Average Outcome Loss: 0.4747626483440399, Average Accuracy: 0.8359375, Test Accuracy: 0.7560975551605225
# Epoch 1200, Average Outcome Loss: 0.43488286435604095, Average Accuracy: 0.84375, Test Accuracy: 0.7560975551605225
# Epoch 1205, Average Outcome Loss: 0.42634984850883484, Average Accuracy: 0.84375, Test Accuracy: 0.7560975551605225
# Epoch 1210, Average Outcome Loss: 0.4396635591983795, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 1215, Average Outcome Loss: 0.5288118869066238, Average Accuracy: 0.7421875, Test Accuracy: 0.7560975551605225
# Epoch 1220, Average Outcome Loss: 0.48477035760879517, Average Accuracy: 0.78125, Test Accuracy: 0.7560975551605225
# Epoch 1225, Average Outcome Loss: 0.42229725420475006, Average Accuracy: 0.8515625, Test Accuracy: 0.7560975551605225
# Epoch 1230, Average Outcome Loss: 0.3810981810092926, Average Accuracy: 0.859375, Test Accuracy: 0.7560975551605225
# Epoch 1235, Average Outcome Loss: 0.4486764967441559, Average Accuracy: 0.8125, Test Accuracy: 0.7560975551605225
# Epoch 1240, Average Outcome Loss: 0.41749030351638794, Average Accuracy: 0.8671875, Test Accuracy: 0.7560975551605225
# Epoch 1245, Average Outcome Loss: 0.48075513541698456, Average Accuracy: 0.796875, Test Accuracy: 0.7560975551605225
# Epoch 1250, Average Outcome Loss: 0.4885507673025131, Average Accuracy: 0.7578125, Test Accuracy: 0.7804877758026123
# Epoch 1255, Average Outcome Loss: 0.48968806862831116, Average Accuracy: 0.765625, Test Accuracy: 0.7804877758026123
# Epoch 1260, Average Outcome Loss: 0.47882598638534546, Average Accuracy: 0.75, Test Accuracy: 0.7560975551605225
# Epoch 1265, Average Outcome Loss: 0.4750692844390869, Average Accuracy: 0.8125, Test Accuracy: 0.707317054271698
# Epoch 1270, Average Outcome Loss: 0.4502342939376831, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 1275, Average Outcome Loss: 0.45236554741859436, Average Accuracy: 0.78125, Test Accuracy: 0.7804877758026123
# Epoch 1280, Average Outcome Loss: 0.4286949634552002, Average Accuracy: 0.8125, Test Accuracy: 0.7804877758026123
# Epoch 1285, Average Outcome Loss: 0.42132116854190826, Average Accuracy: 0.828125, Test Accuracy: 0.8048780560493469
# Epoch 1290, Average Outcome Loss: 0.43891599774360657, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 1295, Average Outcome Loss: 0.422779381275177, Average Accuracy: 0.8046875, Test Accuracy: 0.7560975551605225
# Epoch 1300, Average Outcome Loss: 0.39755387604236603, Average Accuracy: 0.8671875, Test Accuracy: 0.7560975551605225
# Epoch 1305, Average Outcome Loss: 0.48565056920051575, Average Accuracy: 0.78125, Test Accuracy: 0.7560975551605225
# Epoch 1310, Average Outcome Loss: 0.44442905485630035, Average Accuracy: 0.78125, Test Accuracy: 0.7560975551605225
# Epoch 1315, Average Outcome Loss: 0.46839290857315063, Average Accuracy: 0.78125, Test Accuracy: 0.7804877758026123
# Epoch 1320, Average Outcome Loss: 0.4548194110393524, Average Accuracy: 0.7890625, Test Accuracy: 0.7560975551605225
# Epoch 1325, Average Outcome Loss: 0.4913822412490845, Average Accuracy: 0.6953125, Test Accuracy: 0.7560975551605225
# Epoch 1330, Average Outcome Loss: 0.40536656975746155, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 1335, Average Outcome Loss: 0.4675360172986984, Average Accuracy: 0.796875, Test Accuracy: 0.7560975551605225
# Epoch 1340, Average Outcome Loss: 0.46635499596595764, Average Accuracy: 0.796875, Test Accuracy: 0.7804877758026123
# Epoch 1345, Average Outcome Loss: 0.3750953823328018, Average Accuracy: 0.8359375, Test Accuracy: 0.7804877758026123
# Epoch 1350, Average Outcome Loss: 0.3624165803194046, Average Accuracy: 0.859375, Test Accuracy: 0.7804877758026123
# Epoch 1355, Average Outcome Loss: 0.38930292427539825, Average Accuracy: 0.8671875, Test Accuracy: 0.7560975551605225
# Epoch 1360, Average Outcome Loss: 0.4521707743406296, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 1365, Average Outcome Loss: 0.43269628286361694, Average Accuracy: 0.8359375, Test Accuracy: 0.7560975551605225
# Epoch 1370, Average Outcome Loss: 0.41063618659973145, Average Accuracy: 0.8671875, Test Accuracy: 0.7804877758026123
# Epoch 1375, Average Outcome Loss: 0.40037521719932556, Average Accuracy: 0.84375, Test Accuracy: 0.7804877758026123
# Epoch 1380, Average Outcome Loss: 0.4921431392431259, Average Accuracy: 0.78125, Test Accuracy: 0.7804877758026123
# Epoch 1385, Average Outcome Loss: 0.5136299729347229, Average Accuracy: 0.71875, Test Accuracy: 0.7560975551605225
# Epoch 1390, Average Outcome Loss: 0.4193163365125656, Average Accuracy: 0.828125, Test Accuracy: 0.7317073345184326
# Epoch 1395, Average Outcome Loss: 0.5199814140796661, Average Accuracy: 0.6953125, Test Accuracy: 0.7317073345184326
# Epoch 1400, Average Outcome Loss: 0.4224304109811783, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 1405, Average Outcome Loss: 0.4331224709749222, Average Accuracy: 0.859375, Test Accuracy: 0.7804877758026123
# Epoch 1410, Average Outcome Loss: 0.39005783200263977, Average Accuracy: 0.890625, Test Accuracy: 0.7804877758026123
# Epoch 1415, Average Outcome Loss: 0.4676177054643631, Average Accuracy: 0.7890625, Test Accuracy: 0.7804877758026123
# Epoch 1420, Average Outcome Loss: 0.4258453845977783, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 1425, Average Outcome Loss: 0.39477208256721497, Average Accuracy: 0.84375, Test Accuracy: 0.7317073345184326
# Epoch 1430, Average Outcome Loss: 0.4162665456533432, Average Accuracy: 0.8671875, Test Accuracy: 0.7804877758026123
# Epoch 1435, Average Outcome Loss: 0.45568010210990906, Average Accuracy: 0.8046875, Test Accuracy: 0.7804877758026123
# Epoch 1440, Average Outcome Loss: 0.47574880719184875, Average Accuracy: 0.7734375, Test Accuracy: 0.8048780560493469
# Epoch 1445, Average Outcome Loss: 0.39511623978614807, Average Accuracy: 0.8515625, Test Accuracy: 0.7804877758026123
# Epoch 1450, Average Outcome Loss: 0.4660390615463257, Average Accuracy: 0.8125, Test Accuracy: 0.7804877758026123
# Epoch 1455, Average Outcome Loss: 0.5085448920726776, Average Accuracy: 0.75, Test Accuracy: 0.7804877758026123
# Epoch 1460, Average Outcome Loss: 0.5497948825359344, Average Accuracy: 0.7265625, Test Accuracy: 0.7560975551605225
# Epoch 1465, Average Outcome Loss: 0.4953303933143616, Average Accuracy: 0.8203125, Test Accuracy: 0.7317073345184326
# Epoch 1470, Average Outcome Loss: 0.4521930664777756, Average Accuracy: 0.75, Test Accuracy: 0.7317073345184326
# Epoch 1475, Average Outcome Loss: 0.4185377359390259, Average Accuracy: 0.8515625, Test Accuracy: 0.7560975551605225
# Epoch 1480, Average Outcome Loss: 0.42294205725193024, Average Accuracy: 0.8515625, Test Accuracy: 0.7804877758026123
# Epoch 1485, Average Outcome Loss: 0.5182791352272034, Average Accuracy: 0.6875, Test Accuracy: 0.7804877758026123
# Epoch 1490, Average Outcome Loss: 0.46644964814186096, Average Accuracy: 0.796875, Test Accuracy: 0.7804877758026123
# Epoch 1495, Average Outcome Loss: 0.4208708256483078, Average Accuracy: 0.8359375, Test Accuracy: 0.7804877758026123
# Epoch 1500, Average Outcome Loss: 0.32474127411842346, Average Accuracy: 0.890625, Test Accuracy: 0.7804877758026123
# Epoch 1505, Average Outcome Loss: 0.5004440248012543, Average Accuracy: 0.7421875, Test Accuracy: 0.7804877758026123
# Epoch 1510, Average Outcome Loss: 0.3965916335582733, Average Accuracy: 0.8203125, Test Accuracy: 0.7804877758026123
# Epoch 1515, Average Outcome Loss: 0.43980690836906433, Average Accuracy: 0.765625, Test Accuracy: 0.7804877758026123
# Epoch 1520, Average Outcome Loss: 0.49316614866256714, Average Accuracy: 0.7578125, Test Accuracy: 0.8048780560493469
# Epoch 1525, Average Outcome Loss: 0.44411274790763855, Average Accuracy: 0.8046875, Test Accuracy: 0.7804877758026123
# Epoch 1530, Average Outcome Loss: 0.44329734146595, Average Accuracy: 0.7734375, Test Accuracy: 0.7804877758026123
# Epoch 1535, Average Outcome Loss: 0.4229601174592972, Average Accuracy: 0.828125, Test Accuracy: 0.7804877758026123
# Epoch 1540, Average Outcome Loss: 0.42867501080036163, Average Accuracy: 0.8125, Test Accuracy: 0.7804877758026123
# Epoch 1545, Average Outcome Loss: 0.5125845670700073, Average Accuracy: 0.7421875, Test Accuracy: 0.7804877758026123
# Epoch 1550, Average Outcome Loss: 0.4962772727012634, Average Accuracy: 0.78125, Test Accuracy: 0.7804877758026123
# Epoch 1555, Average Outcome Loss: 0.4396522343158722, Average Accuracy: 0.8515625, Test Accuracy: 0.7804877758026123
# Epoch 1560, Average Outcome Loss: 0.4469732642173767, Average Accuracy: 0.8203125, Test Accuracy: 0.7560975551605225
# Epoch 1565, Average Outcome Loss: 0.43831172585487366, Average Accuracy: 0.8359375, Test Accuracy: 0.7317073345184326
# Epoch 1570, Average Outcome Loss: 0.4441922754049301, Average Accuracy: 0.8125, Test Accuracy: 0.7560975551605225
# Epoch 1575, Average Outcome Loss: 0.4882165938615799, Average Accuracy: 0.765625, Test Accuracy: 0.7804877758026123
# Epoch 1580, Average Outcome Loss: 0.3472500443458557, Average Accuracy: 0.8515625, Test Accuracy: 0.7804877758026123
# Epoch 1585, Average Outcome Loss: 0.5129031091928482, Average Accuracy: 0.7734375, Test Accuracy: 0.7804877758026123
# Epoch 1590, Average Outcome Loss: 0.37103186547756195, Average Accuracy: 0.8359375, Test Accuracy: 0.7804877758026123
# Epoch 1595, Average Outcome Loss: 0.4475947618484497, Average Accuracy: 0.8203125, Test Accuracy: 0.7804877758026123
# Epoch 1600, Average Outcome Loss: 0.4207571744918823, Average Accuracy: 0.8046875, Test Accuracy: 0.7804877758026123
# Epoch 1605, Average Outcome Loss: 0.42295026779174805, Average Accuracy: 0.8046875, Test Accuracy: 0.7804877758026123
# Epoch 1610, Average Outcome Loss: 0.3838008642196655, Average Accuracy: 0.8359375, Test Accuracy: 0.7804877758026123
# Epoch 1615, Average Outcome Loss: 0.4096696227788925, Average Accuracy: 0.8359375, Test Accuracy: 0.7804877758026123
# Epoch 1620, Average Outcome Loss: 0.38703081011772156, Average Accuracy: 0.8359375, Test Accuracy: 0.7804877758026123
# Epoch 1625, Average Outcome Loss: 0.4586522579193115, Average Accuracy: 0.7890625, Test Accuracy: 0.7804877758026123
# Epoch 1630, Average Outcome Loss: 0.44849102199077606, Average Accuracy: 0.8046875, Test Accuracy: 0.7804877758026123
# Epoch 1635, Average Outcome Loss: 0.4503163546323776, Average Accuracy: 0.78125, Test Accuracy: 0.7804877758026123
# Epoch 1640, Average Outcome Loss: 0.38377808034420013, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 1645, Average Outcome Loss: 0.3338569849729538, Average Accuracy: 0.8984375, Test Accuracy: 0.7804877758026123
# Epoch 1650, Average Outcome Loss: 0.3527463674545288, Average Accuracy: 0.8515625, Test Accuracy: 0.7804877758026123
# Epoch 1655, Average Outcome Loss: 0.40130989253520966, Average Accuracy: 0.8203125, Test Accuracy: 0.7804877758026123
# Epoch 1660, Average Outcome Loss: 0.3988221287727356, Average Accuracy: 0.828125, Test Accuracy: 0.7804877758026123
# Epoch 1665, Average Outcome Loss: 0.3880975991487503, Average Accuracy: 0.8359375, Test Accuracy: 0.7804877758026123
# Epoch 1670, Average Outcome Loss: 0.36455050110816956, Average Accuracy: 0.875, Test Accuracy: 0.7804877758026123
# Epoch 1675, Average Outcome Loss: 0.3514726608991623, Average Accuracy: 0.90625, Test Accuracy: 0.7804877758026123
# Epoch 1680, Average Outcome Loss: 0.4371354728937149, Average Accuracy: 0.828125, Test Accuracy: 0.7804877758026123
# Epoch 1685, Average Outcome Loss: 0.3812365084886551, Average Accuracy: 0.8515625, Test Accuracy: 0.7804877758026123
# Epoch 1690, Average Outcome Loss: 0.3842410147190094, Average Accuracy: 0.84375, Test Accuracy: 0.7804877758026123
# Epoch 1695, Average Outcome Loss: 0.37090399861335754, Average Accuracy: 0.890625, Test Accuracy: 0.7804877758026123
# Epoch 1700, Average Outcome Loss: 0.44251199066638947, Average Accuracy: 0.828125, Test Accuracy: 0.7804877758026123
# Epoch 1705, Average Outcome Loss: 0.34740251302719116, Average Accuracy: 0.875, Test Accuracy: 0.7804877758026123
# Epoch 1710, Average Outcome Loss: 0.49593669176101685, Average Accuracy: 0.71875, Test Accuracy: 0.7804877758026123
# Epoch 1715, Average Outcome Loss: 0.4105837941169739, Average Accuracy: 0.8515625, Test Accuracy: 0.7804877758026123
# Epoch 1720, Average Outcome Loss: 0.44792842864990234, Average Accuracy: 0.8046875, Test Accuracy: 0.7804877758026123
# Epoch 1725, Average Outcome Loss: 0.4017413407564163, Average Accuracy: 0.84375, Test Accuracy: 0.7804877758026123
# Epoch 1730, Average Outcome Loss: 0.44134385883808136, Average Accuracy: 0.828125, Test Accuracy: 0.7804877758026123
# Epoch 1735, Average Outcome Loss: 0.37257567048072815, Average Accuracy: 0.859375, Test Accuracy: 0.7804877758026123
# Epoch 1740, Average Outcome Loss: 0.3638802170753479, Average Accuracy: 0.8828125, Test Accuracy: 0.7804877758026123
# Epoch 1745, Average Outcome Loss: 0.41048775613307953, Average Accuracy: 0.78125, Test Accuracy: 0.7804877758026123
# Epoch 1750, Average Outcome Loss: 0.3942326456308365, Average Accuracy: 0.828125, Test Accuracy: 0.7804877758026123
# Epoch 1755, Average Outcome Loss: 0.49891553819179535, Average Accuracy: 0.6875, Test Accuracy: 0.7804877758026123
# Epoch 1760, Average Outcome Loss: 0.46130941808223724, Average Accuracy: 0.7890625, Test Accuracy: 0.7804877758026123
# Epoch 1765, Average Outcome Loss: 0.42459042370319366, Average Accuracy: 0.7890625, Test Accuracy: 0.7804877758026123
# Epoch 1770, Average Outcome Loss: 0.37130820751190186, Average Accuracy: 0.8671875, Test Accuracy: 0.7804877758026123
# Epoch 1775, Average Outcome Loss: 0.4598247855901718, Average Accuracy: 0.7890625, Test Accuracy: 0.7804877758026123
# Epoch 1780, Average Outcome Loss: 0.38219986855983734, Average Accuracy: 0.8359375, Test Accuracy: 0.7804877758026123
# Epoch 1785, Average Outcome Loss: 0.3527000844478607, Average Accuracy: 0.890625, Test Accuracy: 0.7804877758026123
# Epoch 1790, Average Outcome Loss: 0.33794981241226196, Average Accuracy: 0.8671875, Test Accuracy: 0.7804877758026123
# Epoch 1795, Average Outcome Loss: 0.3728588819503784, Average Accuracy: 0.8671875, Test Accuracy: 0.7804877758026123
# Epoch 1800, Average Outcome Loss: 0.4127284735441208, Average Accuracy: 0.828125, Test Accuracy: 0.7804877758026123
# Epoch 1805, Average Outcome Loss: 0.38446497917175293, Average Accuracy: 0.8515625, Test Accuracy: 0.7804877758026123
# Epoch 1810, Average Outcome Loss: 0.36289170384407043, Average Accuracy: 0.859375, Test Accuracy: 0.7804877758026123
# Epoch 1815, Average Outcome Loss: 0.39143505692481995, Average Accuracy: 0.84375, Test Accuracy: 0.7804877758026123
# Epoch 1820, Average Outcome Loss: 0.374926894903183, Average Accuracy: 0.84375, Test Accuracy: 0.7804877758026123
# Epoch 1825, Average Outcome Loss: 0.44097059965133667, Average Accuracy: 0.7578125, Test Accuracy: 0.7804877758026123
# Epoch 1830, Average Outcome Loss: 0.38409513235092163, Average Accuracy: 0.828125, Test Accuracy: 0.7804877758026123
# Epoch 1835, Average Outcome Loss: 0.43178482353687286, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 1840, Average Outcome Loss: 0.41646139323711395, Average Accuracy: 0.8515625, Test Accuracy: 0.7560975551605225
# Epoch 1845, Average Outcome Loss: 0.36957956850528717, Average Accuracy: 0.875, Test Accuracy: 0.8048780560493469
# Epoch 1850, Average Outcome Loss: 0.444377139210701, Average Accuracy: 0.7734375, Test Accuracy: 0.7804877758026123
# Epoch 1855, Average Outcome Loss: 0.3827028274536133, Average Accuracy: 0.859375, Test Accuracy: 0.8048780560493469
# Epoch 1860, Average Outcome Loss: 0.38745008409023285, Average Accuracy: 0.8671875, Test Accuracy: 0.7560975551605225
# Epoch 1865, Average Outcome Loss: 0.43818265199661255, Average Accuracy: 0.8359375, Test Accuracy: 0.7560975551605225
# Epoch 1870, Average Outcome Loss: 0.39459042251110077, Average Accuracy: 0.796875, Test Accuracy: 0.7804877758026123
# Epoch 1875, Average Outcome Loss: 0.3271666169166565, Average Accuracy: 0.8984375, Test Accuracy: 0.7804877758026123
# Epoch 1880, Average Outcome Loss: 0.39231812953948975, Average Accuracy: 0.828125, Test Accuracy: 0.7804877758026123
# Epoch 1885, Average Outcome Loss: 0.42148517072200775, Average Accuracy: 0.828125, Test Accuracy: 0.7804877758026123
# Epoch 1890, Average Outcome Loss: 0.4524714946746826, Average Accuracy: 0.7890625, Test Accuracy: 0.7804877758026123
# Epoch 1895, Average Outcome Loss: 0.4118916541337967, Average Accuracy: 0.828125, Test Accuracy: 0.7560975551605225
# Epoch 1900, Average Outcome Loss: 0.3908938765525818, Average Accuracy: 0.875, Test Accuracy: 0.7804877758026123
# Epoch 1905, Average Outcome Loss: 0.3652217835187912, Average Accuracy: 0.90625, Test Accuracy: 0.7804877758026123
# Epoch 1910, Average Outcome Loss: 0.40667441487312317, Average Accuracy: 0.859375, Test Accuracy: 0.7804877758026123
# Epoch 1915, Average Outcome Loss: 0.36492860317230225, Average Accuracy: 0.8359375, Test Accuracy: 0.7804877758026123
# Epoch 1920, Average Outcome Loss: 0.39407363533973694, Average Accuracy: 0.828125, Test Accuracy: 0.7804877758026123
# Epoch 1925, Average Outcome Loss: 0.39490872621536255, Average Accuracy: 0.84375, Test Accuracy: 0.7804877758026123
# Epoch 1930, Average Outcome Loss: 0.38964828848838806, Average Accuracy: 0.8828125, Test Accuracy: 0.7804877758026123
# Epoch 1935, Average Outcome Loss: 0.36401669681072235, Average Accuracy: 0.828125, Test Accuracy: 0.7804877758026123
# Epoch 1940, Average Outcome Loss: 0.3903844654560089, Average Accuracy: 0.875, Test Accuracy: 0.7804877758026123
# Epoch 1945, Average Outcome Loss: 0.3409837782382965, Average Accuracy: 0.8359375, Test Accuracy: 0.7804877758026123
# Epoch 1950, Average Outcome Loss: 0.39574888348579407, Average Accuracy: 0.8203125, Test Accuracy: 0.7804877758026123
# Epoch 1955, Average Outcome Loss: 0.36822520196437836, Average Accuracy: 0.84375, Test Accuracy: 0.7804877758026123
# Epoch 1960, Average Outcome Loss: 0.3989107757806778, Average Accuracy: 0.8125, Test Accuracy: 0.8048780560493469
# Epoch 1965, Average Outcome Loss: 0.4349900186061859, Average Accuracy: 0.78125, Test Accuracy: 0.8048780560493469
# Epoch 1970, Average Outcome Loss: 0.3732272684574127, Average Accuracy: 0.859375, Test Accuracy: 0.7804877758026123
# Epoch 1975, Average Outcome Loss: 0.4393277019262314, Average Accuracy: 0.8046875, Test Accuracy: 0.7804877758026123
# Epoch 1980, Average Outcome Loss: 0.3524758815765381, Average Accuracy: 0.9140625, Test Accuracy: 0.7804877758026123
# Epoch 1985, Average Outcome Loss: 0.39012643694877625, Average Accuracy: 0.859375, Test Accuracy: 0.7804877758026123
# Epoch 1990, Average Outcome Loss: 0.35900214314460754, Average Accuracy: 0.890625, Test Accuracy: 0.8048780560493469
# Epoch 1995, Average Outcome Loss: 0.34825222194194794, Average Accuracy: 0.859375, Test Accuracy: 0.7804877758026123
# Epoch 2000, Average Outcome Loss: 0.40610355138778687, Average Accuracy: 0.8359375, Test Accuracy: 0.7804877758026123
# Epoch 2005, Average Outcome Loss: 0.4047931730747223, Average Accuracy: 0.8359375, Test Accuracy: 0.7804877758026123
# Epoch 2010, Average Outcome Loss: 0.28225134313106537, Average Accuracy: 0.9453125, Test Accuracy: 0.7804877758026123
# Epoch 2015, Average Outcome Loss: 0.3941532373428345, Average Accuracy: 0.859375, Test Accuracy: 0.7804877758026123
# Epoch 2020, Average Outcome Loss: 0.3970889151096344, Average Accuracy: 0.859375, Test Accuracy: 0.7560975551605225
# Epoch 2025, Average Outcome Loss: 0.3769335448741913, Average Accuracy: 0.8515625, Test Accuracy: 0.7560975551605225
# Epoch 2030, Average Outcome Loss: 0.3805035650730133, Average Accuracy: 0.8828125, Test Accuracy: 0.7804877758026123
# Epoch 2035, Average Outcome Loss: 0.3698473274707794, Average Accuracy: 0.84375, Test Accuracy: 0.7804877758026123
# Epoch 2040, Average Outcome Loss: 0.418207511305809, Average Accuracy: 0.8125, Test Accuracy: 0.7804877758026123
# Epoch 2045, Average Outcome Loss: 0.3494042307138443, Average Accuracy: 0.875, Test Accuracy: 0.7560975551605225
# Epoch 2050, Average Outcome Loss: 0.3417086899280548, Average Accuracy: 0.875, Test Accuracy: 0.7560975551605225
# Epoch 2055, Average Outcome Loss: 0.3862698972225189, Average Accuracy: 0.8359375, Test Accuracy: 0.7804877758026123
# ...
# Epoch 820, Average Outcome Loss: 0.5156232714653015, Average Accuracy: 0.8046875, Test Accuracy: 0.6829268336296082
# Epoch 825, Average Outcome Loss: 0.54119473695755, Average Accuracy: 0.7734375, Test Accuracy: 0.707317054271698
# Epoch 830, Average Outcome Loss: 0.46919339895248413, Average Accuracy: 0.84375, Test Accuracy: 0.707317054271698
# Epoch 835, Average Outcome Loss: 0.536279559135437, Average Accuracy: 0.796875, Test Accuracy: 0.707317054271698
# Epoch 840, Average Outcome Loss: 0.5572758615016937, Average Accuracy: 0.765625, Test Accuracy: 0.707317054271698
# Epoch 845, Average Outcome Loss: 0.4851491153240204, Average Accuracy: 0.8359375, Test Accuracy: 0.707317054271698
# Epoch 850, Average Outcome Loss: 0.4848802983760834, Average Accuracy: 0.84375, Test Accuracy: 0.707317054271698
# Epoch 855, Average Outcome Loss: 0.4714820981025696, Average Accuracy: 0.8359375, Test Accuracy: 0.707317054271698
# Epoch 860, Average Outcome Loss: 0.5566940456628799, Average Accuracy: 0.703125, Test Accuracy: 0.707317054271698
# Epoch 865, Average Outcome Loss: 0.47406862676143646, Average Accuracy: 0.875, Test Accuracy: 0.7317073345184326
# Epoch 870, Average Outcome Loss: 0.4878835380077362, Average Accuracy: 0.8359375, Test Accuracy: 0.7317073345184326
# Epoch 875, Average Outcome Loss: 0.5160902142524719, Average Accuracy: 0.7890625, Test Accuracy: 0.7317073345184326
# Epoch 880, Average Outcome Loss: 0.5600212514400482, Average Accuracy: 0.7734375, Test Accuracy: 0.6829268336296082
# Epoch 885, Average Outcome Loss: 0.4894445538520813, Average Accuracy: 0.8125, Test Accuracy: 0.6829268336296082
# Epoch 890, Average Outcome Loss: 0.5861600041389465, Average Accuracy: 0.7265625, Test Accuracy: 0.6829268336296082
# Epoch 895, Average Outcome Loss: 0.5400007963180542, Average Accuracy: 0.796875, Test Accuracy: 0.6829268336296082
# Epoch 900, Average Outcome Loss: 0.5241895616054535, Average Accuracy: 0.796875, Test Accuracy: 0.707317054271698
# Epoch 905, Average Outcome Loss: 0.4761655777692795, Average Accuracy: 0.8515625, Test Accuracy: 0.707317054271698
# Epoch 910, Average Outcome Loss: 0.5288138687610626, Average Accuracy: 0.7890625, Test Accuracy: 0.7317073345184326
# Epoch 915, Average Outcome Loss: 0.5532200038433075, Average Accuracy: 0.765625, Test Accuracy: 0.707317054271698
# Epoch 920, Average Outcome Loss: 0.5355871915817261, Average Accuracy: 0.78125, Test Accuracy: 0.707317054271698
# Epoch 925, Average Outcome Loss: 0.5201797932386398, Average Accuracy: 0.8046875, Test Accuracy: 0.707317054271698
# Epoch 930, Average Outcome Loss: 0.4840957075357437, Average Accuracy: 0.8203125, Test Accuracy: 0.6829268336296082
# Epoch 935, Average Outcome Loss: 0.4812188148498535, Average Accuracy: 0.828125, Test Accuracy: 0.707317054271698
# Epoch 940, Average Outcome Loss: 0.5265381932258606, Average Accuracy: 0.7734375, Test Accuracy: 0.707317054271698
# Epoch 945, Average Outcome Loss: 0.5283910930156708, Average Accuracy: 0.75, Test Accuracy: 0.7317073345184326
# Epoch 950, Average Outcome Loss: 0.5628758072853088, Average Accuracy: 0.78125, Test Accuracy: 0.7317073345184326
# Epoch 955, Average Outcome Loss: 0.5319575071334839, Average Accuracy: 0.78125, Test Accuracy: 0.7317073345184326
# Epoch 960, Average Outcome Loss: 0.5620073974132538, Average Accuracy: 0.78125, Test Accuracy: 0.7317073345184326
# Epoch 965, Average Outcome Loss: 0.5254214257001877, Average Accuracy: 0.78125, Test Accuracy: 0.707317054271698
# Epoch 970, Average Outcome Loss: 0.5389389097690582, Average Accuracy: 0.78125, Test Accuracy: 0.707317054271698
# Epoch 975, Average Outcome Loss: 0.5453242659568787, Average Accuracy: 0.75, Test Accuracy: 0.6829268336296082
# Epoch 980, Average Outcome Loss: 0.5184321850538254, Average Accuracy: 0.8046875, Test Accuracy: 0.707317054271698
# Epoch 985, Average Outcome Loss: 0.519617035984993, Average Accuracy: 0.7890625, Test Accuracy: 0.707317054271698
# Epoch 990, Average Outcome Loss: 0.5294876396656036, Average Accuracy: 0.7734375, Test Accuracy: 0.707317054271698
# Epoch 995, Average Outcome Loss: 0.5407448410987854, Average Accuracy: 0.78125, Test Accuracy: 0.707317054271698
# Epoch 1000, Average Outcome Loss: 0.5449848175048828, Average Accuracy: 0.7890625, Test Accuracy: 0.7317073345184326
# Epoch 1005, Average Outcome Loss: 0.5169276595115662, Average Accuracy: 0.7890625, Test Accuracy: 0.7317073345184326
# Epoch 1010, Average Outcome Loss: 0.5452290177345276, Average Accuracy: 0.765625, Test Accuracy: 0.707317054271698
# Epoch 1015, Average Outcome Loss: 0.5565751194953918, Average Accuracy: 0.78125, Test Accuracy: 0.707317054271698
# Epoch 1020, Average Outcome Loss: 0.5502906143665314, Average Accuracy: 0.7734375, Test Accuracy: 0.707317054271698
# Epoch 1025, Average Outcome Loss: 0.47775591909885406, Average Accuracy: 0.859375, Test Accuracy: 0.707317054271698
# Epoch 1030, Average Outcome Loss: 0.5855425894260406, Average Accuracy: 0.765625, Test Accuracy: 0.707317054271698
# Epoch 1035, Average Outcome Loss: 0.5090925693511963, Average Accuracy: 0.859375, Test Accuracy: 0.7317073345184326
# Epoch 1040, Average Outcome Loss: 0.4608914256095886, Average Accuracy: 0.8203125, Test Accuracy: 0.707317054271698
# Epoch 1045, Average Outcome Loss: 0.5190678238868713, Average Accuracy: 0.7734375, Test Accuracy: 0.707317054271698
# Epoch 1050, Average Outcome Loss: 0.4578956663608551, Average Accuracy: 0.8671875, Test Accuracy: 0.6829268336296082
# Epoch 1055, Average Outcome Loss: 0.5516017377376556, Average Accuracy: 0.75, Test Accuracy: 0.707317054271698
# Epoch 1060, Average Outcome Loss: 0.4949769526720047, Average Accuracy: 0.7734375, Test Accuracy: 0.6829268336296082
# Epoch 1065, Average Outcome Loss: 0.5490414798259735, Average Accuracy: 0.7734375, Test Accuracy: 0.707317054271698
# Epoch 1070, Average Outcome Loss: 0.5507781803607941, Average Accuracy: 0.7734375, Test Accuracy: 0.707317054271698
# Epoch 1075, Average Outcome Loss: 0.6203491985797882, Average Accuracy: 0.6796875, Test Accuracy: 0.7317073345184326
# Epoch 1080, Average Outcome Loss: 0.5695239007472992, Average Accuracy: 0.7109375, Test Accuracy: 0.7317073345184326
# Epoch 1085, Average Outcome Loss: 0.5365609526634216, Average Accuracy: 0.7734375, Test Accuracy: 0.707317054271698
# Epoch 1090, Average Outcome Loss: 0.5414082705974579, Average Accuracy: 0.7421875, Test Accuracy: 0.707317054271698
# Epoch 1095, Average Outcome Loss: 0.5108303725719452, Average Accuracy: 0.8125, Test Accuracy: 0.707317054271698
# Epoch 1100, Average Outcome Loss: 0.47746041417121887, Average Accuracy: 0.8515625, Test Accuracy: 0.707317054271698
# Epoch 1105, Average Outcome Loss: 0.5325242280960083, Average Accuracy: 0.796875, Test Accuracy: 0.707317054271698
# Epoch 1110, Average Outcome Loss: 0.5031754374504089, Average Accuracy: 0.8203125, Test Accuracy: 0.7317073345184326
# Epoch 1115, Average Outcome Loss: 0.47395914793014526, Average Accuracy: 0.8515625, Test Accuracy: 0.707317054271698
# Epoch 1120, Average Outcome Loss: 0.4931233823299408, Average Accuracy: 0.8046875, Test Accuracy: 0.707317054271698
# Epoch 1125, Average Outcome Loss: 0.4567987024784088, Average Accuracy: 0.84375, Test Accuracy: 0.707317054271698
# Epoch 1130, Average Outcome Loss: 0.47761112451553345, Average Accuracy: 0.84375, Test Accuracy: 0.6829268336296082
# Epoch 1135, Average Outcome Loss: 0.4745267778635025, Average Accuracy: 0.8125, Test Accuracy: 0.6829268336296082
# Epoch 1140, Average Outcome Loss: 0.49559830129146576, Average Accuracy: 0.8125, Test Accuracy: 0.6829268336296082
# Epoch 1145, Average Outcome Loss: 0.541976124048233, Average Accuracy: 0.765625, Test Accuracy: 0.7317073345184326
# Epoch 1150, Average Outcome Loss: 0.542347639799118, Average Accuracy: 0.765625, Test Accuracy: 0.7317073345184326
# Epoch 1155, Average Outcome Loss: 0.4990512728691101, Average Accuracy: 0.78125, Test Accuracy: 0.7317073345184326
# Epoch 1160, Average Outcome Loss: 0.5338779091835022, Average Accuracy: 0.8046875, Test Accuracy: 0.7317073345184326
# Epoch 1165, Average Outcome Loss: 0.46125493943691254, Average Accuracy: 0.84375, Test Accuracy: 0.6829268336296082
# Epoch 1170, Average Outcome Loss: 0.49320515990257263, Average Accuracy: 0.796875, Test Accuracy: 0.707317054271698
# Epoch 1175, Average Outcome Loss: 0.5139068961143494, Average Accuracy: 0.796875, Test Accuracy: 0.6829268336296082
# Epoch 1180, Average Outcome Loss: 0.5087295025587082, Average Accuracy: 0.765625, Test Accuracy: 0.707317054271698
# Epoch 1185, Average Outcome Loss: 0.5498741865158081, Average Accuracy: 0.7890625, Test Accuracy: 0.707317054271698
# Epoch 1190, Average Outcome Loss: 0.5627221167087555, Average Accuracy: 0.765625, Test Accuracy: 0.7317073345184326
# Epoch 1195, Average Outcome Loss: 0.47661900520324707, Average Accuracy: 0.8203125, Test Accuracy: 0.7317073345184326
# Epoch 1200, Average Outcome Loss: 0.5028396844863892, Average Accuracy: 0.8046875, Test Accuracy: 0.707317054271698
# Epoch 1205, Average Outcome Loss: 0.5330303609371185, Average Accuracy: 0.8046875, Test Accuracy: 0.6829268336296082
# Epoch 1210, Average Outcome Loss: 0.38720519840717316, Average Accuracy: 0.9140625, Test Accuracy: 0.6829268336296082
# Epoch 1215, Average Outcome Loss: 0.5144607126712799, Average Accuracy: 0.7890625, Test Accuracy: 0.6829268336296082
# Epoch 1220, Average Outcome Loss: 0.4578065276145935, Average Accuracy: 0.8359375, Test Accuracy: 0.6829268336296082
# Epoch 1225, Average Outcome Loss: 0.5260862112045288, Average Accuracy: 0.78125, Test Accuracy: 0.707317054271698
# Epoch 1230, Average Outcome Loss: 0.500170037150383, Average Accuracy: 0.78125, Test Accuracy: 0.707317054271698
# Epoch 1235, Average Outcome Loss: 0.4757731258869171, Average Accuracy: 0.8125, Test Accuracy: 0.707317054271698
# Epoch 1240, Average Outcome Loss: 0.5428181290626526, Average Accuracy: 0.7421875, Test Accuracy: 0.7317073345184326
# Epoch 1245, Average Outcome Loss: 0.558428555727005, Average Accuracy: 0.7109375, Test Accuracy: 0.7317073345184326
# Epoch 1250, Average Outcome Loss: 0.5593035817146301, Average Accuracy: 0.7578125, Test Accuracy: 0.7317073345184326
# Epoch 1255, Average Outcome Loss: 0.4615478068590164, Average Accuracy: 0.828125, Test Accuracy: 0.707317054271698
# Epoch 1260, Average Outcome Loss: 0.5044927895069122, Average Accuracy: 0.7734375, Test Accuracy: 0.707317054271698
# Epoch 1265, Average Outcome Loss: 0.5406952053308487, Average Accuracy: 0.7421875, Test Accuracy: 0.707317054271698
# Epoch 1270, Average Outcome Loss: 0.4926513582468033, Average Accuracy: 0.8203125, Test Accuracy: 0.707317054271698
# Epoch 1275, Average Outcome Loss: 0.5073535293340683, Average Accuracy: 0.8203125, Test Accuracy: 0.6829268336296082
# Epoch 1280, Average Outcome Loss: 0.5290943384170532, Average Accuracy: 0.796875, Test Accuracy: 0.6829268336296082
# Epoch 1285, Average Outcome Loss: 0.49399474263191223, Average Accuracy: 0.7734375, Test Accuracy: 0.6829268336296082
# Epoch 1290, Average Outcome Loss: 0.5961162149906158, Average Accuracy: 0.734375, Test Accuracy: 0.6829268336296082
# Epoch 1295, Average Outcome Loss: 0.5136510729789734, Average Accuracy: 0.8125, Test Accuracy: 0.6829268336296082
# Epoch 1300, Average Outcome Loss: 0.4793209731578827, Average Accuracy: 0.8125, Test Accuracy: 0.707317054271698
# Epoch 1305, Average Outcome Loss: 0.42868107557296753, Average Accuracy: 0.8515625, Test Accuracy: 0.7317073345184326
# Epoch 1310, Average Outcome Loss: 0.49105510115623474, Average Accuracy: 0.828125, Test Accuracy: 0.7317073345184326
# Epoch 1315, Average Outcome Loss: 0.5054431557655334, Average Accuracy: 0.796875, Test Accuracy: 0.7317073345184326
# Epoch 1320, Average Outcome Loss: 0.46244189143180847, Average Accuracy: 0.828125, Test Accuracy: 0.707317054271698
# Epoch 1325, Average Outcome Loss: 0.4730100780725479, Average Accuracy: 0.796875, Test Accuracy: 0.707317054271698
# Epoch 1330, Average Outcome Loss: 0.45107895135879517, Average Accuracy: 0.8515625, Test Accuracy: 0.707317054271698
# Epoch 1335, Average Outcome Loss: 0.4810345023870468, Average Accuracy: 0.828125, Test Accuracy: 0.707317054271698
# Epoch 1340, Average Outcome Loss: 0.573962539434433, Average Accuracy: 0.7578125, Test Accuracy: 0.6829268336296082
# Epoch 1345, Average Outcome Loss: 0.45794689655303955, Average Accuracy: 0.8203125, Test Accuracy: 0.707317054271698
# Epoch 1350, Average Outcome Loss: 0.4759795516729355, Average Accuracy: 0.828125, Test Accuracy: 0.707317054271698
# Epoch 1355, Average Outcome Loss: 0.494365930557251, Average Accuracy: 0.78125, Test Accuracy: 0.707317054271698
# Epoch 1360, Average Outcome Loss: 0.47015851736068726, Average Accuracy: 0.7890625, Test Accuracy: 0.707317054271698
# Epoch 1365, Average Outcome Loss: 0.5008753091096878, Average Accuracy: 0.7890625, Test Accuracy: 0.6829268336296082
# Epoch 1370, Average Outcome Loss: 0.5041614025831223, Average Accuracy: 0.78125, Test Accuracy: 0.6829268336296082
# Epoch 1375, Average Outcome Loss: 0.4106266498565674, Average Accuracy: 0.890625, Test Accuracy: 0.6829268336296082
# Epoch 1380, Average Outcome Loss: 0.42285075783729553, Average Accuracy: 0.859375, Test Accuracy: 0.6829268336296082
# Epoch 1385, Average Outcome Loss: 0.49684764444828033, Average Accuracy: 0.8125, Test Accuracy: 0.6829268336296082
# Epoch 1390, Average Outcome Loss: 0.4759462922811508, Average Accuracy: 0.796875, Test Accuracy: 0.6829268336296082
# Epoch 1395, Average Outcome Loss: 0.5077703595161438, Average Accuracy: 0.7734375, Test Accuracy: 0.707317054271698
# Epoch 1400, Average Outcome Loss: 0.5101941823959351, Average Accuracy: 0.796875, Test Accuracy: 0.7560975551605225
# Epoch 1405, Average Outcome Loss: 0.48306265473365784, Average Accuracy: 0.7890625, Test Accuracy: 0.7560975551605225
# Epoch 1410, Average Outcome Loss: 0.4526282846927643, Average Accuracy: 0.828125, Test Accuracy: 0.7317073345184326
# Epoch 1415, Average Outcome Loss: 0.48163019120693207, Average Accuracy: 0.78125, Test Accuracy: 0.707317054271698
# Epoch 1420, Average Outcome Loss: 0.5001165866851807, Average Accuracy: 0.8046875, Test Accuracy: 0.7317073345184326
# Epoch 1425, Average Outcome Loss: 0.5172840654850006, Average Accuracy: 0.7421875, Test Accuracy: 0.7560975551605225
# Epoch 1430, Average Outcome Loss: 0.4560414105653763, Average Accuracy: 0.84375, Test Accuracy: 0.7560975551605225
# Epoch 1435, Average Outcome Loss: 0.3924972712993622, Average Accuracy: 0.8828125, Test Accuracy: 0.7317073345184326
# Epoch 1440, Average Outcome Loss: 0.5515888631343842, Average Accuracy: 0.7265625, Test Accuracy: 0.6829268336296082
# Epoch 1445, Average Outcome Loss: 0.45182228088378906, Average Accuracy: 0.8125, Test Accuracy: 0.6829268336296082
# Epoch 1450, Average Outcome Loss: 0.47302640974521637, Average Accuracy: 0.8046875, Test Accuracy: 0.6829268336296082
# Epoch 1455, Average Outcome Loss: 0.41257162392139435, Average Accuracy: 0.890625, Test Accuracy: 0.707317054271698
# Epoch 1460, Average Outcome Loss: 0.4970277398824692, Average Accuracy: 0.796875, Test Accuracy: 0.7560975551605225
# Epoch 1465, Average Outcome Loss: 0.5370003879070282, Average Accuracy: 0.765625, Test Accuracy: 0.707317054271698
# Epoch 1470, Average Outcome Loss: 0.511694997549057, Average Accuracy: 0.796875, Test Accuracy: 0.707317054271698
# Epoch 1475, Average Outcome Loss: 0.4438626617193222, Average Accuracy: 0.859375, Test Accuracy: 0.707317054271698
# Epoch 1480, Average Outcome Loss: 0.47791722416877747, Average Accuracy: 0.8125, Test Accuracy: 0.6829268336296082
# Epoch 1485, Average Outcome Loss: 0.45181983709335327, Average Accuracy: 0.828125, Test Accuracy: 0.707317054271698
# Epoch 1490, Average Outcome Loss: 0.5022384077310562, Average Accuracy: 0.78125, Test Accuracy: 0.7560975551605225
# Epoch 1495, Average Outcome Loss: 0.4747625142335892, Average Accuracy: 0.8046875, Test Accuracy: 0.7560975551605225
# Epoch 1500, Average Outcome Loss: 0.3746657371520996, Average Accuracy: 0.8984375, Test Accuracy: 0.707317054271698
# Epoch 1505, Average Outcome Loss: 0.5308581292629242, Average Accuracy: 0.7578125, Test Accuracy: 0.6829268336296082
