# %% [markdown]
# ## Code base plan
#
# 1. script for instantating a model with many optional inputs
# 2. scripts for training the model with many option inputs
# 3.  scripts for getting the data with optional arguments
# 4.  script for training many models across numerous hyper-parameters
# 5. plotting script for summarizing many models

# %%
import rpy2.robjects as ro
import rpy2.robjects.packages as rpackages
import anndata as ad
import scanpy as sc
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
import pandas as pd
import umap
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from keras.callbacks import EarlyStopping
import seaborn as sb
from scipy.spatial.distance import pdist
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import pearsonr
import time
from keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.decomposition import PCA
import math
import random
import rpy2.robjects as ro
from rpy2 import robjects
from rpy2.robjects import r
from rpy2.robjects import pandas2ri
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from sklearn.metrics import roc_curve, auc
from sklearn.ensemble import RandomForestClassifier
import os

os.environ['PYTHONHASHSEED'] = '0'
random.seed(0)
np.random.seed(0)
tf.random.set_seed(0)

rds_path = '/tmp/work/RCproject/gene_lists.rds'
rds_data = r.readRDS(rds_path)

# Extract the names of the lists and their contents
gene_lists = {}
for name, item in zip(rds_data.names, rds_data):
    # Each 'item' is a list associated with the 'name'
    inner_list = list(item)  # Convert the inner R list to a Python list
    gene_lists[name] = inner_list

# Now `python_data` is a dictionary with names as keys and lists as values
gene_list_names = gene_lists.keys()

current_list = [16,1,8,32,64,128]
current_list = [64]


def test_params(current_value):

    print("let's go")
    
    pandas2ri.activate()
    test_set_size = 0.1
    dropout_rate = 0.2 # #0.1
    balance = True
    l2_reg = 0.01
    l1_reg = 0.01
    batch_size = current_value  #determines how many samples are processed per batch, each epoch will process multiple batches
    learning_rate = 0.00001
    num_epochs = 10000
    report_frequency = 5
    accuracy_threshold = 0.90
    clipnorm = 5.0
    simplifly_categories = True
    holdout_size = 0.1  #0.5
    use_gene_list = True
    current_gene_list = 'de_intersect_plus_bulk_genes' #'de_intersect_plus_bulk_genes'#'CV300' #'sig_4_6_0.1' #'de_intersect_plus_bulk_genes'
    PCA_reduce = False
    n_comp_PCA = 128
    weight_initialization_style = 'he_normal' # options: ['he_normal','glorot_uniform','lecun_normal','lecun_uniform','glorot_normal','glorot_normal','he_uniform']

    # Load the RDS file
    rds_path = '/tmp/work/RCproject/gene_lists.rds'
    rds_data = r.readRDS(rds_path)
    
    # Extract the names of the lists and their contents
    gene_lists = {}
    for name, item in zip(rds_data.names, rds_data):
        # Each 'item' is a list associated with the 'name'
        inner_list = list(item)  # Convert the inner R list to a Python list
        gene_lists[name] = inner_list

    current_genes = gene_lists[current_gene_list]

    # Function to read RDS file and extract counts and metadata
    def read_rds_to_matrix_and_metadata(file_path):
        # Load the RDS file in R
        ro.r(f"sce <- readRDS('{file_path}')")
    
        # Extract count data (assumed to be stored in assays)
        counts = ro.r('assay(sce, "scalelogcounts")')
        # Extract row (gene) and column (cell) names
        gene_names = ro.r('rownames(sce)')
        cell_names = ro.r('colnames(sce)')
        
        # Convert to a NumPy array
        counts_np = ro.conversion.rpy2py(counts)
    
        # Convert the counts matrix to a pandas DataFrame
        counts_df = pd.DataFrame(counts_np, index=gene_names, columns=cell_names)
    
        # Extract metadata from colData and convert to a pandas DataFrame directly
        metadata = ro.r('as.data.frame(colData(sce))')  # Get the colData as an R data frame
        metadata_df = pd.DataFrame(metadata)  # Convert R data frame to pandas DataFrame directly
    
        return counts_df, metadata_df
    
    # Usage example
    file_path = '/tmp/work/RCproject/GEO_singlecellexperiment.rds'
    counts_df, metadata_df = read_rds_to_matrix_and_metadata(file_path)
    
    if use_gene_list:
        counts_df = counts_df.loc[current_genes]

    filtered_metadata_df = metadata_df[~metadata_df['Response'].isin(['partial'])].copy()

    row_names = filtered_metadata_df.index.tolist()  # Convert index to a list
    
    filtered_counts_df = counts_df[row_names].copy()

    categories_technology = filtered_metadata_df['batch']

    if simplifly_categories:
        category_map = {'GSE133057': 'micro', 'GSE145037': 'micro', 'GSE150082': 'micro','GSE190826':'seq1','GSE209746':'seq2',
                        'GSE45404_GPL1': 'micro', 'GSE45404_GPL2': 'micro', 'GSE93375': 'micro','GSE94104': 'micro'}
        categories_technology = np.vectorize(category_map.get)(categories_technology)
        
    # Create a LabelEncoder instance
    label_encoder = LabelEncoder()
    # Fit and transform the categories to integers
    numerical_categories_technology = label_encoder.fit_transform(categories_technology)        
    # categories_outcome = adata.obs['Response']
    categories_outcome = filtered_metadata_df['Response']
    numerical_categories_outcome = label_encoder.fit_transform(categories_outcome)


    frequency_counts = pd.Series(numerical_categories_technology).value_counts()
    frequency_counts = pd.Series(numerical_categories_outcome).value_counts()    
    unique_combinations_array = (numerical_categories_outcome + (numerical_categories_technology+1)*2)-2
    np.unique(unique_combinations_array)

    # Assuming filtered_metadata_df is your filtered DataFrame
    filtered_metadata_df.loc[:, 'numerical_categories_technology'] = numerical_categories_technology
    filtered_metadata_df.loc[:, 'numerical_categories_outcome'] = numerical_categories_outcome
    filtered_metadata_df.loc[:, 'combination_tech_outcome'] = unique_combinations_array

    #normalizaiton
    # gene_expression_data = adata.layers['scalelogcounts']
    
    gene_expression_data = filtered_counts_df.T
    
    #Min-max normalization
    
    scaler = MinMaxScaler()
    gene_expression_data = scaler.fit_transform(gene_expression_data)
    
    number_genes = gene_expression_data.shape[1]
    input_dim = number_genes
    
    if PCA_reduce:
    # Initialize PCA and fit it to X_train
        n_components = n_comp_PCA  # You can adjust this based on your data
        pca = PCA(n_components=n_components)
        gene_expression_data = pca.fit_transform(gene_expression_data)

    # setup the test and train datasets
    # X_train, X_test, y_train, y_test = train_test_split(gene_expression_data, filtered_metadata_df, test_size=test_set_size, random_state=1)
    # X_train, X_test, y_train, y_test = train_test_split(gene_expression_data, filtered_metadata_df, test_size=test_set_size, random_state=1, stratify=filtered_metadata_df['numerical_categories_outcome'])
    X_train, X_test, y_train, y_test = train_test_split(gene_expression_data, filtered_metadata_df, test_size=test_set_size, random_state=42,stratify=filtered_metadata_df['combination_tech_outcome'])
    
    y_train_outcome = y_train['numerical_categories_outcome']
    y_test_outcome = y_test['numerical_categories_outcome']
    
    y_train_tech = y_train['numerical_categories_technology']
    y_test_tech = y_test['numerical_categories_technology']
    
    y_train_comb = y_train['combination_tech_outcome']
    y_test_comb = y_test['combination_tech_outcome']

    # # Define the input shape
    # # input_shape = (gene_expression_data.shape[1],)[0]  # Number of genes

    input_shape = (X_train.shape[1],)[0]  # Number of genes
    
    # def build_outcome_classifier():
    #     model = keras.Sequential()
    #     model.add(layers.Input(shape=(input_shape,)))  # Input shape matches your data
        
    #     # model.add(layers.Dense(512,kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),kernel_initializer=weight_intializaiton_style))
    #     # model.add(layers.LeakyReLU(alpha=0.1))  # Leaky ReLU helps with vanishing gradients
    #     # model.add(layers.BatchNormalization())
    #     # model.add(layers.Dropout(dropout_rate))
        
    #     model.add(layers.Dense((256),kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),kernel_initializer=weight_intializaiton_style))
    #     model.add(layers.BatchNormalization())
    #     model.add(layers.LeakyReLU(alpha=0.1))
    #     model.add(layers.Dropout(dropout_rate))
    
    #     model.add(layers.Dense((128),kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),kernel_initializer=weight_intializaiton_style))
    #     model.add(layers.BatchNormalization())
    #     model.add(layers.LeakyReLU(alpha=0.1))
    #     model.add(layers.Dropout(dropout_rate))
        
    #     model.add(layers.Dense((64),kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),kernel_initializer=weight_intializaiton_style))
    #     model.add(layers.BatchNormalization())
    #     model.add(layers.LeakyReLU(alpha=0.1))
    #     model.add(layers.Dropout(dropout_rate))
    
    #     model.add(layers.Dense((32),kernel_initializer=weight_intializaiton_style))
    #     model.add(layers.BatchNormalization())
    #     model.add(layers.LeakyReLU(alpha=0.1))
        
    #     # Output layer for binary classification with sigmoid activation
    #     model.add(layers.Dense(1, activation='sigmoid'))
        
    #     return model

    def build_outcome_classifier():
        model = keras.Sequential()
        model.add(layers.Input(shape=(input_shape,)))  # Input shape matches your data


        # model.add(layers.Dense(512, kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg), 
        #                kernel_initializer=weight_initialization_style))
        # model.add(layers.BatchNormalization())
        # model.add(layers.LeakyReLU(alpha=0.1))
        # model.add(layers.Dropout(dropout_rate))
    
        # # First Dense layer with regularization, batch normalization, Leaky ReLU, and dropout
        # model.add(layers.Dense(256, kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg), 
        #                        kernel_initializer=weight_initialization_style))
        # model.add(layers.BatchNormalization())
        # model.add(layers.LeakyReLU(alpha=0.1))
        # model.add(layers.Dropout(dropout_rate))
    
        # Second Dense layer
        model.add(layers.Dense(128, kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg), 
                               kernel_initializer=weight_initialization_style))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(alpha=0.1))
        model.add(layers.Dropout(dropout_rate))
    
        # Third Dense layer
        model.add(layers.Dense(64, kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg), 
                               kernel_initializer=weight_initialization_style))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(alpha=0.1))
        model.add(layers.Dropout(dropout_rate))
    
        # Fourth Dense layer
        model.add(layers.Dense(32, kernel_initializer=weight_initialization_style))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(alpha=0.1))
    
        # Output layer for binary classification with sigmoid activation
        model.add(layers.Dense(1, activation='sigmoid'))
    
        return model
        
    # Define the mode
    outcome_classifier = build_outcome_classifier()
    
    # set up the optimizer
    # optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate, clipnorm = clipnorm)
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate,beta_1=0.9,beta_2=0.999,epsilon=1e-7,clipnorm = clipnorm)
    
    # determine the sample and batch size
    num_samples = math.floor(X_train.shape[0]* (1-holdout_size))  # number of samples used in each training epoch
    
    # batch_size = adata.shape[0]
    
    # Calculate the number of steps per epoch
    num_steps_per_epoch = num_samples // batch_size
    
    # Compile the outcome discriminator
    outcome_classifier.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])


    test_accuracy_list = []
    train_accuracy_list = []
    
    num_outcomes = len(np.unique(y_test_outcome))
    num_conditions = len(np.unique(unique_combinations_array))
    
    # Define the training step for only the outcome classifier
    def train_step(data, outcome_labels):
        with tf.GradientTape() as tape:
            # Forward pass through the outcome classifier
            outcome_predictions = outcome_classifier(data)
    
            # Compute the biological discriminator loss
            outcome_loss = tf.keras.losses.binary_crossentropy(outcome_labels, outcome_predictions)
            outcome_loss = tf.reduce_mean(outcome_loss)  # Average over the batch
    
        # Compute gradients for the outcome classifier
        classifier_grads = tape.gradient(outcome_loss, outcome_classifier.trainable_variables)
        
        # Calculate accuracy for the outcome classifier
        predicted_outcome_labels = tf.cast(outcome_predictions > 0.5, tf.float32)  # Threshold at 0.5
        outcome_labels_float = tf.cast(outcome_labels, tf.float32)
    
        # Calculate accuracy
        accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted_outcome_labels, outcome_labels_float), tf.float32))
    
        return outcome_loss, accuracy, classifier_grads
    
    # Training loop
    for epoch in range(num_epochs):
        total_loss = 0.0  # To accumulate losses
        total_accuracy = 0.0  # To accumulate accuracy
        accumulated_grads = [tf.zeros_like(var) for var in outcome_classifier.trainable_variables]  # Initialize gradient accumulator
    
        # # Split train data randomly, holding out a portion for generalization
        # X_train_temp, X_test_temp, y_train_temp, y_test_temp = train_test_split(X_train, y_train, test_size=holdout_size, random_state=None, stratify=y_train['combination_tech_outcome'])
        # y_train_comb_temp = y_train_temp['combination_tech_outcome']
        # y_train_temp = y_train_temp['numerical_categories_outcome']


        # Split train data randomly, holding out a portion for generalization
        X_train_temp, X_test_temp, y_train_temp, y_test_temp = train_test_split(X_train, y_train, test_size=holdout_size, random_state=None)
        
        # Use .loc to explicitly specify column names for clarity
        y_train_comb_temp = y_train_temp.loc[:, 'combination_tech_outcome']
        y_train_temp = y_train_temp.loc[:, 'numerical_categories_outcome']
        
        # Mini-batch training loop
        for step in range(num_steps_per_epoch):
            # Balance batches if necessary
            batch_indices = []
            if balance:
                for condition in range(num_conditions):
                    condition_indices = np.where(y_train_comb_temp == condition)[0]
                    condition_batch_indices = np.random.choice(condition_indices, size=batch_size // num_conditions, replace=True)
                    batch_indices.append(condition_batch_indices)
            else:
                all_indices = np.arange(len(X_train_temp))
                random_indices = np.random.choice(all_indices, size=batch_size, replace=True)
                batch_indices.append(random_indices)
            X_batch = X_train_temp[np.concatenate(batch_indices)]
            # y_batch = y_train_temp[np.concatenate(batch_indices)]
            y_batch = y_train_temp.iloc[np.concatenate(batch_indices)]

            y_batch = tf.expand_dims(y_batch, axis=-1)  # Adjust labels shape for binary_crossentropy                    
            # Perform the training step and collect gradients
            outcome_loss, accuracy, classifier_grads = train_step(X_batch, y_batch)
            
            # Accumulate gradients and losses
            total_loss += outcome_loss.numpy()
            total_accuracy += accuracy.numpy()
            accumulated_grads = [acc_grad + grad for acc_grad, grad in zip(accumulated_grads, classifier_grads)]
    
        # Average the accumulated gradients
        averaged_grads = [grad / num_steps_per_epoch for grad in accumulated_grads]
    
        # Apply averaged gradients to update model weights
        optimizer.apply_gradients(zip(averaged_grads, outcome_classifier.trainable_variables))
    
        # Calculate average loss and accuracy for the epoch
        avg_loss = total_loss / num_steps_per_epoch
        avg_accuracy = total_accuracy / num_steps_per_epoch
    
        # Print average accuracy at the end of each epoch and calculate the accuracy for the test set
        if epoch % report_frequency == 0:
            # Evaluate on test data
            outcome_predictions = outcome_classifier(X_test)
            predicted_outcome_labels = tf.cast(outcome_predictions > 0.5, tf.float32)  # Threshold at 0.5
            outcome_labels = tf.expand_dims(y_test_outcome, axis=-1)  # Reshape to match logits shape
            outcome_labels_float = tf.cast(outcome_labels, tf.float32)
    
            # Calculate accuracy
            test_accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted_outcome_labels, outcome_labels_float), tf.float32))
            
            # Store and print metrics
            train_accuracy_list.append(avg_accuracy)
            test_accuracy_list.append(test_accuracy)
            print(f'Epoch {epoch}, Average Outcome Loss: {avg_loss}, Average Accuracy: {avg_accuracy}, Test Accuracy: {test_accuracy}')
    
            # Early stopping condition for accuracy
            if test_accuracy > accuracy_threshold:
                print('Early stopping: test set performance high enough')
                break

    current_val_str = str(current_value)
    title = 'no_batch_norm_with_balance_true_batch_size_' + current_val_str
    
    # Create the PDF file name based on a variable
    output_dir = "tmp_plots"
    pdf_filename = os.path.join(output_dir, f"{title}.pdf")
    
    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)  # Ensure the directory is created
    
    # Create a new figure to hold all plots
    with PdfPages(pdf_filename) as pdf:
        fig, axs = plt.subplots(2, 2, figsize=(12, 10))  # 2 rows, 2 columns
    
        # Training accuracy plot
        x_values = np.arange(1, len(train_accuracy_list) + 1) * report_frequency
        frequency_counts = pd.Series(y_train_outcome).value_counts()
        train_chance_level = frequency_counts[0] / len(y_train_outcome)
    
        axs[0, 0].plot(x_values, train_accuracy_list, label='Training Accuracy', color='blue')
        axs[0, 0].axhline(train_chance_level, color='black', linestyle='--')
        axs[0, 0].set_title('Training Set Accuracy Over Epochs')
        axs[0, 0].set_xlabel('Epoch')
        axs[0, 0].set_ylabel('Training Accuracy')
        axs[0, 0].grid()
        axs[0, 0].legend()
    
        # Testing accuracy plot
        frequency_counts = pd.Series(y_test_outcome).value_counts()
        test_chance_level = frequency_counts[0] / len(y_test_outcome)
    
        axs[0, 1].plot(x_values, test_accuracy_list, label='Test Accuracy', color='orange')
        axs[0, 1].axhline(test_chance_level, color='black', linestyle='--')
        axs[0, 1].set_title('Test Set Accuracy Over Epochs')
        axs[0, 1].set_xlabel('Epoch')
        axs[0, 1].set_ylabel('Test Accuracy')
        axs[0, 1].grid()
        axs[0, 1].legend()
    
        # ROC curve for ANN
        fpr, tpr, thresholds = roc_curve(y_test_outcome, predicted_outcome_labels)
        roc_auc = auc(fpr, tpr)
    
        axs[1, 0].plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
        axs[1, 0].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        axs[1, 0].set_xlim([0.0, 1.0])
        axs[1, 0].set_ylim([0.0, 1.05])
        axs[1, 0].set_xlabel('False Positive Rate')
        axs[1, 0].set_ylabel('True Positive Rate')
        axs[1, 0].set_title('ROC Curve for ANN')
        axs[1, 0].legend(loc="lower right")
    
        # ROC curve for Random Forest
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X_train, y_train_outcome)
        y_pred_prob = clf.predict_proba(X_test)[:, 1]
        fpr, tpr, thresholds = roc_curve(y_test_outcome, y_pred_prob)
        roc_auc = auc(fpr, tpr)
    
        axs[1, 1].plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
        axs[1, 1].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        axs[1, 1].set_xlim([0.0, 1.0])
        axs[1, 1].set_ylim([0.0, 1.05])
        axs[1, 1].set_xlabel('False Positive Rate')
        axs[1, 1].set_ylabel('True Positive Rate')
        axs[1, 1].set_title('ROC Curve for Random Forest')
        axs[1, 1].legend(loc="lower right")
    
        plt.tight_layout()
        pdf.savefig(fig)  # Save the figure to the PDF
        plt.close(fig)     # Close the figure

for current_value in current_list:
    test_params(current_value)

# current_value = 0
# test_params(curren_value)
# Out:
# let's go
# Epoch 0, Average Outcome Loss: 0.7103002309799195, Average Accuracy: 0.3666666686534882, Test Accuracy: 0.5609756112098694
# Epoch 5, Average Outcome Loss: 0.7051610231399537, Average Accuracy: 0.37333333790302276, Test Accuracy: 0.5609756112098694
# Epoch 10, Average Outcome Loss: 0.7006662249565124, Average Accuracy: 0.4099999964237213, Test Accuracy: 0.6097561120986938
# Epoch 15, Average Outcome Loss: 0.703763222694397, Average Accuracy: 0.38333333730697633, Test Accuracy: 0.6341463327407837
# Epoch 20, Average Outcome Loss: 0.7022265434265137, Average Accuracy: 0.4033333361148834, Test Accuracy: 0.6097561120986938
# Epoch 25, Average Outcome Loss: 0.6995043158531189, Average Accuracy: 0.45333333015441896, Test Accuracy: 0.6097561120986938
# Epoch 30, Average Outcome Loss: 0.7016997098922729, Average Accuracy: 0.426666671037674, Test Accuracy: 0.5853658318519592
# Epoch 35, Average Outcome Loss: 0.6944787740707398, Average Accuracy: 0.47666666507720945, Test Accuracy: 0.5609756112098694
# Epoch 40, Average Outcome Loss: 0.6986567735671997, Average Accuracy: 0.426666659116745, Test Accuracy: 0.5609756112098694
# Epoch 45, Average Outcome Loss: 0.6997189164161682, Average Accuracy: 0.46666666865348816, Test Accuracy: 0.5609756112098694
# Epoch 50, Average Outcome Loss: 0.6937849760055542, Average Accuracy: 0.4600000023841858, Test Accuracy: 0.6097561120986938
# Epoch 55, Average Outcome Loss: 0.6934503793716431, Average Accuracy: 0.44666666388511655, Test Accuracy: 0.6097561120986938
# Epoch 60, Average Outcome Loss: 0.6934773087501526, Average Accuracy: 0.44333332777023315, Test Accuracy: 0.6341463327407837
# Epoch 65, Average Outcome Loss: 0.6911623120307923, Average Accuracy: 0.4866666555404663, Test Accuracy: 0.6341463327407837
# Epoch 70, Average Outcome Loss: 0.6916272401809692, Average Accuracy: 0.45666667222976687, Test Accuracy: 0.6097561120986938
# Epoch 75, Average Outcome Loss: 0.6897615313529968, Average Accuracy: 0.4900000035762787, Test Accuracy: 0.6341463327407837
# Epoch 80, Average Outcome Loss: 0.6904374957084656, Average Accuracy: 0.44000000357627866, Test Accuracy: 0.6097561120986938
# Epoch 85, Average Outcome Loss: 0.6853453278541565, Average Accuracy: 0.5633333384990692, Test Accuracy: 0.6585366129875183
# Epoch 90, Average Outcome Loss: 0.6890833973884583, Average Accuracy: 0.5066666722297668, Test Accuracy: 0.6585366129875183
# Epoch 95, Average Outcome Loss: 0.6888006448745727, Average Accuracy: 0.5233333289623261, Test Accuracy: 0.6585366129875183
# Epoch 100, Average Outcome Loss: 0.686287808418274, Average Accuracy: 0.5166666686534882, Test Accuracy: 0.6585366129875183
# Epoch 105, Average Outcome Loss: 0.6892005324363708, Average Accuracy: 0.46666666865348816, Test Accuracy: 0.6585366129875183
# Epoch 110, Average Outcome Loss: 0.6882576942443848, Average Accuracy: 0.49333332777023314, Test Accuracy: 0.6585366129875183
# Epoch 115, Average Outcome Loss: 0.6837175130844116, Average Accuracy: 0.5099999904632568, Test Accuracy: 0.6829268336296082
# Epoch 120, Average Outcome Loss: 0.6812584519386291, Average Accuracy: 0.5599999904632569, Test Accuracy: 0.6829268336296082
# Epoch 125, Average Outcome Loss: 0.6769661664962768, Average Accuracy: 0.6233333349227905, Test Accuracy: 0.707317054271698
# Epoch 130, Average Outcome Loss: 0.6844295859336853, Average Accuracy: 0.48333333134651185, Test Accuracy: 0.707317054271698
# Epoch 135, Average Outcome Loss: 0.6855745553970337, Average Accuracy: 0.5199999988079071, Test Accuracy: 0.7317073345184326
# Epoch 140, Average Outcome Loss: 0.6831269145011902, Average Accuracy: 0.523333340883255, Test Accuracy: 0.7317073345184326
# Epoch 145, Average Outcome Loss: 0.6831312656402588, Average Accuracy: 0.5833333373069763, Test Accuracy: 0.7317073345184326
# Epoch 150, Average Outcome Loss: 0.6824961066246032, Average Accuracy: 0.5833333253860473, Test Accuracy: 0.7560975551605225
# Epoch 155, Average Outcome Loss: 0.6804129719734192, Average Accuracy: 0.5833333373069763, Test Accuracy: 0.707317054271698
# Epoch 160, Average Outcome Loss: 0.6823245048522949, Average Accuracy: 0.5566666603088379, Test Accuracy: 0.7317073345184326
# Epoch 165, Average Outcome Loss: 0.6782675385475159, Average Accuracy: 0.6200000047683716, Test Accuracy: 0.7560975551605225
# Epoch 170, Average Outcome Loss: 0.678700578212738, Average Accuracy: 0.5899999976158142, Test Accuracy: 0.7317073345184326
# Epoch 175, Average Outcome Loss: 0.6790348172187806, Average Accuracy: 0.6199999928474427, Test Accuracy: 0.7317073345184326
# Epoch 180, Average Outcome Loss: 0.6814560651779175, Average Accuracy: 0.5633333206176758, Test Accuracy: 0.707317054271698
# Epoch 185, Average Outcome Loss: 0.6749144196510315, Average Accuracy: 0.6200000047683716, Test Accuracy: 0.7317073345184326
# Epoch 190, Average Outcome Loss: 0.6769589185714722, Average Accuracy: 0.5900000095367431, Test Accuracy: 0.7317073345184326
# Epoch 195, Average Outcome Loss: 0.6740939021110535, Average Accuracy: 0.5866666793823242, Test Accuracy: 0.6829268336296082
# Epoch 200, Average Outcome Loss: 0.6806790590286255, Average Accuracy: 0.5199999988079071, Test Accuracy: 0.707317054271698
# Epoch 205, Average Outcome Loss: 0.6726510047912597, Average Accuracy: 0.6300000071525573, Test Accuracy: 0.707317054271698
# Epoch 210, Average Outcome Loss: 0.6729874730110168, Average Accuracy: 0.6566666603088379, Test Accuracy: 0.707317054271698
# Epoch 215, Average Outcome Loss: 0.6717356443405151, Average Accuracy: 0.6133333325386048, Test Accuracy: 0.7317073345184326
# Epoch 220, Average Outcome Loss: 0.6778559684753418, Average Accuracy: 0.5866666555404663, Test Accuracy: 0.707317054271698
# Epoch 225, Average Outcome Loss: 0.6694713115692139, Average Accuracy: 0.6199999928474427, Test Accuracy: 0.707317054271698
# Epoch 230, Average Outcome Loss: 0.6704329252243042, Average Accuracy: 0.5700000047683715, Test Accuracy: 0.707317054271698
# Epoch 235, Average Outcome Loss: 0.6669025182723999, Average Accuracy: 0.5666666626930237, Test Accuracy: 0.707317054271698
# Epoch 240, Average Outcome Loss: 0.6664575099945068, Average Accuracy: 0.6100000143051147, Test Accuracy: 0.6829268336296082
# Epoch 245, Average Outcome Loss: 0.6629603266716003, Average Accuracy: 0.6333333253860474, Test Accuracy: 0.6829268336296082
# Epoch 250, Average Outcome Loss: 0.6750856161117553, Average Accuracy: 0.5533333420753479, Test Accuracy: 0.6829268336296082
# Epoch 255, Average Outcome Loss: 0.6631073832511902, Average Accuracy: 0.6, Test Accuracy: 0.6829268336296082
# Epoch 260, Average Outcome Loss: 0.6646267771720886, Average Accuracy: 0.5966666579246521, Test Accuracy: 0.6585366129875183
# Epoch 265, Average Outcome Loss: 0.6630596041679382, Average Accuracy: 0.5766666769981384, Test Accuracy: 0.6829268336296082
# Epoch 270, Average Outcome Loss: 0.6633862018585205, Average Accuracy: 0.5633333325386047, Test Accuracy: 0.6829268336296082
# Epoch 275, Average Outcome Loss: 0.662734866142273, Average Accuracy: 0.5933333396911621, Test Accuracy: 0.6585366129875183
# Epoch 280, Average Outcome Loss: 0.6658016562461853, Average Accuracy: 0.5699999988079071, Test Accuracy: 0.6585366129875183
# Epoch 285, Average Outcome Loss: 0.6607621669769287, Average Accuracy: 0.6299999833106995, Test Accuracy: 0.6585366129875183
# Epoch 290, Average Outcome Loss: 0.662057614326477, Average Accuracy: 0.5699999988079071, Test Accuracy: 0.6585366129875183
# Epoch 295, Average Outcome Loss: 0.6555081009864807, Average Accuracy: 0.6266666769981384, Test Accuracy: 0.6585366129875183
# Epoch 300, Average Outcome Loss: 0.6631136775016785, Average Accuracy: 0.6399999976158142, Test Accuracy: 0.6585366129875183
# Epoch 305, Average Outcome Loss: 0.661947739124298, Average Accuracy: 0.5566666662693024, Test Accuracy: 0.6585366129875183
# Epoch 310, Average Outcome Loss: 0.6643338799476624, Average Accuracy: 0.5633333384990692, Test Accuracy: 0.6585366129875183
# Epoch 315, Average Outcome Loss: 0.665959894657135, Average Accuracy: 0.5900000095367431, Test Accuracy: 0.6829268336296082
# Epoch 320, Average Outcome Loss: 0.6535722732543945, Average Accuracy: 0.6133333325386048, Test Accuracy: 0.6829268336296082
# Epoch 325, Average Outcome Loss: 0.658982765674591, Average Accuracy: 0.6099999904632568, Test Accuracy: 0.6829268336296082
# Epoch 330, Average Outcome Loss: 0.6512916564941407, Average Accuracy: 0.653333330154419, Test Accuracy: 0.6829268336296082
# Epoch 335, Average Outcome Loss: 0.6576242804527282, Average Accuracy: 0.5933333396911621, Test Accuracy: 0.6585366129875183
# Epoch 340, Average Outcome Loss: 0.6416172385215759, Average Accuracy: 0.6766666650772095, Test Accuracy: 0.6585366129875183
# Epoch 345, Average Outcome Loss: 0.6498300790786743, Average Accuracy: 0.6800000071525574, Test Accuracy: 0.6585366129875183
# Epoch 350, Average Outcome Loss: 0.6480607986450195, Average Accuracy: 0.6300000071525573, Test Accuracy: 0.6585366129875183
# Epoch 355, Average Outcome Loss: 0.6535097479820251, Average Accuracy: 0.6333333253860474, Test Accuracy: 0.6341463327407837
# Epoch 360, Average Outcome Loss: 0.6634908556938172, Average Accuracy: 0.5733333349227905, Test Accuracy: 0.6341463327407837
# Epoch 365, Average Outcome Loss: 0.6521271586418151, Average Accuracy: 0.6133333444595337, Test Accuracy: 0.6585366129875183
# Epoch 370, Average Outcome Loss: 0.6577115178108215, Average Accuracy: 0.5633333265781403, Test Accuracy: 0.6341463327407837
# Epoch 375, Average Outcome Loss: 0.651051652431488, Average Accuracy: 0.6233333289623261, Test Accuracy: 0.6341463327407837
# Epoch 380, Average Outcome Loss: 0.6594610452651978, Average Accuracy: 0.6199999928474427, Test Accuracy: 0.6585366129875183
# Epoch 385, Average Outcome Loss: 0.6353698372840881, Average Accuracy: 0.6733333349227906, Test Accuracy: 0.6585366129875183
# Epoch 390, Average Outcome Loss: 0.6471169948577881, Average Accuracy: 0.6333333253860474, Test Accuracy: 0.6585366129875183
# Epoch 395, Average Outcome Loss: 0.645578920841217, Average Accuracy: 0.6833333373069763, Test Accuracy: 0.6341463327407837
# Epoch 400, Average Outcome Loss: 0.6545983552932739, Average Accuracy: 0.6333333373069763, Test Accuracy: 0.6585366129875183
# Epoch 405, Average Outcome Loss: 0.6344848155975342, Average Accuracy: 0.7066666722297669, Test Accuracy: 0.6341463327407837
# Epoch 410, Average Outcome Loss: 0.6485789060592652, Average Accuracy: 0.6733333349227906, Test Accuracy: 0.6585366129875183
# Epoch 415, Average Outcome Loss: 0.6610877871513366, Average Accuracy: 0.59666668176651, Test Accuracy: 0.6585366129875183
# Epoch 420, Average Outcome Loss: 0.6436531186103821, Average Accuracy: 0.6633333325386047, Test Accuracy: 0.6585366129875183
# Epoch 425, Average Outcome Loss: 0.6579246163368225, Average Accuracy: 0.6433333277702331, Test Accuracy: 0.6341463327407837
# Epoch 430, Average Outcome Loss: 0.6407387614250183, Average Accuracy: 0.6733333230018616, Test Accuracy: 0.6585366129875183
# Epoch 435, Average Outcome Loss: 0.6419222593307495, Average Accuracy: 0.6366666793823242, Test Accuracy: 0.6341463327407837
# Epoch 440, Average Outcome Loss: 0.6424568295478821, Average Accuracy: 0.6700000047683716, Test Accuracy: 0.6341463327407837
# Epoch 445, Average Outcome Loss: 0.6511869192123413, Average Accuracy: 0.6133333444595337, Test Accuracy: 0.6341463327407837
# Epoch 450, Average Outcome Loss: 0.6544448852539062, Average Accuracy: 0.6133333325386048, Test Accuracy: 0.6341463327407837
# Epoch 455, Average Outcome Loss: 0.6218334436416626, Average Accuracy: 0.7199999928474426, Test Accuracy: 0.6341463327407837
# Epoch 460, Average Outcome Loss: 0.6360811710357666, Average Accuracy: 0.6933333277702332, Test Accuracy: 0.6829268336296082
# Epoch 465, Average Outcome Loss: 0.6461016774177551, Average Accuracy: 0.653333330154419, Test Accuracy: 0.6585366129875183
# Epoch 470, Average Outcome Loss: 0.6361535310745239, Average Accuracy: 0.6699999928474426, Test Accuracy: 0.6341463327407837
# Epoch 475, Average Outcome Loss: 0.6489801406860352, Average Accuracy: 0.6433333277702331, Test Accuracy: 0.6341463327407837
# Epoch 480, Average Outcome Loss: 0.6425827145576477, Average Accuracy: 0.7, Test Accuracy: 0.6341463327407837
# Epoch 485, Average Outcome Loss: 0.6350727796554565, Average Accuracy: 0.7066666603088378, Test Accuracy: 0.6341463327407837
# Epoch 490, Average Outcome Loss: 0.6457947492599487, Average Accuracy: 0.649999988079071, Test Accuracy: 0.6341463327407837
# Epoch 495, Average Outcome Loss: 0.6402196407318115, Average Accuracy: 0.6466666698455811, Test Accuracy: 0.6341463327407837
# Epoch 500, Average Outcome Loss: 0.6278602004051208, Average Accuracy: 0.6666666626930237, Test Accuracy: 0.6097561120986938
# Epoch 505, Average Outcome Loss: 0.6314147353172302, Average Accuracy: 0.6833333253860474, Test Accuracy: 0.6341463327407837
# Epoch 510, Average Outcome Loss: 0.6385173559188843, Average Accuracy: 0.6866666555404664, Test Accuracy: 0.6341463327407837
# Epoch 515, Average Outcome Loss: 0.6380148291587829, Average Accuracy: 0.6633333206176758, Test Accuracy: 0.6341463327407837
# Epoch 520, Average Outcome Loss: 0.6348095774650574, Average Accuracy: 0.6833333253860474, Test Accuracy: 0.5853658318519592
# Epoch 525, Average Outcome Loss: 0.6479640126228332, Average Accuracy: 0.6399999976158142, Test Accuracy: 0.6341463327407837
# Epoch 530, Average Outcome Loss: 0.6211093306541443, Average Accuracy: 0.7166666626930237, Test Accuracy: 0.6341463327407837
# Epoch 535, Average Outcome Loss: 0.6337505578994751, Average Accuracy: 0.65, Test Accuracy: 0.6585366129875183
# Epoch 540, Average Outcome Loss: 0.6385841608047486, Average Accuracy: 0.6566666603088379, Test Accuracy: 0.6341463327407837
# Epoch 545, Average Outcome Loss: 0.6365226149559021, Average Accuracy: 0.65, Test Accuracy: 0.6341463327407837
# Epoch 550, Average Outcome Loss: 0.629180085659027, Average Accuracy: 0.6933333396911621, Test Accuracy: 0.6341463327407837
# Epoch 555, Average Outcome Loss: 0.6177206039428711, Average Accuracy: 0.7299999952316284, Test Accuracy: 0.6341463327407837
# Epoch 560, Average Outcome Loss: 0.6211541175842286, Average Accuracy: 0.7233333230018616, Test Accuracy: 0.6341463327407837
# Epoch 565, Average Outcome Loss: 0.6336162090301514, Average Accuracy: 0.6399999856948853, Test Accuracy: 0.6585366129875183
# Epoch 570, Average Outcome Loss: 0.6295800685882569, Average Accuracy: 0.6666666626930237, Test Accuracy: 0.6341463327407837
# Epoch 575, Average Outcome Loss: 0.6140278935432434, Average Accuracy: 0.696666669845581, Test Accuracy: 0.5853658318519592
# Epoch 580, Average Outcome Loss: 0.6148951888084412, Average Accuracy: 0.7200000047683716, Test Accuracy: 0.6341463327407837
# Epoch 585, Average Outcome Loss: 0.6212675094604492, Average Accuracy: 0.696666669845581, Test Accuracy: 0.6341463327407837
# Epoch 590, Average Outcome Loss: 0.6182969570159912, Average Accuracy: 0.6799999952316285, Test Accuracy: 0.6585366129875183
# Epoch 595, Average Outcome Loss: 0.6194531798362732, Average Accuracy: 0.6866666674613953, Test Accuracy: 0.6585366129875183
# Epoch 600, Average Outcome Loss: 0.6291328549385071, Average Accuracy: 0.6933333396911621, Test Accuracy: 0.6341463327407837
# Epoch 605, Average Outcome Loss: 0.627876615524292, Average Accuracy: 0.6800000071525574, Test Accuracy: 0.5853658318519592
# Epoch 610, Average Outcome Loss: 0.6236055254936218, Average Accuracy: 0.6300000071525573, Test Accuracy: 0.6097561120986938
# Epoch 615, Average Outcome Loss: 0.6078848004341125, Average Accuracy: 0.7, Test Accuracy: 0.6585366129875183
# Epoch 620, Average Outcome Loss: 0.6171199917793274, Average Accuracy: 0.6866666555404664, Test Accuracy: 0.6585366129875183
# Epoch 625, Average Outcome Loss: 0.6189206838607788, Average Accuracy: 0.6600000023841858, Test Accuracy: 0.6585366129875183
# Epoch 630, Average Outcome Loss: 0.6201823711395263, Average Accuracy: 0.6700000047683716, Test Accuracy: 0.6585366129875183
# Epoch 635, Average Outcome Loss: 0.6225316405296326, Average Accuracy: 0.6933333277702332, Test Accuracy: 0.6585366129875183
# Epoch 640, Average Outcome Loss: 0.6098901748657226, Average Accuracy: 0.7166666626930237, Test Accuracy: 0.6585366129875183
# Epoch 645, Average Outcome Loss: 0.6096598625183105, Average Accuracy: 0.7166666626930237, Test Accuracy: 0.6585366129875183
# Epoch 650, Average Outcome Loss: 0.6229634761810303, Average Accuracy: 0.6566666722297668, Test Accuracy: 0.6341463327407837
# Epoch 655, Average Outcome Loss: 0.6060224413871765, Average Accuracy: 0.6899999976158142, Test Accuracy: 0.6585366129875183
# Epoch 660, Average Outcome Loss: 0.616777217388153, Average Accuracy: 0.6899999976158142, Test Accuracy: 0.6585366129875183
# Epoch 665, Average Outcome Loss: 0.614981722831726, Average Accuracy: 0.6799999952316285, Test Accuracy: 0.6585366129875183
# Epoch 670, Average Outcome Loss: 0.6221128940582276, Average Accuracy: 0.6833333134651184, Test Accuracy: 0.6585366129875183
# Epoch 675, Average Outcome Loss: 0.6286675810813904, Average Accuracy: 0.6899999856948853, Test Accuracy: 0.6585366129875183
# Epoch 680, Average Outcome Loss: 0.6237949728965759, Average Accuracy: 0.6599999904632569, Test Accuracy: 0.6585366129875183
# Epoch 685, Average Outcome Loss: 0.6233758687973022, Average Accuracy: 0.653333330154419, Test Accuracy: 0.6341463327407837
# Epoch 690, Average Outcome Loss: 0.6221047759056091, Average Accuracy: 0.6766666531562805, Test Accuracy: 0.6097561120986938
# Epoch 695, Average Outcome Loss: 0.5919589400291443, Average Accuracy: 0.6933333277702332, Test Accuracy: 0.6585366129875183
# Epoch 700, Average Outcome Loss: 0.6095552444458008, Average Accuracy: 0.6899999976158142, Test Accuracy: 0.6829268336296082
# Epoch 705, Average Outcome Loss: 0.6124271273612976, Average Accuracy: 0.6733333230018616, Test Accuracy: 0.6829268336296082
# Epoch 710, Average Outcome Loss: 0.6116388201713562, Average Accuracy: 0.6800000071525574, Test Accuracy: 0.6585366129875183
# Epoch 715, Average Outcome Loss: 0.6172330141067505, Average Accuracy: 0.6766666650772095, Test Accuracy: 0.6585366129875183
# Epoch 720, Average Outcome Loss: 0.5980724453926086, Average Accuracy: 0.6900000095367431, Test Accuracy: 0.6585366129875183
# Epoch 725, Average Outcome Loss: 0.6069587707519531, Average Accuracy: 0.70333331823349, Test Accuracy: 0.6585366129875183
# Epoch 730, Average Outcome Loss: 0.6163737893104553, Average Accuracy: 0.6633333325386047, Test Accuracy: 0.6585366129875183
# Epoch 735, Average Outcome Loss: 0.6061479926109314, Average Accuracy: 0.7066666603088378, Test Accuracy: 0.6829268336296082
# Epoch 740, Average Outcome Loss: 0.6134389877319336, Average Accuracy: 0.6766666650772095, Test Accuracy: 0.6829268336296082
# Epoch 745, Average Outcome Loss: 0.6093880534172058, Average Accuracy: 0.6666666626930237, Test Accuracy: 0.6829268336296082
# Epoch 750, Average Outcome Loss: 0.6155784249305725, Average Accuracy: 0.6666666746139527, Test Accuracy: 0.6829268336296082
# Epoch 755, Average Outcome Loss: 0.6050961136817932, Average Accuracy: 0.6933333277702332, Test Accuracy: 0.6829268336296082
# Epoch 760, Average Outcome Loss: 0.6038128137588501, Average Accuracy: 0.6766666769981384, Test Accuracy: 0.6829268336296082
# Epoch 765, Average Outcome Loss: 0.6316647171974182, Average Accuracy: 0.6399999856948853, Test Accuracy: 0.6829268336296082
# Epoch 770, Average Outcome Loss: 0.6204423785209656, Average Accuracy: 0.6733333349227906, Test Accuracy: 0.6829268336296082
# Epoch 775, Average Outcome Loss: 0.6100190281867981, Average Accuracy: 0.7199999928474426, Test Accuracy: 0.6829268336296082
# Epoch 780, Average Outcome Loss: 0.5952430844306946, Average Accuracy: 0.7033333301544189, Test Accuracy: 0.6341463327407837
# Epoch 785, Average Outcome Loss: 0.5937052130699157, Average Accuracy: 0.6766666531562805, Test Accuracy: 0.6829268336296082
# Epoch 790, Average Outcome Loss: 0.6131641507148743, Average Accuracy: 0.6700000047683716, Test Accuracy: 0.6829268336296082
# Epoch 795, Average Outcome Loss: 0.5943902969360352, Average Accuracy: 0.7299999952316284, Test Accuracy: 0.6829268336296082
# Epoch 800, Average Outcome Loss: 0.6248756051063538, Average Accuracy: 0.6733333230018616, Test Accuracy: 0.6829268336296082
# Epoch 805, Average Outcome Loss: 0.597731602191925, Average Accuracy: 0.6933333277702332, Test Accuracy: 0.6829268336296082
# Epoch 810, Average Outcome Loss: 0.603010094165802, Average Accuracy: 0.6699999928474426, Test Accuracy: 0.6585366129875183
# Epoch 815, Average Outcome Loss: 0.633350670337677, Average Accuracy: 0.6466666698455811, Test Accuracy: 0.6829268336296082
# Epoch 820, Average Outcome Loss: 0.6133206605911254, Average Accuracy: 0.65, Test Accuracy: 0.6829268336296082
# Epoch 825, Average Outcome Loss: 0.5941414713859559, Average Accuracy: 0.6899999976158142, Test Accuracy: 0.6829268336296082
# Epoch 830, Average Outcome Loss: 0.5965618968009949, Average Accuracy: 0.7366666555404663, Test Accuracy: 0.6341463327407837
# Epoch 835, Average Outcome Loss: 0.6259367823600769, Average Accuracy: 0.6400000095367432, Test Accuracy: 0.6829268336296082
# Epoch 840, Average Outcome Loss: 0.603303849697113, Average Accuracy: 0.6900000095367431, Test Accuracy: 0.6829268336296082
# Epoch 845, Average Outcome Loss: 0.6041212797164917, Average Accuracy: 0.6799999952316285, Test Accuracy: 0.6585366129875183
# Epoch 850, Average Outcome Loss: 0.6037347555160523, Average Accuracy: 0.6399999976158142, Test Accuracy: 0.6341463327407837
# Epoch 855, Average Outcome Loss: 0.600412130355835, Average Accuracy: 0.6433333277702331, Test Accuracy: 0.6829268336296082
# Epoch 860, Average Outcome Loss: 0.6254581212997437, Average Accuracy: 0.6000000238418579, Test Accuracy: 0.6829268336296082
# Epoch 865, Average Outcome Loss: 0.603434431552887, Average Accuracy: 0.6466666460037231, Test Accuracy: 0.6829268336296082
# Epoch 870, Average Outcome Loss: 0.604413902759552, Average Accuracy: 0.6900000095367431, Test Accuracy: 0.6585366129875183
# Epoch 875, Average Outcome Loss: 0.6096208453178406, Average Accuracy: 0.6566666722297668, Test Accuracy: 0.6341463327407837
# Epoch 880, Average Outcome Loss: 0.5962058901786804, Average Accuracy: 0.7100000023841858, Test Accuracy: 0.6341463327407837
# Epoch 885, Average Outcome Loss: 0.5849212288856507, Average Accuracy: 0.75, Test Accuracy: 0.6341463327407837
# Epoch 890, Average Outcome Loss: 0.592990267276764, Average Accuracy: 0.7066666841506958, Test Accuracy: 0.6585366129875183
# Epoch 895, Average Outcome Loss: 0.5932252645492554, Average Accuracy: 0.6900000095367431, Test Accuracy: 0.6829268336296082
# Epoch 900, Average Outcome Loss: 0.5981482625007629, Average Accuracy: 0.7066666603088378, Test Accuracy: 0.6341463327407837
# Epoch 905, Average Outcome Loss: 0.6128008008003235, Average Accuracy: 0.6566666603088379, Test Accuracy: 0.6341463327407837
# Epoch 910, Average Outcome Loss: 0.5971192836761474, Average Accuracy: 0.7099999904632568, Test Accuracy: 0.6341463327407837
# Epoch 915, Average Outcome Loss: 0.6093024849891663, Average Accuracy: 0.7133333325386048, Test Accuracy: 0.6341463327407837
# Epoch 920, Average Outcome Loss: 0.6180208325386047, Average Accuracy: 0.65, Test Accuracy: 0.6341463327407837
# Epoch 925, Average Outcome Loss: 0.6183762788772583, Average Accuracy: 0.6599999904632569, Test Accuracy: 0.6341463327407837
# Epoch 930, Average Outcome Loss: 0.5716435551643372, Average Accuracy: 0.7366666555404663, Test Accuracy: 0.6341463327407837
# Epoch 935, Average Outcome Loss: 0.5960278272628784, Average Accuracy: 0.6766666650772095, Test Accuracy: 0.6341463327407837
# Epoch 940, Average Outcome Loss: 0.599976372718811, Average Accuracy: 0.7166666626930237, Test Accuracy: 0.6585366129875183
# Epoch 945, Average Outcome Loss: 0.5808209180831909, Average Accuracy: 0.699999988079071, Test Accuracy: 0.6585366129875183
# Epoch 950, Average Outcome Loss: 0.5600137591362, Average Accuracy: 0.753333330154419, Test Accuracy: 0.6341463327407837
# Epoch 955, Average Outcome Loss: 0.5716070413589478, Average Accuracy: 0.7599999904632568, Test Accuracy: 0.6341463327407837
# Epoch 960, Average Outcome Loss: 0.5896347284317016, Average Accuracy: 0.6700000047683716, Test Accuracy: 0.6341463327407837
# Epoch 965, Average Outcome Loss: 0.5833967804908753, Average Accuracy: 0.7166666626930237, Test Accuracy: 0.6585366129875183
# Epoch 970, Average Outcome Loss: 0.593137800693512, Average Accuracy: 0.6533333420753479, Test Accuracy: 0.6585366129875183
# Epoch 975, Average Outcome Loss: 0.5919546723365784, Average Accuracy: 0.7033333301544189, Test Accuracy: 0.6585366129875183
# Epoch 980, Average Outcome Loss: 0.6073271632194519, Average Accuracy: 0.7033333301544189, Test Accuracy: 0.6585366129875183
# Epoch 985, Average Outcome Loss: 0.5765475153923034, Average Accuracy: 0.7266666650772095, Test Accuracy: 0.6585366129875183
# Epoch 990, Average Outcome Loss: 0.5971026062965393, Average Accuracy: 0.6833333373069763, Test Accuracy: 0.6585366129875183
# Epoch 995, Average Outcome Loss: 0.5852712035179138, Average Accuracy: 0.7166666626930237, Test Accuracy: 0.6341463327407837
# Epoch 1000, Average Outcome Loss: 0.590899395942688, Average Accuracy: 0.7066666603088378, Test Accuracy: 0.6341463327407837
# Epoch 1005, Average Outcome Loss: 0.5906183838844299, Average Accuracy: 0.6666666507720947, Test Accuracy: 0.6341463327407837
# Epoch 1010, Average Outcome Loss: 0.5715197801589966, Average Accuracy: 0.7300000071525574, Test Accuracy: 0.6341463327407837
# Epoch 1015, Average Outcome Loss: 0.592447817325592, Average Accuracy: 0.6766666650772095, Test Accuracy: 0.6341463327407837
# Epoch 1020, Average Outcome Loss: 0.598112964630127, Average Accuracy: 0.70333331823349, Test Accuracy: 0.6585366129875183
# Epoch 1025, Average Outcome Loss: 0.5678446054458618, Average Accuracy: 0.7100000023841858, Test Accuracy: 0.6585366129875183
# Epoch 1030, Average Outcome Loss: 0.6084088444709778, Average Accuracy: 0.6866666555404664, Test Accuracy: 0.6341463327407837
# Epoch 1035, Average Outcome Loss: 0.6203988671302796, Average Accuracy: 0.6699999809265137, Test Accuracy: 0.6341463327407837
# Epoch 1040, Average Outcome Loss: 0.5731077909469604, Average Accuracy: 0.7466666579246521, Test Accuracy: 0.6341463327407837
# Epoch 1045, Average Outcome Loss: 0.6228576898574829, Average Accuracy: 0.6233333349227905, Test Accuracy: 0.6585366129875183
# Epoch 1050, Average Outcome Loss: 0.5784246921539307, Average Accuracy: 0.7300000071525574, Test Accuracy: 0.6341463327407837
# Epoch 1055, Average Outcome Loss: 0.6033954501152039, Average Accuracy: 0.6633333325386047, Test Accuracy: 0.6341463327407837
# Epoch 1060, Average Outcome Loss: 0.5791415452957154, Average Accuracy: 0.7033333301544189, Test Accuracy: 0.6585366129875183
# Epoch 1065, Average Outcome Loss: 0.6100780367851257, Average Accuracy: 0.6466666698455811, Test Accuracy: 0.6585366129875183
# Epoch 1070, Average Outcome Loss: 0.5856716156005859, Average Accuracy: 0.7066666603088378, Test Accuracy: 0.6341463327407837
# Epoch 1075, Average Outcome Loss: 0.6024746298789978, Average Accuracy: 0.6866666555404664, Test Accuracy: 0.6341463327407837
# Epoch 1080, Average Outcome Loss: 0.5807564616203308, Average Accuracy: 0.7266666889190674, Test Accuracy: 0.6341463327407837
# Epoch 1085, Average Outcome Loss: 0.6009902954101562, Average Accuracy: 0.7100000023841858, Test Accuracy: 0.6585366129875183
# Epoch 1090, Average Outcome Loss: 0.5982631921768189, Average Accuracy: 0.6566666603088379, Test Accuracy: 0.6585366129875183
# Epoch 1095, Average Outcome Loss: 0.5953402757644654, Average Accuracy: 0.6766666650772095, Test Accuracy: 0.6585366129875183
# Epoch 1100, Average Outcome Loss: 0.5687338352203369, Average Accuracy: 0.7299999833106995, Test Accuracy: 0.6341463327407837
# Epoch 1105, Average Outcome Loss: 0.5781632781028747, Average Accuracy: 0.6899999976158142, Test Accuracy: 0.6585366129875183
# Epoch 1110, Average Outcome Loss: 0.5861582159996033, Average Accuracy: 0.6933333396911621, Test Accuracy: 0.6341463327407837
# Epoch 1115, Average Outcome Loss: 0.5782986283302307, Average Accuracy: 0.696666669845581, Test Accuracy: 0.6341463327407837
# Epoch 1120, Average Outcome Loss: 0.6007279992103577, Average Accuracy: 0.7199999928474426, Test Accuracy: 0.6341463327407837
# Epoch 1125, Average Outcome Loss: 0.5734751462936402, Average Accuracy: 0.7033333301544189, Test Accuracy: 0.6341463327407837
# Epoch 1130, Average Outcome Loss: 0.5770923972129822, Average Accuracy: 0.6899999856948853, Test Accuracy: 0.6585366129875183
# Epoch 1135, Average Outcome Loss: 0.5932539820671081, Average Accuracy: 0.6233333230018616, Test Accuracy: 0.6585366129875183
# Epoch 1140, Average Outcome Loss: 0.5786365151405335, Average Accuracy: 0.7, Test Accuracy: 0.6341463327407837
# Epoch 1145, Average Outcome Loss: 0.6035646080970765, Average Accuracy: 0.6899999976158142, Test Accuracy: 0.6341463327407837
# Epoch 1150, Average Outcome Loss: 0.5542018175125122, Average Accuracy: 0.7366666555404663, Test Accuracy: 0.6585366129875183
# Epoch 1155, Average Outcome Loss: 0.5836724758148193, Average Accuracy: 0.6633333325386047, Test Accuracy: 0.6585366129875183
# Epoch 1160, Average Outcome Loss: 0.584626579284668, Average Accuracy: 0.6933333277702332, Test Accuracy: 0.6341463327407837
# Epoch 1165, Average Outcome Loss: 0.5757746815681457, Average Accuracy: 0.699999988079071, Test Accuracy: 0.6585366129875183
# Epoch 1170, Average Outcome Loss: 0.6017502307891845, Average Accuracy: 0.6799999952316285, Test Accuracy: 0.6341463327407837
# Epoch 1175, Average Outcome Loss: 0.5846209406852723, Average Accuracy: 0.7200000047683716, Test Accuracy: 0.6341463327407837
# Epoch 1180, Average Outcome Loss: 0.5797285079956055, Average Accuracy: 0.6900000095367431, Test Accuracy: 0.6585366129875183
# Epoch 1185, Average Outcome Loss: 0.5716375470161438, Average Accuracy: 0.7033333420753479, Test Accuracy: 0.6585366129875183
# Epoch 1190, Average Outcome Loss: 0.5756109356880188, Average Accuracy: 0.6800000071525574, Test Accuracy: 0.6341463327407837
# Epoch 1195, Average Outcome Loss: 0.5801265835762024, Average Accuracy: 0.6966666579246521, Test Accuracy: 0.6341463327407837
# Epoch 1200, Average Outcome Loss: 0.5634214520454407, Average Accuracy: 0.6966666579246521, Test Accuracy: 0.6341463327407837
# Epoch 1205, Average Outcome Loss: 0.5840998291969299, Average Accuracy: 0.696666669845581, Test Accuracy: 0.6341463327407837
# Epoch 1210, Average Outcome Loss: 0.5906744122505188, Average Accuracy: 0.6833333373069763, Test Accuracy: 0.6341463327407837
# Epoch 1215, Average Outcome Loss: 0.5777364015579224, Average Accuracy: 0.6766666531562805, Test Accuracy: 0.6585366129875183
# Epoch 1220, Average Outcome Loss: 0.5624485850334168, Average Accuracy: 0.7199999928474426, Test Accuracy: 0.6585366129875183
# Epoch 1225, Average Outcome Loss: 0.5742071866989136, Average Accuracy: 0.7133333325386048, Test Accuracy: 0.6585366129875183
# Epoch 1230, Average Outcome Loss: 0.5524576783180237, Average Accuracy: 0.7566666841506958, Test Accuracy: 0.6341463327407837
# Epoch 1235, Average Outcome Loss: 0.5581033587455749, Average Accuracy: 0.7066666722297669, Test Accuracy: 0.6585366129875183
# Epoch 1240, Average Outcome Loss: 0.5662553429603576, Average Accuracy: 0.7066666603088378, Test Accuracy: 0.6585366129875183
# Epoch 1245, Average Outcome Loss: 0.5428360939025879, Average Accuracy: 0.7699999928474426, Test Accuracy: 0.6341463327407837
# Epoch 1250, Average Outcome Loss: 0.5693071007728576, Average Accuracy: 0.7, Test Accuracy: 0.6341463327407837
# Epoch 1255, Average Outcome Loss: 0.5717657804489136, Average Accuracy: 0.6700000047683716, Test Accuracy: 0.6585366129875183
# Epoch 1260, Average Outcome Loss: 0.5630147218704223, Average Accuracy: 0.7166666746139526, Test Accuracy: 0.6585366129875183
# Epoch 1265, Average Outcome Loss: 0.5579383134841919, Average Accuracy: 0.7466666579246521, Test Accuracy: 0.6341463327407837
# Epoch 1270, Average Outcome Loss: 0.591258955001831, Average Accuracy: 0.6933333277702332, Test Accuracy: 0.6341463327407837
# Epoch 1275, Average Outcome Loss: 0.5770053267478943, Average Accuracy: 0.7033333301544189, Test Accuracy: 0.6341463327407837
# Epoch 1280, Average Outcome Loss: 0.571164333820343, Average Accuracy: 0.7033333420753479, Test Accuracy: 0.6341463327407837
# Epoch 1285, Average Outcome Loss: 0.5479937553405761, Average Accuracy: 0.7333333253860473, Test Accuracy: 0.6585366129875183
# Epoch 1290, Average Outcome Loss: 0.5422765731811523, Average Accuracy: 0.7533333420753479, Test Accuracy: 0.6341463327407837
# Epoch 1295, Average Outcome Loss: 0.5788984417915344, Average Accuracy: 0.7133333325386048, Test Accuracy: 0.6341463327407837
# Epoch 1300, Average Outcome Loss: 0.5884379029273987, Average Accuracy: 0.6833333373069763, Test Accuracy: 0.6341463327407837
# Epoch 1305, Average Outcome Loss: 0.5626822710037231, Average Accuracy: 0.70333331823349, Test Accuracy: 0.6341463327407837
# Epoch 1310, Average Outcome Loss: 0.5534127831459046, Average Accuracy: 0.7033333420753479, Test Accuracy: 0.6341463327407837
# Epoch 1315, Average Outcome Loss: 0.5601472973823547, Average Accuracy: 0.7433333277702332, Test Accuracy: 0.6341463327407837
# Epoch 1320, Average Outcome Loss: 0.5697139978408814, Average Accuracy: 0.7, Test Accuracy: 0.6341463327407837
# Epoch 1325, Average Outcome Loss: 0.5679617166519165, Average Accuracy: 0.6866666674613953, Test Accuracy: 0.6341463327407837
# Epoch 1330, Average Outcome Loss: 0.5617681264877319, Average Accuracy: 0.7366666793823242, Test Accuracy: 0.6341463327407837
# Epoch 1335, Average Outcome Loss: 0.5664552807807922, Average Accuracy: 0.7366666555404663, Test Accuracy: 0.6585366129875183
# Epoch 1340, Average Outcome Loss: 0.5555901885032654, Average Accuracy: 0.7099999904632568, Test Accuracy: 0.6585366129875183
# Epoch 1345, Average Outcome Loss: 0.537907749414444, Average Accuracy: 0.7133333206176757, Test Accuracy: 0.6341463327407837
# Epoch 1350, Average Outcome Loss: 0.5767032861709595, Average Accuracy: 0.696666669845581, Test Accuracy: 0.6341463327407837
# Epoch 1355, Average Outcome Loss: 0.5887797713279724, Average Accuracy: 0.6233333349227905, Test Accuracy: 0.6341463327407837
# Epoch 1360, Average Outcome Loss: 0.5811819434165955, Average Accuracy: 0.6733333230018616, Test Accuracy: 0.6341463327407837
# Epoch 1365, Average Outcome Loss: 0.5718994498252868, Average Accuracy: 0.7299999952316284, Test Accuracy: 0.6341463327407837
# Epoch 1370, Average Outcome Loss: 0.5514104127883911, Average Accuracy: 0.7300000071525574, Test Accuracy: 0.6341463327407837
# Epoch 1375, Average Outcome Loss: 0.5663327574729919, Average Accuracy: 0.6933333277702332, Test Accuracy: 0.6341463327407837
# Epoch 1380, Average Outcome Loss: 0.576362943649292, Average Accuracy: 0.6833333134651184, Test Accuracy: 0.6585366129875183
# Epoch 1385, Average Outcome Loss: 0.5669321060180664, Average Accuracy: 0.7033333420753479, Test Accuracy: 0.6341463327407837
# Epoch 1390, Average Outcome Loss: 0.553296560049057, Average Accuracy: 0.7066666722297669, Test Accuracy: 0.6341463327407837
# Epoch 1395, Average Outcome Loss: 0.5592457771301269, Average Accuracy: 0.7266666650772095, Test Accuracy: 0.6341463327407837
# Epoch 1400, Average Outcome Loss: 0.5599607110023499, Average Accuracy: 0.7166666865348816, Test Accuracy: 0.6341463327407837
# Epoch 1405, Average Outcome Loss: 0.5462505102157593, Average Accuracy: 0.7533333420753479, Test Accuracy: 0.6341463327407837
# Epoch 1410, Average Outcome Loss: 0.566760778427124, Average Accuracy: 0.6866666793823242, Test Accuracy: 0.6341463327407837
# Epoch 1415, Average Outcome Loss: 0.5607704639434814, Average Accuracy: 0.7033333420753479, Test Accuracy: 0.6341463327407837
# Epoch 1420, Average Outcome Loss: 0.5461507260799408, Average Accuracy: 0.7566666603088379, Test Accuracy: 0.6341463327407837
# Epoch 1425, Average Outcome Loss: 0.5408892273902893, Average Accuracy: 0.7566666722297668, Test Accuracy: 0.6341463327407837
# Epoch 1430, Average Outcome Loss: 0.5474326729774475, Average Accuracy: 0.7199999928474426, Test Accuracy: 0.6341463327407837
# Epoch 1435, Average Outcome Loss: 0.5606272935867309, Average Accuracy: 0.6733333349227906, Test Accuracy: 0.6341463327407837
# Epoch 1440, Average Outcome Loss: 0.5821276545524597, Average Accuracy: 0.7199999809265136, Test Accuracy: 0.6341463327407837
# Epoch 1445, Average Outcome Loss: 0.5553144693374634, Average Accuracy: 0.7100000023841858, Test Accuracy: 0.6341463327407837
# Epoch 1450, Average Outcome Loss: 0.5500672698020935, Average Accuracy: 0.7233333230018616, Test Accuracy: 0.6341463327407837
# Epoch 1455, Average Outcome Loss: 0.5341111183166504, Average Accuracy: 0.7466666579246521, Test Accuracy: 0.6341463327407837
# Epoch 1460, Average Outcome Loss: 0.5651142239570618, Average Accuracy: 0.7133333325386048, Test Accuracy: 0.6341463327407837
# Epoch 1465, Average Outcome Loss: 0.5700659155845642, Average Accuracy: 0.7, Test Accuracy: 0.6341463327407837
# Epoch 1470, Average Outcome Loss: 0.5746524691581726, Average Accuracy: 0.6866666555404664, Test Accuracy: 0.6341463327407837
# Epoch 1475, Average Outcome Loss: 0.5546031832695008, Average Accuracy: 0.6866666674613953, Test Accuracy: 0.6341463327407837
# Epoch 1480, Average Outcome Loss: 0.5409847438335419, Average Accuracy: 0.7333333373069764, Test Accuracy: 0.6341463327407837
# Epoch 1485, Average Outcome Loss: 0.5923078536987305, Average Accuracy: 0.6566666722297668, Test Accuracy: 0.6341463327407837
# Epoch 1490, Average Outcome Loss: 0.5474341869354248, Average Accuracy: 0.7399999976158143, Test Accuracy: 0.6341463327407837
# Epoch 1495, Average Outcome Loss: 0.5277532339096069, Average Accuracy: 0.7399999976158143, Test Accuracy: 0.6341463327407837
# Epoch 1500, Average Outcome Loss: 0.5394504547119141, Average Accuracy: 0.7433333396911621, Test Accuracy: 0.6341463327407837
# Epoch 1505, Average Outcome Loss: 0.5389706790447235, Average Accuracy: 0.7133333325386048, Test Accuracy: 0.6341463327407837
# Epoch 1510, Average Outcome Loss: 0.5301048159599304, Average Accuracy: 0.75, Test Accuracy: 0.6341463327407837
# Epoch 1515, Average Outcome Loss: 0.5397514700889587, Average Accuracy: 0.7333333373069764, Test Accuracy: 0.6341463327407837
# Epoch 1520, Average Outcome Loss: 0.5678357481956482, Average Accuracy: 0.7066666722297669, Test Accuracy: 0.6341463327407837
# Epoch 1525, Average Outcome Loss: 0.5939257621765137, Average Accuracy: 0.6233333349227905, Test Accuracy: 0.6341463327407837
# Epoch 1530, Average Outcome Loss: 0.5502238750457764, Average Accuracy: 0.7, Test Accuracy: 0.6585366129875183
# Epoch 1535, Average Outcome Loss: 0.5425862193107605, Average Accuracy: 0.7366666674613953, Test Accuracy: 0.6341463327407837
# Epoch 1540, Average Outcome Loss: 0.5404915392398835, Average Accuracy: 0.7533333420753479, Test Accuracy: 0.6341463327407837
# Epoch 1545, Average Outcome Loss: 0.5524871945381165, Average Accuracy: 0.7233333468437195, Test Accuracy: 0.6341463327407837
# Epoch 1550, Average Outcome Loss: 0.55263831615448, Average Accuracy: 0.65, Test Accuracy: 0.6585366129875183
# Epoch 1555, Average Outcome Loss: 0.5381811380386352, Average Accuracy: 0.7266666650772095, Test Accuracy: 0.6341463327407837
# Epoch 1560, Average Outcome Loss: 0.5572744488716126, Average Accuracy: 0.7066666603088378, Test Accuracy: 0.6341463327407837
# Epoch 1565, Average Outcome Loss: 0.5776874542236328, Average Accuracy: 0.6933333396911621, Test Accuracy: 0.6341463327407837
# Epoch 1570, Average Outcome Loss: 0.5648751139640809, Average Accuracy: 0.7199999928474426, Test Accuracy: 0.6341463327407837
# Epoch 1575, Average Outcome Loss: 0.5272010326385498, Average Accuracy: 0.7500000119209289, Test Accuracy: 0.6341463327407837
# Epoch 1580, Average Outcome Loss: 0.5252092003822326, Average Accuracy: 0.7299999952316284, Test Accuracy: 0.6341463327407837
# Epoch 1585, Average Outcome Loss: 0.5604363799095153, Average Accuracy: 0.7133333086967468, Test Accuracy: 0.6341463327407837
# Epoch 1590, Average Outcome Loss: 0.5619361519813537, Average Accuracy: 0.7266666650772095, Test Accuracy: 0.6341463327407837
# Epoch 1595, Average Outcome Loss: 0.5303421795368195, Average Accuracy: 0.7166666746139526, Test Accuracy: 0.6341463327407837
# Epoch 1600, Average Outcome Loss: 0.5276281416416169, Average Accuracy: 0.7100000023841858, Test Accuracy: 0.6341463327407837
# Epoch 1605, Average Outcome Loss: 0.5822623133659363, Average Accuracy: 0.6799999952316285, Test Accuracy: 0.6341463327407837
# Epoch 1610, Average Outcome Loss: 0.5336750984191895, Average Accuracy: 0.7133333325386048, Test Accuracy: 0.6341463327407837
# Epoch 1615, Average Outcome Loss: 0.5652448296546936, Average Accuracy: 0.7200000047683716, Test Accuracy: 0.6585366129875183
# Epoch 1620, Average Outcome Loss: 0.560437536239624, Average Accuracy: 0.7033333301544189, Test Accuracy: 0.6341463327407837
# Epoch 1625, Average Outcome Loss: 0.5513030171394349, Average Accuracy: 0.7066666722297669, Test Accuracy: 0.6341463327407837
# Epoch 1630, Average Outcome Loss: 0.5643596172332763, Average Accuracy: 0.7333333253860473, Test Accuracy: 0.6341463327407837
# Epoch 1635, Average Outcome Loss: 0.5320448815822602, Average Accuracy: 0.7233333349227905, Test Accuracy: 0.6341463327407837
# Epoch 1640, Average Outcome Loss: 0.533389663696289, Average Accuracy: 0.6866666555404664, Test Accuracy: 0.6341463327407837
# Epoch 1645, Average Outcome Loss: 0.521183443069458, Average Accuracy: 0.75, Test Accuracy: 0.6341463327407837
# Epoch 1650, Average Outcome Loss: 0.5494892358779907, Average Accuracy: 0.6700000047683716, Test Accuracy: 0.6341463327407837
# Epoch 1655, Average Outcome Loss: 0.543793547153473, Average Accuracy: 0.7166666746139526, Test Accuracy: 0.6341463327407837
# Epoch 1660, Average Outcome Loss: 0.5317819356918335, Average Accuracy: 0.7333333253860473, Test Accuracy: 0.6341463327407837
# Epoch 1665, Average Outcome Loss: 0.5526053667068481, Average Accuracy: 0.746666669845581, Test Accuracy: 0.6341463327407837
# Epoch 1670, Average Outcome Loss: 0.5617796421051026, Average Accuracy: 0.7100000023841858, Test Accuracy: 0.6341463327407837
# Epoch 1675, Average Outcome Loss: 0.5219309389591217, Average Accuracy: 0.753333330154419, Test Accuracy: 0.6341463327407837
# Epoch 1680, Average Outcome Loss: 0.5123774588108063, Average Accuracy: 0.7666666746139527, Test Accuracy: 0.6341463327407837
# Epoch 1685, Average Outcome Loss: 0.5618484377861023, Average Accuracy: 0.7133333206176757, Test Accuracy: 0.6341463327407837
# Epoch 1690, Average Outcome Loss: 0.5237068414688111, Average Accuracy: 0.7399999976158143, Test Accuracy: 0.6341463327407837
# Epoch 1695, Average Outcome Loss: 0.538706636428833, Average Accuracy: 0.7066666603088378, Test Accuracy: 0.6341463327407837
# Epoch 1700, Average Outcome Loss: 0.5548879325389862, Average Accuracy: 0.7199999928474426, Test Accuracy: 0.6341463327407837
# Epoch 1705, Average Outcome Loss: 0.532759040594101, Average Accuracy: 0.7200000166893006, Test Accuracy: 0.6341463327407837
# Epoch 1710, Average Outcome Loss: 0.5459595561027527, Average Accuracy: 0.7, Test Accuracy: 0.6341463327407837
# Epoch 1715, Average Outcome Loss: 0.5544867515563965, Average Accuracy: 0.7266666650772095, Test Accuracy: 0.6341463327407837
# Epoch 1720, Average Outcome Loss: 0.544137179851532, Average Accuracy: 0.7399999976158143, Test Accuracy: 0.6341463327407837
# Epoch 1725, Average Outcome Loss: 0.5372419238090516, Average Accuracy: 0.7399999976158143, Test Accuracy: 0.6341463327407837
# Epoch 1730, Average Outcome Loss: 0.5335499167442321, Average Accuracy: 0.75, Test Accuracy: 0.6341463327407837
# Epoch 1735, Average Outcome Loss: 0.5479121446609497, Average Accuracy: 0.7099999904632568, Test Accuracy: 0.6341463327407837
# Epoch 1740, Average Outcome Loss: 0.5441736102104187, Average Accuracy: 0.7433333396911621, Test Accuracy: 0.6341463327407837
# Epoch 1745, Average Outcome Loss: 0.5099281013011933, Average Accuracy: 0.7633333325386047, Test Accuracy: 0.6341463327407837
# Epoch 1750, Average Outcome Loss: 0.5497307658195496, Average Accuracy: 0.7433333396911621, Test Accuracy: 0.6341463327407837
# Epoch 1755, Average Outcome Loss: 0.5383701980113983, Average Accuracy: 0.7633333325386047, Test Accuracy: 0.6341463327407837
# Epoch 1760, Average Outcome Loss: 0.5193027436733246, Average Accuracy: 0.7733333349227905, Test Accuracy: 0.6341463327407837
# Epoch 1765, Average Outcome Loss: 0.5250766396522522, Average Accuracy: 0.8133333325386047, Test Accuracy: 0.6341463327407837
# Epoch 1770, Average Outcome Loss: 0.5229345023632049, Average Accuracy: 0.7733333349227905, Test Accuracy: 0.6341463327407837
# Epoch 1775, Average Outcome Loss: 0.5387528777122498, Average Accuracy: 0.7266666650772095, Test Accuracy: 0.6341463327407837
# Epoch 1780, Average Outcome Loss: 0.5378337919712066, Average Accuracy: 0.7666666626930236, Test Accuracy: 0.6341463327407837
# Epoch 1785, Average Outcome Loss: 0.5313912630081177, Average Accuracy: 0.7399999976158143, Test Accuracy: 0.6341463327407837
# Epoch 1790, Average Outcome Loss: 0.5345823287963867, Average Accuracy: 0.7600000143051148, Test Accuracy: 0.6341463327407837
# Epoch 1795, Average Outcome Loss: 0.5384766101837158, Average Accuracy: 0.7666666746139527, Test Accuracy: 0.6341463327407837
# Epoch 1800, Average Outcome Loss: 0.5493505358695984, Average Accuracy: 0.7366666793823242, Test Accuracy: 0.6341463327407837
# Epoch 1805, Average Outcome Loss: 0.5780655264854431, Average Accuracy: 0.7, Test Accuracy: 0.6341463327407837
# Epoch 1810, Average Outcome Loss: 0.5221866130828857, Average Accuracy: 0.7666666746139527, Test Accuracy: 0.6341463327407837
# Epoch 1815, Average Outcome Loss: 0.5399102389812469, Average Accuracy: 0.7399999856948852, Test Accuracy: 0.6341463327407837
# Epoch 1820, Average Outcome Loss: 0.5073749244213104, Average Accuracy: 0.7633333325386047, Test Accuracy: 0.6341463327407837
# Epoch 1825, Average Outcome Loss: 0.5341164588928222, Average Accuracy: 0.7, Test Accuracy: 0.6341463327407837
# Epoch 1830, Average Outcome Loss: 0.535236942768097, Average Accuracy: 0.746666669845581, Test Accuracy: 0.6341463327407837
# Epoch 1835, Average Outcome Loss: 0.5284912467002869, Average Accuracy: 0.7733333349227905, Test Accuracy: 0.6341463327407837
# Epoch 1840, Average Outcome Loss: 0.5345231592655182, Average Accuracy: 0.7599999904632568, Test Accuracy: 0.6341463327407837
# Epoch 1845, Average Outcome Loss: 0.5288375854492188, Average Accuracy: 0.7433333396911621, Test Accuracy: 0.6341463327407837
# Epoch 1850, Average Outcome Loss: 0.5288644731044769, Average Accuracy: 0.7799999952316284, Test Accuracy: 0.6341463327407837
# Epoch 1855, Average Outcome Loss: 0.500711727142334, Average Accuracy: 0.7566666603088379, Test Accuracy: 0.6341463327407837
# Epoch 1860, Average Outcome Loss: 0.4973922073841095, Average Accuracy: 0.7899999976158142, Test Accuracy: 0.6341463327407837
# Epoch 1865, Average Outcome Loss: 0.5093524515628814, Average Accuracy: 0.7666666746139527, Test Accuracy: 0.6341463327407837
# Epoch 1870, Average Outcome Loss: 0.5013485550880432, Average Accuracy: 0.8, Test Accuracy: 0.6341463327407837
# Epoch 1875, Average Outcome Loss: 0.526958954334259, Average Accuracy: 0.7633333444595337, Test Accuracy: 0.6341463327407837
# Epoch 1880, Average Outcome Loss: 0.5419898986816406, Average Accuracy: 0.6966666579246521, Test Accuracy: 0.6341463327407837
# Epoch 1885, Average Outcome Loss: 0.5586262047290802, Average Accuracy: 0.7233333349227905, Test Accuracy: 0.6341463327407837
# Epoch 1890, Average Outcome Loss: 0.5107388198375702, Average Accuracy: 0.7566666722297668, Test Accuracy: 0.6341463327407837
# Epoch 1895, Average Outcome Loss: 0.5089334905147552, Average Accuracy: 0.7599999904632568, Test Accuracy: 0.6341463327407837
# Epoch 1900, Average Outcome Loss: 0.5146260559558868, Average Accuracy: 0.7766666650772095, Test Accuracy: 0.6341463327407837
# Epoch 1905, Average Outcome Loss: 0.5092657089233399, Average Accuracy: 0.7366666674613953, Test Accuracy: 0.6341463327407837
# Epoch 1910, Average Outcome Loss: 0.5257459998130798, Average Accuracy: 0.7400000095367432, Test Accuracy: 0.6341463327407837
# Epoch 1915, Average Outcome Loss: 0.5292771458625793, Average Accuracy: 0.7566666722297668, Test Accuracy: 0.6341463327407837
# Epoch 1920, Average Outcome Loss: 0.5242518246173858, Average Accuracy: 0.753333330154419, Test Accuracy: 0.6341463327407837
# ...
# Epoch 6425, Average Outcome Loss: 0.25114436745643615, Average Accuracy: 0.8966666698455811, Test Accuracy: 0.6585366129875183
# Epoch 6430, Average Outcome Loss: 0.26501524746418, Average Accuracy: 0.9100000023841858, Test Accuracy: 0.6585366129875183
# Epoch 6435, Average Outcome Loss: 0.27263605296611787, Average Accuracy: 0.9133333206176758, Test Accuracy: 0.6341463327407837
# Epoch 6440, Average Outcome Loss: 0.23157841861248016, Average Accuracy: 0.9533333301544189, Test Accuracy: 0.6829268336296082
# Epoch 6445, Average Outcome Loss: 0.23419034481048584, Average Accuracy: 0.9166666746139527, Test Accuracy: 0.6585366129875183
# Epoch 6450, Average Outcome Loss: 0.23102861642837524, Average Accuracy: 0.9133333325386047, Test Accuracy: 0.6585366129875183
# Epoch 6455, Average Outcome Loss: 0.26832892596721647, Average Accuracy: 0.9100000143051148, Test Accuracy: 0.6341463327407837
# Epoch 6460, Average Outcome Loss: 0.23562952876091003, Average Accuracy: 0.9366666555404664, Test Accuracy: 0.6341463327407837
# Epoch 6465, Average Outcome Loss: 0.2447665423154831, Average Accuracy: 0.9133333325386047, Test Accuracy: 0.6341463327407837
# Epoch 6470, Average Outcome Loss: 0.25303625762462617, Average Accuracy: 0.9200000047683716, Test Accuracy: 0.6341463327407837
# Epoch 6475, Average Outcome Loss: 0.2743506133556366, Average Accuracy: 0.8799999952316284, Test Accuracy: 0.6341463327407837
# Epoch 6480, Average Outcome Loss: 0.22506943345069885, Average Accuracy: 0.9433333277702332, Test Accuracy: 0.6341463327407837
# Epoch 6485, Average Outcome Loss: 0.26332602500915525, Average Accuracy: 0.8933333396911621, Test Accuracy: 0.6341463327407837
# Epoch 6490, Average Outcome Loss: 0.24757250249385834, Average Accuracy: 0.9333333253860474, Test Accuracy: 0.6341463327407837
# Epoch 6495, Average Outcome Loss: 0.26683890223503115, Average Accuracy: 0.9266666650772095, Test Accuracy: 0.6341463327407837
# Epoch 6500, Average Outcome Loss: 0.272050940990448, Average Accuracy: 0.8966666698455811, Test Accuracy: 0.6585366129875183
# Epoch 6505, Average Outcome Loss: 0.2457984834909439, Average Accuracy: 0.9299999952316285, Test Accuracy: 0.6341463327407837
# Epoch 6510, Average Outcome Loss: 0.24276132881641388, Average Accuracy: 0.9233333230018616, Test Accuracy: 0.6341463327407837
# Epoch 6515, Average Outcome Loss: 0.2579454302787781, Average Accuracy: 0.9066666603088379, Test Accuracy: 0.6585366129875183
# Epoch 6520, Average Outcome Loss: 0.250222384929657, Average Accuracy: 0.9166666626930237, Test Accuracy: 0.6341463327407837
# Epoch 6525, Average Outcome Loss: 0.2194245547056198, Average Accuracy: 0.946666669845581, Test Accuracy: 0.6341463327407837
# Epoch 6530, Average Outcome Loss: 0.25123782455921173, Average Accuracy: 0.9299999833106994, Test Accuracy: 0.6341463327407837
# Epoch 6535, Average Outcome Loss: 0.23604277968406678, Average Accuracy: 0.9166666626930237, Test Accuracy: 0.6341463327407837
# Epoch 6540, Average Outcome Loss: 0.25307286977767945, Average Accuracy: 0.9266666650772095, Test Accuracy: 0.6341463327407837
# Epoch 6545, Average Outcome Loss: 0.2358667880296707, Average Accuracy: 0.9133333325386047, Test Accuracy: 0.6585366129875183
# Epoch 6550, Average Outcome Loss: 0.25524560511112215, Average Accuracy: 0.9233333349227906, Test Accuracy: 0.6341463327407837
# Epoch 6555, Average Outcome Loss: 0.24009388387203218, Average Accuracy: 0.9199999928474426, Test Accuracy: 0.6341463327407837
# Epoch 6560, Average Outcome Loss: 0.26644032895565034, Average Accuracy: 0.903333330154419, Test Accuracy: 0.6341463327407837
# Epoch 6565, Average Outcome Loss: 0.25003792345523834, Average Accuracy: 0.9100000023841858, Test Accuracy: 0.6585366129875183
# Epoch 6570, Average Outcome Loss: 0.2371436208486557, Average Accuracy: 0.9233333349227906, Test Accuracy: 0.6585366129875183
# Epoch 6575, Average Outcome Loss: 0.23470440208911897, Average Accuracy: 0.9333333253860474, Test Accuracy: 0.6341463327407837
# Epoch 6580, Average Outcome Loss: 0.2444010853767395, Average Accuracy: 0.9266666531562805, Test Accuracy: 0.6341463327407837
# Epoch 6585, Average Outcome Loss: 0.2354943722486496, Average Accuracy: 0.95, Test Accuracy: 0.6585366129875183
# Epoch 6590, Average Outcome Loss: 0.2411784291267395, Average Accuracy: 0.9233333230018616, Test Accuracy: 0.6585366129875183
# Epoch 6595, Average Outcome Loss: 0.24960801005363464, Average Accuracy: 0.9299999952316285, Test Accuracy: 0.6341463327407837
# Epoch 6600, Average Outcome Loss: 0.23532565534114838, Average Accuracy: 0.9399999976158142, Test Accuracy: 0.6341463327407837
# Epoch 6605, Average Outcome Loss: 0.2703610688447952, Average Accuracy: 0.9100000023841858, Test Accuracy: 0.6585366129875183
# Epoch 6610, Average Outcome Loss: 0.2401231735944748, Average Accuracy: 0.9300000071525574, Test Accuracy: 0.6585366129875183
# Epoch 6615, Average Outcome Loss: 0.228266641497612, Average Accuracy: 0.949999988079071, Test Accuracy: 0.6341463327407837
# Epoch 6620, Average Outcome Loss: 0.23354020118713378, Average Accuracy: 0.9333333253860474, Test Accuracy: 0.6341463327407837
# Epoch 6625, Average Outcome Loss: 0.23664483428001404, Average Accuracy: 0.9433333277702332, Test Accuracy: 0.6585366129875183
# Epoch 6630, Average Outcome Loss: 0.26979495882987975, Average Accuracy: 0.9133333206176758, Test Accuracy: 0.6341463327407837
# Epoch 6635, Average Outcome Loss: 0.29675379395484924, Average Accuracy: 0.9066666722297668, Test Accuracy: 0.6585366129875183
# Epoch 6640, Average Outcome Loss: 0.22521818578243255, Average Accuracy: 0.9399999976158142, Test Accuracy: 0.6341463327407837
# Epoch 6645, Average Outcome Loss: 0.23453395664691926, Average Accuracy: 0.9466666579246521, Test Accuracy: 0.6341463327407837
# Epoch 6650, Average Outcome Loss: 0.24680131077766418, Average Accuracy: 0.9199999928474426, Test Accuracy: 0.6585366129875183
# Epoch 6655, Average Outcome Loss: 0.2509794145822525, Average Accuracy: 0.9533333301544189, Test Accuracy: 0.6341463327407837
# Epoch 6660, Average Outcome Loss: 0.23509370684623718, Average Accuracy: 0.9233333349227906, Test Accuracy: 0.6585366129875183
# Epoch 6665, Average Outcome Loss: 0.2770343452692032, Average Accuracy: 0.9266666650772095, Test Accuracy: 0.6829268336296082
# Epoch 6670, Average Outcome Loss: 0.22641660273075104, Average Accuracy: 0.9333333373069763, Test Accuracy: 0.6341463327407837
# Epoch 6675, Average Outcome Loss: 0.26376546621322633, Average Accuracy: 0.899999988079071, Test Accuracy: 0.6341463327407837
# Epoch 6680, Average Outcome Loss: 0.2484414428472519, Average Accuracy: 0.8899999976158142, Test Accuracy: 0.6829268336296082
# Epoch 6685, Average Outcome Loss: 0.25647794306278227, Average Accuracy: 0.9066666722297668, Test Accuracy: 0.6585366129875183
# Epoch 6690, Average Outcome Loss: 0.25036900639534, Average Accuracy: 0.9266666650772095, Test Accuracy: 0.6341463327407837
# Epoch 6695, Average Outcome Loss: 0.23249787986278533, Average Accuracy: 0.9433333277702332, Test Accuracy: 0.6341463327407837
# Epoch 6700, Average Outcome Loss: 0.24545506834983827, Average Accuracy: 0.9433333277702332, Test Accuracy: 0.6585366129875183
# Epoch 6705, Average Outcome Loss: 0.2450157195329666, Average Accuracy: 0.9233333349227906, Test Accuracy: 0.6585366129875183
# Epoch 6710, Average Outcome Loss: 0.23645776510238647, Average Accuracy: 0.9466666579246521, Test Accuracy: 0.6585366129875183
# Epoch 6715, Average Outcome Loss: 0.2223730653524399, Average Accuracy: 0.9533333301544189, Test Accuracy: 0.6341463327407837
# Epoch 6720, Average Outcome Loss: 0.23807883858680726, Average Accuracy: 0.9099999904632569, Test Accuracy: 0.6829268336296082
# Epoch 6725, Average Outcome Loss: 0.22506118416786194, Average Accuracy: 0.9466666579246521, Test Accuracy: 0.6341463327407837
# Epoch 6730, Average Outcome Loss: 0.2406608760356903, Average Accuracy: 0.9233333468437195, Test Accuracy: 0.6341463327407837
# Epoch 6735, Average Outcome Loss: 0.21201370656490326, Average Accuracy: 0.9433333277702332, Test Accuracy: 0.707317054271698
# Epoch 6740, Average Outcome Loss: 0.2326749801635742, Average Accuracy: 0.9299999952316285, Test Accuracy: 0.6341463327407837
# Epoch 6745, Average Outcome Loss: 0.24452386498451234, Average Accuracy: 0.9366666555404664, Test Accuracy: 0.6341463327407837
# Epoch 6750, Average Outcome Loss: 0.25914327800273895, Average Accuracy: 0.9399999976158142, Test Accuracy: 0.6829268336296082
# Epoch 6755, Average Outcome Loss: 0.2647563010454178, Average Accuracy: 0.9, Test Accuracy: 0.707317054271698
# Epoch 6760, Average Outcome Loss: 0.24428963661193848, Average Accuracy: 0.9200000047683716, Test Accuracy: 0.6585366129875183
# Epoch 6765, Average Outcome Loss: 0.22205977141857147, Average Accuracy: 0.9399999856948853, Test Accuracy: 0.6829268336296082
# Epoch 6770, Average Outcome Loss: 0.23166399598121643, Average Accuracy: 0.9099999904632569, Test Accuracy: 0.707317054271698
# Epoch 6775, Average Outcome Loss: 0.20829307436943054, Average Accuracy: 0.9566666483879089, Test Accuracy: 0.6585366129875183
# Epoch 6780, Average Outcome Loss: 0.20320126116275788, Average Accuracy: 0.9433333158493042, Test Accuracy: 0.6829268336296082
# Epoch 6785, Average Outcome Loss: 0.2448782354593277, Average Accuracy: 0.9266666769981384, Test Accuracy: 0.6585366129875183
# Epoch 6790, Average Outcome Loss: 0.22843626737594605, Average Accuracy: 0.9399999856948853, Test Accuracy: 0.6341463327407837
# Epoch 6795, Average Outcome Loss: 0.2288217455148697, Average Accuracy: 0.946666669845581, Test Accuracy: 0.6341463327407837
# Epoch 6800, Average Outcome Loss: 0.26178129613399503, Average Accuracy: 0.9166666626930237, Test Accuracy: 0.6585366129875183
# Epoch 6805, Average Outcome Loss: 0.2345411002635956, Average Accuracy: 0.9300000071525574, Test Accuracy: 0.6341463327407837
# Epoch 6810, Average Outcome Loss: 0.22866812944412232, Average Accuracy: 0.949999988079071, Test Accuracy: 0.6341463327407837
# Epoch 6815, Average Outcome Loss: 0.2502704977989197, Average Accuracy: 0.9133333444595337, Test Accuracy: 0.707317054271698
# Epoch 6820, Average Outcome Loss: 0.2196824550628662, Average Accuracy: 0.9466666579246521, Test Accuracy: 0.6585366129875183
# Epoch 6825, Average Outcome Loss: 0.2494812101125717, Average Accuracy: 0.95, Test Accuracy: 0.6341463327407837
# Epoch 6830, Average Outcome Loss: 0.22811867892742158, Average Accuracy: 0.9399999976158142, Test Accuracy: 0.6341463327407837
# Epoch 6835, Average Outcome Loss: 0.24774385690689088, Average Accuracy: 0.9366666555404664, Test Accuracy: 0.6341463327407837
# Epoch 6840, Average Outcome Loss: 0.21776995956897735, Average Accuracy: 0.9566666483879089, Test Accuracy: 0.6829268336296082
# Epoch 6845, Average Outcome Loss: 0.23646355271339417, Average Accuracy: 0.9399999856948853, Test Accuracy: 0.6341463327407837
# Epoch 6850, Average Outcome Loss: 0.22754005789756776, Average Accuracy: 0.9433333158493042, Test Accuracy: 0.6585366129875183
# Epoch 6855, Average Outcome Loss: 0.2134939581155777, Average Accuracy: 0.9566666722297669, Test Accuracy: 0.6341463327407837
# Epoch 6860, Average Outcome Loss: 0.24245527088642121, Average Accuracy: 0.9400000095367431, Test Accuracy: 0.6585366129875183
# Epoch 6865, Average Outcome Loss: 0.23045969903469085, Average Accuracy: 0.949999988079071, Test Accuracy: 0.707317054271698
# Epoch 6870, Average Outcome Loss: 0.21368875801563264, Average Accuracy: 0.9399999976158142, Test Accuracy: 0.6585366129875183
# Epoch 6875, Average Outcome Loss: 0.22541494369506837, Average Accuracy: 0.950000011920929, Test Accuracy: 0.6341463327407837
# Epoch 6880, Average Outcome Loss: 0.2407636135816574, Average Accuracy: 0.9233333230018616, Test Accuracy: 0.6829268336296082
# Epoch 6885, Average Outcome Loss: 0.2686076581478119, Average Accuracy: 0.8966666698455811, Test Accuracy: 0.6585366129875183
# Epoch 6890, Average Outcome Loss: 0.24513709545135498, Average Accuracy: 0.949999988079071, Test Accuracy: 0.6341463327407837
# Epoch 6895, Average Outcome Loss: 0.23072995543479918, Average Accuracy: 0.9466666579246521, Test Accuracy: 0.6829268336296082
# Epoch 6900, Average Outcome Loss: 0.2206392139196396, Average Accuracy: 0.949999988079071, Test Accuracy: 0.6585366129875183
# Epoch 6905, Average Outcome Loss: 0.2347782224416733, Average Accuracy: 0.9533333301544189, Test Accuracy: 0.6585366129875183
# Epoch 6910, Average Outcome Loss: 0.2250051736831665, Average Accuracy: 0.9333333253860474, Test Accuracy: 0.6341463327407837
# Epoch 6915, Average Outcome Loss: 0.21507591307163237, Average Accuracy: 0.9466666579246521, Test Accuracy: 0.6341463327407837
# Epoch 6920, Average Outcome Loss: 0.2258707195520401, Average Accuracy: 0.9600000023841858, Test Accuracy: 0.6585366129875183
# Epoch 6925, Average Outcome Loss: 0.23443116545677184, Average Accuracy: 0.9433333277702332, Test Accuracy: 0.6341463327407837
# Epoch 6930, Average Outcome Loss: 0.2301519989967346, Average Accuracy: 0.9266666769981384, Test Accuracy: 0.6585366129875183
# Epoch 6935, Average Outcome Loss: 0.23595681488513948, Average Accuracy: 0.9433333277702332, Test Accuracy: 0.6585366129875183
# Epoch 6940, Average Outcome Loss: 0.21587766110897064, Average Accuracy: 0.9533333301544189, Test Accuracy: 0.6341463327407837
# Epoch 6945, Average Outcome Loss: 0.2293129175901413, Average Accuracy: 0.9466666579246521, Test Accuracy: 0.6341463327407837
# Epoch 6950, Average Outcome Loss: 0.21049323081970214, Average Accuracy: 0.9333333253860474, Test Accuracy: 0.707317054271698
# Epoch 6955, Average Outcome Loss: 0.21067998111248015, Average Accuracy: 0.9599999904632568, Test Accuracy: 0.6341463327407837
# Epoch 6960, Average Outcome Loss: 0.22436790764331818, Average Accuracy: 0.9533333301544189, Test Accuracy: 0.6829268336296082
# Epoch 6965, Average Outcome Loss: 0.23093636929988862, Average Accuracy: 0.9333333373069763, Test Accuracy: 0.6829268336296082
# Epoch 6970, Average Outcome Loss: 0.21108003258705138, Average Accuracy: 0.9533333301544189, Test Accuracy: 0.6341463327407837
# Epoch 6975, Average Outcome Loss: 0.23450620472431183, Average Accuracy: 0.9566666603088378, Test Accuracy: 0.6829268336296082
# Epoch 6980, Average Outcome Loss: 0.21185003519058226, Average Accuracy: 0.9233333230018616, Test Accuracy: 0.707317054271698
# Epoch 6985, Average Outcome Loss: 0.22834431529045104, Average Accuracy: 0.9333333373069763, Test Accuracy: 0.6341463327407837
# Epoch 6990, Average Outcome Loss: 0.2409545123577118, Average Accuracy: 0.9166666507720947, Test Accuracy: 0.707317054271698
# Epoch 6995, Average Outcome Loss: 0.23804769217967986, Average Accuracy: 0.9233333230018616, Test Accuracy: 0.707317054271698
# Epoch 7000, Average Outcome Loss: 0.26702147126197817, Average Accuracy: 0.9233333230018616, Test Accuracy: 0.6097561120986938
# Epoch 7005, Average Outcome Loss: 0.20710180103778839, Average Accuracy: 0.95333331823349, Test Accuracy: 0.6829268336296082
# Epoch 7010, Average Outcome Loss: 0.23648750483989717, Average Accuracy: 0.9333333253860474, Test Accuracy: 0.6829268336296082
# Epoch 7015, Average Outcome Loss: 0.24716750383377076, Average Accuracy: 0.9199999928474426, Test Accuracy: 0.6585366129875183
# Epoch 7020, Average Outcome Loss: 0.2251907229423523, Average Accuracy: 0.9433333158493042, Test Accuracy: 0.6829268336296082
# Epoch 7025, Average Outcome Loss: 0.2286028355360031, Average Accuracy: 0.9300000071525574, Test Accuracy: 0.6585366129875183
# Epoch 7030, Average Outcome Loss: 0.2070760726928711, Average Accuracy: 0.9599999904632568, Test Accuracy: 0.6829268336296082
# Epoch 7035, Average Outcome Loss: 0.2102819561958313, Average Accuracy: 0.946666669845581, Test Accuracy: 0.6829268336296082
# Epoch 7040, Average Outcome Loss: 0.2376112759113312, Average Accuracy: 0.9233333230018616, Test Accuracy: 0.6341463327407837
# Epoch 7045, Average Outcome Loss: 0.2646342843770981, Average Accuracy: 0.9100000023841858, Test Accuracy: 0.6829268336296082
# Epoch 7050, Average Outcome Loss: 0.21256582736968993, Average Accuracy: 0.9633333325386048, Test Accuracy: 0.6585366129875183
